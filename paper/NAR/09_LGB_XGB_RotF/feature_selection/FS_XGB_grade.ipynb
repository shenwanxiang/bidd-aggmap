# %%
import warnings, os
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
from glob import glob


import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from aggmap import AggMap, loadmap
import seaborn as sns


import xgboost as xgb
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_auc_score
from sklearn.metrics import auc as calculate_auc

# %% [markdown]
# ## LGR, RF, KNN, ROF, XGBoost

# %%
from sklearn.ensemble import RandomForestClassifier
from rotation_forest import RotationForestClassifier

# %%
def score(dfr):
    y_true = dfr.y_true
    y_score = dfr.y_score
    y_pred = dfr.y_score.round()

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    acc = (tp + tn) / sum([tn, fp, fn, tp])
    auc = roc_auc_score(y_true, y_score)
    ber =  (fp / (fp + tn) + fn / (tp + fn)) * 0.5

    print('acc: %.3f, roc-auc: %.3f, BER: %.3f' % (acc,auc,ber))

    return acc, auc


def get_best_params(X, y):
    clf = xgb.XGBClassifier(eval_metric='logloss', silent=True, verbose=0)
    parameters = {'max_depth': [4, 6, 9],
                  'n_estimators': [20, 50, 100]}

    grid = GridSearchCV(clf, parameters, scoring='roc_auc', n_jobs=9, iid=False, cv=5, verbose=0)
    gres = grid.fit(X, y)
    return grid.best_params_

# %%
lst = glob('/home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/*.h5')

n_fold = 5

res = []
for p in lst:
    
    print('#'*50 + ' %s ' % p + '#'*50 )
    dfx = pd.read_hdf(p, key = 'expression')
    dfy = pd.read_hdf(p, key = 'labels')
    print(p, dfy.value_counts().to_dict())

    outer = KFold(n_splits = n_fold, shuffle = True, random_state = 123)
    outer_idx = list(outer.split(dfx, dfy))

    fold_all = []
    for i, idx in enumerate(outer_idx):

        fold_num = "fold_%s" % str(i).zfill(2) 

        train_idx, test_idx = idx

        # subset feature selection by the fold change
        dfxy_train = dfx.iloc[train_idx].join(dfy.iloc[train_idx])
        abds = dfxy_train.groupby(dfy.name).mean()
        fc = abs(abds.iloc[0] - abds.iloc[1])
        selected = fc[fc > 0.5].index

        trainX = dfx[selected].iloc[train_idx].values
        trainY = dfy.iloc[train_idx].values

        testX = dfx[selected].iloc[test_idx].values
        testY = dfy.iloc[test_idx].values

        ## training
        print("\nInput train and test X shape is %s, %s  \n" % (trainX.shape,  testX.shape))
        print("Getting the best parameters by gridsearch \n")
        best_params = get_best_params(trainX, trainY)
        clf = xgb.XGBClassifier(eval_metric='logloss', **best_params, n_jobs=-1)
        clf.fit(trainX, trainY)

        ## evaluation
        y_true = testY
        y_score = clf.predict_proba(testX)[:,1]
        dfr = pd.DataFrame([y_true, y_score]).T
        dfr.columns = ['y_true', 'y_score']
        dfr.index = dfy.iloc[test_idx].index
        acc, auc = score(dfr)
        
        fold_all.append(auc)
        res.append([auc, i, p, len(selected), best_params])
        
    print('The auc score for %s is %s.' % (p, np.mean(fold_all)))
# Out:
# ################################################## /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_LIHC_grade.h5 ##################################################
# /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_LIHC_grade.h5 {0: 250, 1: 124}
#
# Input train and test X shape is (299, 2260), (75, 2260)
#
# Getting the best parameters by gridsearch
#
# [22:47:25] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.720, roc-auc: 0.722, BER: 0.347
#
# Input train and test X shape is (299, 2854), (75, 2854)
#
# Getting the best parameters by gridsearch
#
# [23:14:37] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.573, roc-auc: 0.524, BER: 0.558
#
# Input train and test X shape is (299, 1785), (75, 1785)
#
# Getting the best parameters by gridsearch
#
# [23:42:37] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.707, roc-auc: 0.650, BER: 0.381
#
# Input train and test X shape is (299, 1909), (75, 1909)
#
# Getting the best parameters by gridsearch
#
# [00:10:05] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.613, roc-auc: 0.672, BER: 0.455
#
# Input train and test X shape is (300, 1627), (74, 1627)
#
# Getting the best parameters by gridsearch
#
# [00:36:55] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.581, roc-auc: 0.697, BER: 0.519
# The auc score for /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_LIHC_grade.h5 is 0.6529504478529965.
# ################################################## /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_KIRC_grade.h5 ##################################################
# /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_KIRC_grade.h5 {0: 337, 1: 207}
#
# Input train and test X shape is (435, 307), (109, 307)
#
# Getting the best parameters by gridsearch
#
# [01:12:59] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.578, roc-auc: 0.585, BER: 0.482
#
# Input train and test X shape is (435, 173), (109, 173)
#
# Getting the best parameters by gridsearch
#
# [01:52:15] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.615, roc-auc: 0.617, BER: 0.449
#
# Input train and test X shape is (435, 209), (109, 209)
#
# Getting the best parameters by gridsearch
#
# [02:29:02] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.642, roc-auc: 0.659, BER: 0.390
#
# Input train and test X shape is (435, 284), (109, 284)
#
# Getting the best parameters by gridsearch
#
# [03:07:07] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.633, roc-auc: 0.634, BER: 0.404
#
# Input train and test X shape is (436, 1027), (108, 1027)
#
# Getting the best parameters by gridsearch
#
# [03:43:42] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.583, roc-auc: 0.546, BER: 0.471
# The auc score for /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_KIRC_grade.h5 is 0.6080215395824597.
# ################################################## /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_STAD_grade.h5 ##################################################
# /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_STAD_grade.h5 {1: 246, 0: 170}
#
# Input train and test X shape is (332, 4322), (84, 4322)
#
# Getting the best parameters by gridsearch
#
# [04:08:03] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.702, roc-auc: 0.741, BER: 0.325
#
# Input train and test X shape is (333, 1721), (83, 1721)
#
# Getting the best parameters by gridsearch
#
# [04:30:07] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.711, roc-auc: 0.774, BER: 0.290
#
# Input train and test X shape is (333, 5304), (83, 5304)
#
# Getting the best parameters by gridsearch
#
# [04:51:35] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.651, roc-auc: 0.696, BER: 0.354
#
# Input train and test X shape is (333, 3486), (83, 3486)
#
# Getting the best parameters by gridsearch
#
# [05:13:29] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.771, roc-auc: 0.805, BER: 0.271
#
# Input train and test X shape is (333, 3015), (83, 3015)
#
# Getting the best parameters by gridsearch
#
# [05:35:13] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.759, roc-auc: 0.822, BER: 0.252
# The auc score for /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_STAD_grade.h5 is 0.7674306461705023.
# ################################################## /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_UCEC_grade.h5 ##################################################
# /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_UCEC_grade.h5 {1: 324, 0: 230}
#
# Input train and test X shape is (443, 5259), (111, 5259)
#
# Getting the best parameters by gridsearch
#
# [05:56:42] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.766, roc-auc: 0.896, BER: 0.242
#
# Input train and test X shape is (443, 5302), (111, 5302)
#
# Getting the best parameters by gridsearch
#
# [06:18:19] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.838, roc-auc: 0.917, BER: 0.166
#
# Input train and test X shape is (443, 5521), (111, 5521)
#
# Getting the best parameters by gridsearch
#
# [06:40:01] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.829, roc-auc: 0.870, BER: 0.186
#
# Input train and test X shape is (443, 5512), (111, 5512)
#
# Getting the best parameters by gridsearch
#
# [07:00:44] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.784, roc-auc: 0.841, BER: 0.227
#
# Input train and test X shape is (444, 5381), (110, 5381)
#
# Getting the best parameters by gridsearch
#
# [07:15:04] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.827, roc-auc: 0.883, BER: 0.177
# The auc score for /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_UCEC_grade.h5 is 0.8814764653402258.
# ################################################## /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_PAAD_grade.h5 ##################################################
# /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_PAAD_grade.h5 {0: 131, 1: 48}
#
# Input train and test X shape is (143, 2606), (36, 2606)
#
# Getting the best parameters by gridsearch
#
# [07:25:01] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.750, roc-auc: 0.688, BER: 0.359
#
# Input train and test X shape is (143, 1927), (36, 1927)
#
# Getting the best parameters by gridsearch
#
# [07:34:02] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.611, roc-auc: 0.592, BER: 0.472
#
# Input train and test X shape is (143, 1935), (36, 1935)
#
# Getting the best parameters by gridsearch
#
# [07:42:54] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.750, roc-auc: 0.630, BER: 0.463
#
# Input train and test X shape is (143, 2736), (36, 2736)
#
# Getting the best parameters by gridsearch
#
# [07:51:59] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.694, roc-auc: 0.419, BER: 0.569
#
# Input train and test X shape is (144, 1740), (35, 1740)
#
# Getting the best parameters by gridsearch
#
# [08:00:56] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.657, roc-auc: 0.637, BER: 0.392
# The auc score for /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_PAAD_grade.h5 is 0.5928977504532227.
# ################################################## /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_CESC_grade.h5 ##################################################
# /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_CESC_grade.h5 {0: 187, 1: 119}
#
# Input train and test X shape is (244, 1925), (62, 1925)
#
# Getting the best parameters by gridsearch
#
# [08:12:34] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.581, roc-auc: 0.548, BER: 0.468
#
# Input train and test X shape is (245, 2420), (61, 2420)
#
# Getting the best parameters by gridsearch
#
# [08:24:59] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.557, roc-auc: 0.537, BER: 0.469
#
# Input train and test X shape is (245, 1470), (61, 1470)
#
# Getting the best parameters by gridsearch
#
# [08:37:59] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.738, roc-auc: 0.758, BER: 0.362
#
# Input train and test X shape is (245, 1944), (61, 1944)
#
# Getting the best parameters by gridsearch
#
# [08:50:53] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.656, roc-auc: 0.619, BER: 0.361
#
# Input train and test X shape is (245, 2096), (61, 2096)
#
# Getting the best parameters by gridsearch
#
# [09:03:30] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.639, roc-auc: 0.578, BER: 0.400
# The auc score for /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_CESC_grade.h5 is 0.6078591043296926.
# ################################################## /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_test_HNSC_grade.h5 ##################################################
# /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_test_HNSC_grade.h5 {0: 385, 1: 119}
#
# Input train and test X shape is (403, 1849), (101, 1849)
#
# Getting the best parameters by gridsearch
#
# [09:17:51] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.792, roc-auc: 0.741, BER: 0.379
#
# Input train and test X shape is (403, 2578), (101, 2578)
#
# Getting the best parameters by gridsearch
#
# [09:31:40] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.752, roc-auc: 0.604, BER: 0.420
#
# Input train and test X shape is (403, 1450), (101, 1450)
#
# Getting the best parameters by gridsearch
#
# [09:46:37] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.743, roc-auc: 0.772, BER: 0.436
#
# Input train and test X shape is (403, 1612), (101, 1612)
#
# Getting the best parameters by gridsearch
#
# [10:00:32] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.762, roc-auc: 0.761, BER: 0.413
#
# Input train and test X shape is (404, 955), (100, 955)
#
# Getting the best parameters by gridsearch
#
# [10:14:25] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.710, roc-auc: 0.791, BER: 0.423
# The auc score for /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_test_HNSC_grade.h5 is 0.7338392449404268.
# ################################################## /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_LGG_grade.h5 ##################################################
# /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_LGG_grade.h5 {1: 269, 0: 263}
#
# Input train and test X shape is (425, 2390), (107, 2390)
#
# Getting the best parameters by gridsearch
#
# [10:30:13] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.804, roc-auc: 0.861, BER: 0.196
#
# Input train and test X shape is (425, 3233), (107, 3233)
#
# Getting the best parameters by gridsearch
#
# [10:46:19] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.645, roc-auc: 0.702, BER: 0.355
#
# Input train and test X shape is (426, 3169), (106, 3169)
#
# Getting the best parameters by gridsearch
#
# [11:02:32] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.660, roc-auc: 0.721, BER: 0.341
#
# Input train and test X shape is (426, 2814), (106, 2814)
#
# Getting the best parameters by gridsearch
#
# [11:18:10] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.670, roc-auc: 0.711, BER: 0.305
#
# Input train and test X shape is (426, 3157), (106, 3157)
#
# Getting the best parameters by gridsearch
#
# [11:33:44] WARNING: ../src/learner.cc:576:
# Parameters: { "silent", "verbose" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# acc: 0.613, roc-auc: 0.683, BER: 0.387
# The auc score for /home/shenwanxiang/Research/AggMapNet_dataset/TCGA-G/O_z-score_train_LGG_grade.h5 is 0.7357916489271965.

# %%
dfres = pd.DataFrame(res, columns = ['score', 'fold', 'task', 'selected_features', 'best_params'])
dfres.to_csv('./FS_XGB_5FCV_results_grade.csv')
dfres.groupby('task').mean().sort_values('score',ascending=False)
# Out:
#                                                        score  fold  \
# task
# /home/shenwanxiang/Research/AggMapNet_dataset/T...  0.881476   2.0
# /home/shenwanxiang/Research/AggMapNet_dataset/T...  0.767431   2.0
# /home/shenwanxiang/Research/AggMapNet_dataset/T...  0.735792   2.0
# /home/shenwanxiang/Research/AggMapNet_dataset/T...  0.733839   2.0
# /home/shenwanxiang/Research/AggMapNet_dataset/T...  0.652950   2.0
# /home/shenwanxiang/Research/AggMapNet_dataset/T...  0.608022   2.0
# /home/shenwanxiang/Research/AggMapNet_dataset/T...  0.607859   2.0
# /home/shenwanxiang/Research/AggMapNet_dataset/T...  0.592898   2.0
#
#                                                     selected_features
# task
# /home/shenwanxiang/Research/AggMapNet_dataset/T...             5395.0
# /home/shenwanxiang/Research/AggMapNet_dataset/T...             3569.6
# /home/shenwanxiang/Research/AggMapNet_dataset/T...             2952.6
# /home/shenwanxiang/Research/AggMapNet_dataset/T...             1688.8
# /home/shenwanxiang/Research/AggMapNet_dataset/T...             2087.0
# /home/shenwanxiang/Research/AggMapNet_dataset/T...              400.0
# /home/shenwanxiang/Research/AggMapNet_dataset/T...             1971.0
# /home/shenwanxiang/Research/AggMapNet_dataset/T...             2188.8

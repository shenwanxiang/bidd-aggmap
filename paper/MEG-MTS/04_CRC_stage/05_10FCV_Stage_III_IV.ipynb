# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Aug 16 17:10:53 2020

@author: wanxiang.shen@u.nus.edu
"""

import warnings, os
warnings.filterwarnings("ignore")

from copy import copy
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_auc_score
from sklearn.metrics import auc as calculate_auc


import seaborn as sns
import matplotlib.pyplot as plt
from joblib import dump, load
from aggmap import AggMap, AggModel, loadmap

from aggmap import show
np.random.seed(666) #just for reaptable results



def prc_auc_score(y_true, y_score):
    precision, recall, threshold  = precision_recall_curve(y_true, y_score) #PRC_AUC
    auc = calculate_auc(recall, precision)
    return auc


def score(dfr):
    y_true = dfr.y_true
    y_score = dfr.y_score
    y_pred = dfr.y_score.round()

    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    acc = (tp + tn) / sum([tn, fp, fn, tp])
    auc = roc_auc_score(y_true, y_score)

    print('acc: %.3f, roc-auc: %.3f' % (acc,auc))

    return acc, auc


    
def plot_imp(stage, i, dfi, model_dir):
    sns.set(style='white',  font='sans-serif', font_scale=2)
    fig, ax  = plt.subplots(1, 1, figsize=(10, 9))
    
    fold = 'fold_%s' % i
    
    impname = '%s_importance' % stage
    
    dfi.loc[dfi['v']==0, [impname]] = 0
    IMPM = dfi[impname].values.reshape(*mp.fmap_shape)
    sns.heatmap(IMPM,  
                cmap = 'rainbow', alpha = 0.8, xticklabels=10, ax =ax,
                yticklabels=10, vmin = 0.2,
                cbar_kws = {'fraction':0.046, 'pad':0.02})

    plt.title(fold)

    plt.subplots_adjust(wspace = 0.18)

    plt.savefig('./%s/%s.svg' % (model_dir, fold), dpi = 400, bbox_inches="tight")

# %%
from fmp import CalcFeatImp

data = pd.read_csv('./data/dfx.csv', index_col = 0)
label = pd.read_csv('./data/dfy.csv', index_col = 0)

mp = loadmap('./CRC_stage.mp')

# %%
label.groupby('Group').size()
# Out:
# Group
# Healthy         127
# MP               40
# Stage_0          27
# Stage_III_IV     54
# Stage_I_II       69
# dtype: int64

# %% [markdown]
# ## Model: Healthy vs. Stage_III_IV:

# %%
stage = 'Stage_III_IV'
model_dir = './%s_model' % stage

if not os.path.exists(model_dir):
    os.makedirs(model_dir)
    
sld = label[label.Group.isin(['Healthy', stage])].index
dfy = label.loc[sld][['Group']]
dfx = data.loc[sld]
dfx = np.log(dfx + 1e-8)
dfy.shape, dfx.shape
# Out:
# ((181, 1), (181, 7278))

# %%
X = mp.batch_transform(dfx.values, scale_method = 'standard') # NaN values should be the lowest value
Y = pd.get_dummies(dfy['Group']).values
# Out:
# 100%|##########| 181/181 [00:18<00:00,  9.80it/s]

# %%
dfy.shape, dfx.shape
# Out:
# ((181, 1), (181, 7278))

# %%
class_ = pd.get_dummies(dfy['Group']).columns
class_
# Out:
# Index(['Healthy', 'Stage_III_IV'], dtype='object')

# %%
outer_fold = 10
repeat_seeds = [8, 16, 32, 64, 128]#5 repeats random seeds 8, 16, 32, 64, 128

each_fold_results = []
run_all_res = []
imp_res = []
for repeat_seed in repeat_seeds: 
    
    outer = StratifiedKFold(n_splits = outer_fold, shuffle = True, random_state = repeat_seed)
    outer_idx = outer.split(X, Y[:,1])

    print('#'*50 + ' %s ' % repeat_seed + '#'*50 )
    run_one_res = []
    for i, idx in enumerate(outer_idx):
        
        fold_num = "fold_%s" % str(i).zfill(2) 
        
        train_idx, test_idx = idx
        
        testY = Y[test_idx]
        testX = X[test_idx]
        
        trainX = X[train_idx]
        trainY = Y[train_idx]

        print("\n input train and test X shape is %s, %s " % (trainX.shape,  testX.shape))
        
        clf = AggModel.MultiClassEstimator(epochs = 15, gpuid = 5,  conv1_kernel_size = 17,
                                           batch_size = 2, verbose = 0) #
        clf.fit(trainX, trainY) 
        y_true = testY[:,1] #Stage
        y_score = clf.predict_proba(testX)[:,1]
        
        dfr = pd.DataFrame([y_true, y_score]).T
        dfr.columns = ['y_true', 'y_score']
        dfr.index = dfy.iloc[test_idx].index
        acc, auc = score(dfr)
        run_one_res.append(dfr)
        each_fold_results.append([auc, i, repeat_seed])
        
        ## save model for interpretation
        if repeat_seed == 8:
            clf._model.save(os.path.join(model_dir, 'seed_%s_fold_%s.h5' % (repeat_seed, i)))
            model = clf._model
            arrX = trainX
            dfY = pd.DataFrame(trainY, columns = pd.get_dummies(dfy['Group']).columns)
            df_imp = CalcFeatImp(model, mp, arrX, dfY, task_type = 'classification', sigmoidy = False, )
            df_imp.to_excel(os.path.join(model_dir, 'feature_imp_%s_%s.xlsx' % (repeat_seed, i)))
            plot_imp(stage, i, df_imp, model_dir)
            imp_res.append([repeat_seed, i, df_imp])  
            
    run_all_res.append(pd.concat(run_one_res))

dump(imp_res, os.path.join(model_dir, 'feature_imp.pkl'))
# Out:
# ################################################## 8 ##################################################
#
#  input train and test X shape is (162, 86, 85, 5), (19, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.737, roc-auc: 0.744
# 2021-02-06 10:46:29,617 - INFO - [bidd-aggmap] - generate file: ./feature points_7278_correlation_umap_mp
# 2021-02-06 10:46:29,716 - INFO - [bidd-aggmap] - save html file to ./feature points_7278_correlation_umap_mp
#   0%|          | 0/7310 [00:00<?, ?it/s]
# calculating feature importance for Stage_III_IV ...
# 100%|##########| 7310/7310 [11:32<00:00, 10.55it/s]
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.938
# 2021-02-06 10:58:26,163 - INFO - [bidd-aggmap] - generate file: ./feature points_7278_correlation_umap_mp
# 2021-02-06 10:58:26,278 - INFO - [bidd-aggmap] - save html file to ./feature points_7278_correlation_umap_mp
#   0%|          | 0/7310 [00:00<?, ?it/s]
# calculating feature importance for Stage_III_IV ...
# 100%|##########| 7310/7310 [15:48<00:00,  7.70it/s]
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.833, roc-auc: 0.954
# 2021-02-06 11:14:44,265 - INFO - [bidd-aggmap] - generate file: ./feature points_7278_correlation_umap_mp
# 2021-02-06 11:14:44,376 - INFO - [bidd-aggmap] - save html file to ./feature points_7278_correlation_umap_mp
#   0%|          | 0/7310 [00:00<?, ?it/s]
# calculating feature importance for Stage_III_IV ...
# 100%|##########| 7310/7310 [17:07<00:00,  7.12it/s]
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.944, roc-auc: 0.923
# 2021-02-06 11:32:22,427 - INFO - [bidd-aggmap] - generate file: ./feature points_7278_correlation_umap_mp
# 2021-02-06 11:32:22,533 - INFO - [bidd-aggmap] - save html file to ./feature points_7278_correlation_umap_mp
#   0%|          | 3/7310 [00:00<04:31, 26.94it/s]
# calculating feature importance for Stage_III_IV ...
# 100%|##########| 7310/7310 [17:41<00:00,  6.89it/s]
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.985
# 2021-02-06 11:50:31,739 - INFO - [bidd-aggmap] - generate file: ./feature points_7278_correlation_umap_mp
# 2021-02-06 11:50:31,879 - INFO - [bidd-aggmap] - save html file to ./feature points_7278_correlation_umap_mp
#   0%|          | 0/7310 [00:00<?, ?it/s]
# calculating feature importance for Stage_III_IV ...
# 100%|##########| 7310/7310 [16:56<00:00,  7.19it/s]
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 1.000, roc-auc: 1.000
# 2021-02-06 12:07:56,966 - INFO - [bidd-aggmap] - generate file: ./feature points_7278_correlation_umap_mp
# 2021-02-06 12:07:57,142 - INFO - [bidd-aggmap] - save html file to ./feature points_7278_correlation_umap_mp
#   0%|          | 0/7310 [00:00<?, ?it/s]
# calculating feature importance for Stage_III_IV ...
# 100%|##########| 7310/7310 [17:25<00:00,  6.99it/s]
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.944, roc-auc: 0.969
# 2021-02-06 12:25:49,435 - INFO - [bidd-aggmap] - generate file: ./feature points_7278_correlation_umap_mp
# 2021-02-06 12:25:50,632 - INFO - [bidd-aggmap] - save html file to ./feature points_7278_correlation_umap_mp
#   0%|          | 0/7310 [00:00<?, ?it/s]
# calculating feature importance for Stage_III_IV ...
# 100%|##########| 7310/7310 [15:55<00:00,  7.65it/s]
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.958
# 2021-02-06 12:42:13,884 - INFO - [bidd-aggmap] - generate file: ./feature points_7278_correlation_umap_mp
# 2021-02-06 12:42:14,006 - INFO - [bidd-aggmap] - save html file to ./feature points_7278_correlation_umap_mp
#   0%|          | 0/7310 [00:00<?, ?it/s]
# calculating feature importance for Stage_III_IV ...
# 100%|##########| 7310/7310 [17:09<00:00,  7.10it/s]
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.722, roc-auc: 0.764
# 2021-02-06 12:59:55,944 - INFO - [bidd-aggmap] - generate file: ./feature points_7278_correlation_umap_mp
# 2021-02-06 12:59:56,081 - INFO - [bidd-aggmap] - save html file to ./feature points_7278_correlation_umap_mp
#   0%|          | 0/7310 [00:00<?, ?it/s]
# calculating feature importance for Stage_III_IV ...
# 100%|##########| 7310/7310 [19:18<00:00,  6.31it/s]
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.778, roc-auc: 0.917
# 2021-02-06 13:19:53,765 - INFO - [bidd-aggmap] - generate file: ./feature points_7278_correlation_umap_mp
# 2021-02-06 13:19:54,022 - INFO - [bidd-aggmap] - save html file to ./feature points_7278_correlation_umap_mp
#   0%|          | 0/7310 [00:00<?, ?it/s]
# calculating feature importance for Stage_III_IV ...
# 100%|##########| 7310/7310 [22:31<00:00,  5.41it/s]
# ################################################## 16 ##################################################
#
#  input train and test X shape is (162, 86, 85, 5), (19, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.789, roc-auc: 0.769
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.954
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.877
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.944, roc-auc: 0.892
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 1.000, roc-auc: 1.000
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.833, roc-auc: 0.831
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.833, roc-auc: 0.862
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.972
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.833, roc-auc: 0.972
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.917
# ################################################## 32 ##################################################
#
#  input train and test X shape is (162, 86, 85, 5), (19, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.789, roc-auc: 0.872
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.954
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.833, roc-auc: 0.769
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.892
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.944, roc-auc: 0.815
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.722, roc-auc: 0.662
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.833, roc-auc: 0.831
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.833, roc-auc: 0.958
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.944, roc-auc: 0.931
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 1.000
# ################################################## 64 ##################################################
#
#  input train and test X shape is (162, 86, 85, 5), (19, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.895, roc-auc: 0.846
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.944, roc-auc: 0.954
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.778, roc-auc: 0.831
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.833, roc-auc: 0.892
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.954
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 1.000, roc-auc: 1.000
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.831
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.778, roc-auc: 0.861
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.944, roc-auc: 0.986
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.833, roc-auc: 0.764
# ################################################## 128 ##################################################
#
#  input train and test X shape is (162, 86, 85, 5), (19, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.789, roc-auc: 0.859
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.833, roc-auc: 0.831
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.908
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 1.000, roc-auc: 1.000
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.944, roc-auc: 0.985
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.944, roc-auc: 0.954
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.944, roc-auc: 0.985
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.667, roc-auc: 0.708
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.778, roc-auc: 0.736
#
#  input train and test X shape is (163, 86, 85, 5), (18, 86, 85, 5)
# MultiClassEstimator(batch_size=2, conv1_kernel_size=17, epochs=15, gpuid='5')
# acc: 0.889, roc-auc: 0.944
# ['./Stage_III_IV_model/feature_imp.pkl']

# %%
pd.DataFrame(each_fold_results,columns = ['ROC-AUC', 'fold', 'seed']).to_csv('./results/each_fold_performance_results_%s.csv' % stage)

# %%
pd.DataFrame(each_fold_results,columns = ['ROC-AUC', 'fold', 'seed']).groupby('seed').apply(np.mean)
# Out:
#        ROC-AUC  fold   seed
# seed
# 8     0.915171   4.5    8.0
# 16    0.904573   4.5   16.0
# 32    0.868376   4.5   32.0
# 64    0.891880   4.5   64.0
# 128   0.890940   4.5  128.0

# %%
pd.DataFrame(each_fold_results,columns = ['ROC-AUC', 'fold', 'seed']).groupby('seed').apply(np.mean).mean()
# Out:
# ROC-AUC     0.894188
# fold        4.500000
# seed       49.600000
# dtype: float64

# %%
dfres = imp_res[1][-1]
for i, a in enumerate(imp_res):
    df = a[-1]
    dfres['fold_%s' % i] = df['%s_importance' % stage]
    

dfres = dfres.drop(columns=['%s_importance' % stage])
dfres['scatter_x'] = dfres['v'].map(mp.df_embedding.x.to_dict())
dfres['scatter_y'] = dfres['v'].map(mp.df_embedding.y.to_dict())
dfres = dfres.rename(columns = {'x':'grid_x', 'y':'grid_y', 'v': 'feature_points'})
dfres = dfres[['feature_points', 'grid_x', 'grid_y','scatter_x', 'scatter_y', 'Subtypes', 'colors', 'fold_0',
       'fold_1', 'fold_2', 'fold_3', 'fold_4', 'fold_5', 'fold_6', 'fold_7','fold_8', 'fold_9', ]]
dfres = dfres.set_index('feature_points')
dfres["%s_avg_imp" % stage] = dfres[dfres.columns[-10:]].mean(axis=1)
#dfres = dfres.sort_values("%s_avg_imp" % stage, ascending=False)
dfres.to_excel('./results/%s_importance.xlsx' % stage)

# %%
sns.set(style='white',  font='sans-serif', font_scale=2)
fig, ax  = plt.subplots(1, 1, figsize=(10, 9))

IMPM = dfres["%s_avg_imp" % stage] .values.reshape(*mp.fmap_shape)
sns.heatmap(IMPM,  
            cmap = 'rainbow', alpha = 0.8, xticklabels=10, ax =ax,
            yticklabels=10, vmin = 0.2,
            cbar_kws = {'fraction':0.046, 'pad':0.02})

plt.title("%s_average_importance" % stage)

plt.subplots_adjust(wspace = 0.18)

plt.savefig("./results/%s_average_importance.svg" % stage, dpi = 400, bbox_inches="tight")

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Aug 16 17:10:53 2020

@author: wanxiang.shen@u.nus.edu
"""

import warnings, os
warnings.filterwarnings("ignore")

from copy import copy
from glob import glob

import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_auc_score
from sklearn.metrics import auc as calculate_auc


import seaborn as sns
import matplotlib.pyplot as plt
from joblib import dump, load
from aggmap import AggMap, AggModel, loadmap

from aggmap import show
np.random.seed(666) #just for reaptable results

# %%
mp = loadmap('/raid/shenwanxiang/agg_mp_object/RSPC-S.mp')

# %%
lst = glob('./tasks_O_z-score/*.h5')

# %%
p = lst[0]
dfx = pd.read_hdf(p, key = 'expression')
dfy = pd.read_hdf(p, key = 'labels')

# %%
X = mp.batch_transform(dfx.values)
# Out:
# 100%|##########| 554/554 [03:10<00:00,  2.90it/s]

# %%
dfy
# Out:
# 46C422D1-E1A1-42E5-8FB1-918C0DAE533D    0
# FCD43986-D877-4856-A4E0-F35AF0A5117D    1
# 122D1D3C-8C13-4BFF-A135-2A308C6A9483    0
# BACA9F84-971B-43B5-834F-8C524D378998    1
# 38F5957E-0A99-432D-8F0B-B48E03F17668    0
#                                        ..
# 78F28873-E471-497A-9405-FB8955808599    1
# 9A33172F-AEEA-4B7D-9605-0C60D7872CEA    0
# 6DA90F71-A4FF-4AD6-A270-7FFB160D01EA    1
# E2A4C651-977F-4F40-B5EC-46DF75944141    0
# D2101E37-DF46-42AC-B1CD-B1B3BAA71104    0
# Name: xml_neoplasm_histologic_grade, Length: 554, dtype: int64

# %%
show.imshow_wrap(X[0],x_max=1, vmin = 0, color_list = list(mp.colormaps.values()))

# %%
show.imshow_wrap(X[1],x_max=1, vmin = 0, color_list = list(mp.colormaps.values()))

# %%
plt.imshow(X[1].sum(axis=-1))

# %%
plt.imshow(X[0].sum(axis=-1))

# %%
plt.imshow(X[2].sum(axis=-1))

# %%
plt.imshow(X[-3].sum(axis=-1))

# %%
plt.imshow(X[-1].sum(axis=-1))

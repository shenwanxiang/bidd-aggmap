# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Aug 16 17:10:53 2020

@author: wanxiang.shen@u.nus.edu
"""

import warnings, os
warnings.filterwarnings("ignore")


import pandas as pd
import numpy as np
from glob import glob

from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_auc_score
from sklearn.metrics import auc as calculate_auc

import matplotlib.pyplot as plt
import seaborn as sns

from aggmap import AggMap, AggModel, loadmap
from aggmap import show
np.random.seed(666) #just for reaptable results

# %%
flist = glob('./data/*.csv.gzip')
flist = pd.Series(flist).sort_values().tolist()
fall = []
for i in flist:
    df1 = pd.read_csv(i, compression='gzip', index_col = 0)
    df1['class'] = i.split('/')[-1].split('.csv')[0]
    fall.append(df1)
    
df = pd.concat(fall, axis=0)

# %%
dfx = df[df.columns[:-1]]
dfy = df[df.columns[-1:]]
dfx = np.log2(dfx + 1) #apply log2(x + 1)

# %%
scale_method = 'minmax'
mp = loadmap('/raid/shenwanxiang/agg_mp_object/pan-cancer.mp')
X = mp.batch_transform(dfx.values, scale_method = scale_method) 
Y = pd.get_dummies(dfy['class']).values
# Out:
# 100%|##########| 10446/10446 [24:22<00:00,  7.14it/s]

# %%
mp.fmap_shape
# Out:
# (102, 102)

# %%
dfy.shape, dfx.shape
# Out:
# ((10446, 1), (10446, 10381))

# %%
class_ = pd.get_dummies(dfy['class']).columns
class_
# Out:
# Index(['01_ACC', '02_BLCA', '03_BRCA', '04_CESC', '05_CHOL', '06_COAD',
#        '07_DLBC', '08_ESCA', '09_GBM', '10_HNSC', '11_KICH', '12_KIRC',
#        '13_KIRP', '14_LAML', '15_LGG', '16_LIHC', '17_LUAD', '18_LUSC',
#        '19_MESO', '20_OV', '21_PAAD', '22_PCPG', '23_PRAD', '24_READ',
#        '25_SARC', '26_SKCM', '27_STAD', '28_TGCT', '29_THCA', '30_THYM',
#        '31_UCEC', '32_UCS', '33_UVM'],
#       dtype='object')

# %% [markdown]
# ## feature maps

# %%
idx = dfy.reset_index().groupby('class').apply(lambda x:x.index.tolist())
rows = idx.index.tolist()
fontsize = 20
fig, axes = plt.subplots(nrows=3, ncols=11, figsize=(25, 8), sharex = True, sharey = True)

for row, ax in zip(rows, axes.ravel()):
    pid = idx.loc[row][0]  
    pid_name = row.split('_')[-1]
    x = X[pid]
    #ax.imshow(x.sum(axis=-1))
    #show.imshow(x, ax = ax,  mode = 'dark', color_list= pd.Series(mp.colormaps).tolist(), x_max=1, vmin=0, vmax=0.5) #
    show.imshow(x, ax = ax,  mode = 'dark', color_list= pd.Series(mp.colormaps).tolist(), x_max=x.max()-0.05, vmin=-0.1, ) # vmax=x.max()
    ax.set_xlabel(pid_name, fontsize = fontsize) 

fig.tight_layout()
fig.savefig('./fmp-5.png', bbox_inches='tight', dpi=400) 
# fig.savefig('./fmp.svg', bbox_inches='tight', dpi=400)

# %%
classes = [i.split('_')[-1] for i in class_]
select = ['READ','CHOL', 'UCS', 'KICH', 'ESCA']
s = idx.apply(lambda x:x[0])
s.index = classes
s = s.loc[select]
fontsize = 20
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(8, 1.8), sharex = True, sharey = True)

for i, j, ax in zip(s.tolist(),s.index, axes.ravel()):
    pid_name = j
    x = X[i]
#     ax.imshow(x, cmap = 'gray')
#     ax.set_xticks([])
#     ax.set_yticks([])
    show.imshow(x, ax = ax,  mode = 'dark', color_list= pd.Series(mp.colormaps).tolist(), x_max=x.max()-0.05, vmin=-0.1, ) # vmax=x.max()
    #show.imshow(x.sum(axis=-1).reshape(102,102,1), ax = ax,  mode = 'dark', color_list= ['gray'], x_max=1) #
    #ax.set_xlabel(pid_name, fontsize = fontsize) 
    
fig.tight_layout()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.05)
#fig.savefig('./Lyu-reshape-5.pdf', bbox_inches='tight', dpi=400) 
# fig.savefig('./fmp.svg', bbox_inches='tight', dpi=400)

# %%
classes = [i.split('_')[-1] for i in class_]
select = ['READ','CHOL', 'UCS', 'KICH', 'ESCA']
s = idx.apply(lambda x:x[0])
s.index = classes
s = s.loc[select]
fontsize = 20
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(8, 2), sharex = True, sharey = True)

for i, j, ax in zip(s.tolist(),s.index, axes.ravel()):
    pid_name = j
    x = X[i]
    ax.imshow(x.sum(axis=-1), cmap = 'gray')
    ax.set_xticks([])
    ax.set_yticks([])
    #show.imshow(x.sum(axis=-1).reshape(102,102,1), ax = ax,  mode = 'dark', color_list= ['gray'], x_max=1) #
    #ax.set_xlabel(pid_name, fontsize = fontsize) 
    
fig.tight_layout()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.05)
#fig.savefig('./Lyu-reshape-5.pdf', bbox_inches='tight', dpi=400) 
# fig.savefig('./fmp.svg', bbox_inches='tight', dpi=400)

# %%
idx = dfy.reset_index().groupby('class').apply(lambda x:x.index.tolist())
rows = idx.index.tolist()
fontsize = 20
fig, axes = plt.subplots(nrows=3, ncols=11, figsize=(25, 8), sharex = True, sharey = True)

for row, ax in zip(rows, axes.ravel()):
    pid = idx.loc[row][0]  
    pid_name = row.split('_')[-1]
    x = X[pid]
    ax.imshow(x.sum(axis=-1), cmap = 'gray')
    ax.set_xticks([])
    ax.set_yticks([])
    #show.imshow(x.sum(axis=-1).reshape(102,102,1), ax = ax,  mode = 'dark', color_list= ['gray'], x_max=1) #
    ax.set_xlabel(pid_name, fontsize = fontsize) 

    
fig.tight_layout()
fig.savefig('./fmp-1.png', bbox_inches='tight', dpi=400) 
# fig.savefig('./fmp.svg', bbox_inches='tight', dpi=400)

# %% [markdown]
# ## 10 fold cv performances

# %%
outer_fold = 10
# n, w,h,c = X.shape
# X1 = X.sum(axis=-1).reshape(n,w,h,1)

each_fold_results = []
outer = StratifiedKFold(n_splits = outer_fold, shuffle = True)
outer_idx = outer.split(X, dfy.values)

print('#'*50  )
run_one_res = []
for i, idx in enumerate(outer_idx):

    fold_num = "fold_%s" % str(i).zfill(2) 

    save_path = './fold_results_c5/%s' % fold_num
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    train_idx, test_idx = idx

    testY = Y[test_idx]
    testX = X[test_idx]

    trainX = X[train_idx]
    trainY = Y[train_idx]

    test_true_label = pd.DataFrame(testY).idxmax(axis=1).to_frame(name = 'y_true')
    test_true_label.index = dfy.iloc[test_idx].index
    test_true_label = test_true_label.join(dfy.iloc[test_idx])
    test_true_label.to_csv(os.path.join(save_path, 'test_true_label.csv'))


    print("\n input train and test X shape is %s, %s " % (trainX.shape,  testX.shape))

    clf = AggModel.MultiClassEstimator(epochs = 100, batch_size = 64, lr = 1e-3,  
                                       gpuid = 4, verbose = 1, metric = 'ACC', ) #
    clf.fit(trainX, trainY) 

    clf._model.save(os.path.join(save_path, 'model.h5'))
    
    test_pred_label = pd.DataFrame(clf.predict(testX)).idxmax(axis=1).to_frame(name = 'y_pred')
    test_pred_label.index = test_true_label.index
    test_pred_label.to_csv(os.path.join(save_path, 'test_pred_label.csv'))

    test_avg_loss, test_avg_acc = clf._model.evaluate(testX, testY, verbose=0)
    print('test_avg_loss: %.3f, test_avg_acc: %.3f, ' % (test_avg_loss, test_avg_acc))

    each_fold_results.append(test_avg_acc)
# Out:
# ##################################################
#
#  input train and test X shape is (9401, 102, 102, 5), (1045, 102, 102, 5)
# MultiClassEstimator(batch_size=64, epochs=100, gpuid='4', lr=0.001,
#                     metric='ACC', verbose=1)
# Train on 9401 samples, validate on 9401 samples
# Epoch 1/100
# 9401/9401 [==============================] - 33s 3ms/sample - loss: 1.9340 - accuracy: 0.4823 - val_loss: 0.8339 - val_accuracy: 0.7551
# Epoch 2/100
# 9401/9401 [==============================] - 26s 3ms/sample - loss: 0.6018 - accuracy: 0.8223 - val_loss: 0.5090 - val_accuracy: 0.8445
# Epoch 3/100
# 9401/9401 [==============================] - 26s 3ms/sample - loss: 0.3723 - accuracy: 0.8896 - val_loss: 0.2811 - val_accuracy: 0.9162
# Epoch 4/100
# 9401/9401 [==============================] - 25s 3ms/sample - loss: 0.3003 - accuracy: 0.9095 - val_loss: 0.2410 - val_accuracy: 0.9216
# Epoch 5/100
# 9401/9401 [==============================] - 25s 3ms/sample - loss: 0.2535 - accuracy: 0.9194 - val_loss: 0.2594 - val_accuracy: 0.9223
# Epoch 6/100
# 9401/9401 [==============================] - 26s 3ms/sample - loss: 0.2146 - accuracy: 0.9327 - val_loss: 0.2104 - val_accuracy: 0.9308
# Epoch 7/100
# 9401/9401 [==============================] - 26s 3ms/sample - loss: 0.2051 - accuracy: 0.9320 - val_loss: 0.1532 - val_accuracy: 0.9477
# Epoch 8/100
# 9401/9401 [==============================] - 25s 3ms/sample - loss: 0.1767 - accuracy: 0.9395 - val_loss: 0.1552 - val_accuracy: 0.9495
# Epoch 9/100
# 9401/9401 [==============================] - 25s 3ms/sample - loss: 0.1717 - accuracy: 0.9406 - val_loss: 0.1596 - val_accuracy: 0.9523
# Epoch 10/100
# 9401/9401 [==============================] - 24s 3ms/sample - loss: 0.1619 - accuracy: 0.9438 - val_loss: 0.1761 - val_accuracy: 0.9399
# Epoch 11/100
# 9401/9401 [==============================] - 24s 3ms/sample - loss: 0.1391 - accuracy: 0.9502 - val_loss: 0.1341 - val_accuracy: 0.9553
# Epoch 12/100
# 9401/9401 [==============================] - 24s 3ms/sample - loss: 0.1408 - accuracy: 0.9497 - val_loss: 0.1204 - val_accuracy: 0.9582
# Epoch 13/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 0.1365 - accuracy: 0.9505 - val_loss: 0.0937 - val_accuracy: 0.9668
# Epoch 14/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.1139 - accuracy: 0.9568 - val_loss: 0.1217 - val_accuracy: 0.9521
# Epoch 15/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.1152 - accuracy: 0.9582 - val_loss: 0.0805 - val_accuracy: 0.9706
# Epoch 16/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0970 - accuracy: 0.9649 - val_loss: 0.0990 - val_accuracy: 0.9594
# Epoch 17/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0994 - accuracy: 0.9643 - val_loss: 0.0937 - val_accuracy: 0.9662
# Epoch 18/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0853 - accuracy: 0.9675 - val_loss: 0.0749 - val_accuracy: 0.9723
# Epoch 19/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0809 - accuracy: 0.9695 - val_loss: 0.0839 - val_accuracy: 0.9694
# Epoch 20/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0878 - accuracy: 0.9686 - val_loss: 0.0847 - val_accuracy: 0.9704
# Epoch 21/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0737 - accuracy: 0.9740 - val_loss: 0.0519 - val_accuracy: 0.9822
# Epoch 22/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0677 - accuracy: 0.9750 - val_loss: 0.0622 - val_accuracy: 0.9766
# Epoch 23/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0668 - accuracy: 0.9748 - val_loss: 0.1010 - val_accuracy: 0.9668
# Epoch 24/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0747 - accuracy: 0.9729 - val_loss: 0.0680 - val_accuracy: 0.9763
# Epoch 25/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0521 - accuracy: 0.9816 - val_loss: 0.0610 - val_accuracy: 0.9777
# Epoch 26/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0560 - accuracy: 0.9793 - val_loss: 0.0546 - val_accuracy: 0.9811
# Epoch 27/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0478 - accuracy: 0.9819 - val_loss: 0.0432 - val_accuracy: 0.9837
# Epoch 28/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0486 - accuracy: 0.9817 - val_loss: 0.0284 - val_accuracy: 0.9913
# Epoch 29/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0414 - accuracy: 0.9844 - val_loss: 0.0339 - val_accuracy: 0.9878
# Epoch 30/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0375 - accuracy: 0.9872 - val_loss: 0.0318 - val_accuracy: 0.9883
# Epoch 31/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0327 - accuracy: 0.9897 - val_loss: 0.0179 - val_accuracy: 0.9944
# Epoch 32/100
# 9401/9401 [==============================] - 24s 3ms/sample - loss: 0.0253 - accuracy: 0.9904 - val_loss: 0.0303 - val_accuracy: 0.9910
# Epoch 33/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0323 - accuracy: 0.9888 - val_loss: 0.0248 - val_accuracy: 0.9922
# Epoch 34/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0206 - accuracy: 0.9930 - val_loss: 0.0106 - val_accuracy: 0.9981
# Epoch 35/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0287 - accuracy: 0.9904 - val_loss: 0.0703 - val_accuracy: 0.9713
# Epoch 36/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0386 - accuracy: 0.9876 - val_loss: 0.0423 - val_accuracy: 0.9869
# Epoch 37/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0338 - accuracy: 0.9868 - val_loss: 0.0195 - val_accuracy: 0.9929
# Epoch 38/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0187 - accuracy: 0.9932 - val_loss: 0.0251 - val_accuracy: 0.9897
# Epoch 39/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0218 - accuracy: 0.9924 - val_loss: 0.0109 - val_accuracy: 0.9967
# Epoch 40/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0322 - accuracy: 0.9886 - val_loss: 0.0142 - val_accuracy: 0.9964
# Epoch 41/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0130 - accuracy: 0.9959 - val_loss: 0.0174 - val_accuracy: 0.9926
# Epoch 42/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0258 - accuracy: 0.9915 - val_loss: 0.0140 - val_accuracy: 0.9962
# Epoch 43/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0260 - accuracy: 0.9909 - val_loss: 0.0691 - val_accuracy: 0.9739
# Epoch 44/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0350 - accuracy: 0.9880 - val_loss: 0.0337 - val_accuracy: 0.9855
# Epoch 45/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0207 - accuracy: 0.9934 - val_loss: 0.0091 - val_accuracy: 0.9984
# Epoch 46/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0170 - accuracy: 0.9943 - val_loss: 0.0378 - val_accuracy: 0.9877
# Epoch 47/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0247 - accuracy: 0.9919 - val_loss: 0.0062 - val_accuracy: 0.9983
# Epoch 48/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0104 - accuracy: 0.9966 - val_loss: 0.0073 - val_accuracy: 0.9976
# Epoch 49/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0098 - accuracy: 0.9970 - val_loss: 0.0066 - val_accuracy: 0.9979
# Epoch 50/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0132 - accuracy: 0.9952 - val_loss: 0.0083 - val_accuracy: 0.9976
# Epoch 51/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0146 - accuracy: 0.9960 - val_loss: 0.0066 - val_accuracy: 0.9983
# Epoch 52/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0145 - accuracy: 0.9949 - val_loss: 0.0177 - val_accuracy: 0.9952
# Epoch 53/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0386 - accuracy: 0.9868 - val_loss: 0.0172 - val_accuracy: 0.9956
# Epoch 54/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0202 - accuracy: 0.9931 - val_loss: 0.0088 - val_accuracy: 0.9972
# Epoch 55/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0077 - accuracy: 0.9978 - val_loss: 0.0014 - val_accuracy: 1.0000
# Epoch 56/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0077 - accuracy: 0.9971 - val_loss: 0.0181 - val_accuracy: 0.9948
# Epoch 57/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0098 - accuracy: 0.9966 - val_loss: 0.0045 - val_accuracy: 0.9989
# Epoch 58/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0086 - accuracy: 0.9971 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 59/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0353 - accuracy: 0.9890 - val_loss: 0.0593 - val_accuracy: 0.9787
# Epoch 60/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0324 - accuracy: 0.9883 - val_loss: 0.0104 - val_accuracy: 0.9965
# Epoch 61/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0061 - val_accuracy: 0.9982
# Epoch 62/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0160 - accuracy: 0.9946 - val_loss: 0.0095 - val_accuracy: 0.9981
# Epoch 63/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.0013 - val_accuracy: 0.9998
# Epoch 64/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 65/100
# 9401/9401 [==============================] - 26s 3ms/sample - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0026 - val_accuracy: 0.9995
# Epoch 66/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0081 - accuracy: 0.9971 - val_loss: 0.0172 - val_accuracy: 0.9926
# Epoch 67/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0171 - accuracy: 0.9944 - val_loss: 0.0054 - val_accuracy: 0.9984
# Epoch 68/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0225 - accuracy: 0.9928 - val_loss: 0.0294 - val_accuracy: 0.9896
# Epoch 69/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0252 - accuracy: 0.9918 - val_loss: 0.0078 - val_accuracy: 0.9980
# Epoch 70/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0033 - accuracy: 0.9989 - val_loss: 3.9418e-04 - val_accuracy: 1.0000
# Epoch 71/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 3.8016e-04 - accuracy: 1.0000 - val_loss: 2.5717e-04 - val_accuracy: 1.0000
# Epoch 72/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.4441e-04 - accuracy: 1.0000 - val_loss: 9.2501e-05 - val_accuracy: 1.0000
# Epoch 73/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 8.4879e-05 - accuracy: 1.0000 - val_loss: 6.9190e-05 - val_accuracy: 1.0000
# Epoch 74/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 6.7570e-05 - accuracy: 1.0000 - val_loss: 5.8064e-05 - val_accuracy: 1.0000
# Epoch 75/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 5.6382e-05 - accuracy: 1.0000 - val_loss: 4.9006e-05 - val_accuracy: 1.0000
# Epoch 76/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 4.8736e-05 - accuracy: 1.0000 - val_loss: 4.2840e-05 - val_accuracy: 1.0000
# Epoch 77/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 4.2696e-05 - accuracy: 1.0000 - val_loss: 3.8041e-05 - val_accuracy: 1.0000
# Epoch 78/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 3.7451e-05 - accuracy: 1.0000 - val_loss: 3.3177e-05 - val_accuracy: 1.0000
# Epoch 79/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 3.3250e-05 - accuracy: 1.0000 - val_loss: 2.9776e-05 - val_accuracy: 1.0000
# Epoch 80/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 2.9443e-05 - accuracy: 1.0000 - val_loss: 2.7074e-05 - val_accuracy: 1.0000
# Epoch 81/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 2.6998e-05 - accuracy: 1.0000 - val_loss: 2.4587e-05 - val_accuracy: 1.0000
# Epoch 82/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 2.4216e-05 - accuracy: 1.0000 - val_loss: 2.2215e-05 - val_accuracy: 1.0000
# Epoch 83/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 2.1912e-05 - accuracy: 1.0000 - val_loss: 2.0030e-05 - val_accuracy: 1.0000
# Epoch 84/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 2.0097e-05 - accuracy: 1.0000 - val_loss: 1.8326e-05 - val_accuracy: 1.0000
# Epoch 85/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 1.8231e-05 - accuracy: 1.0000 - val_loss: 1.6756e-05 - val_accuracy: 1.0000
# Epoch 86/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.7004e-05 - accuracy: 1.0000 - val_loss: 1.5325e-05 - val_accuracy: 1.0000
# Epoch 87/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 1.5338e-05 - accuracy: 1.0000 - val_loss: 1.4173e-05 - val_accuracy: 1.0000
# Epoch 88/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.4149e-05 - accuracy: 1.0000 - val_loss: 1.3020e-05 - val_accuracy: 1.0000
# Epoch 89/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 1.3045e-05 - accuracy: 1.0000 - val_loss: 1.2116e-05 - val_accuracy: 1.0000
# Epoch 90/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.1977e-05 - accuracy: 1.0000 - val_loss: 1.1236e-05 - val_accuracy: 1.0000
# Epoch 91/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 1.1219e-05 - accuracy: 1.0000 - val_loss: 1.0201e-05 - val_accuracy: 1.0000
# Epoch 92/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.0308e-05 - accuracy: 1.0000 - val_loss: 9.5001e-06 - val_accuracy: 1.0000
# Epoch 93/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 9.4890e-06 - accuracy: 1.0000 - val_loss: 8.8089e-06 - val_accuracy: 1.0000
# Epoch 94/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 8.8442e-06 - accuracy: 1.0000 - val_loss: 8.1150e-06 - val_accuracy: 1.0000
# Epoch 95/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 8.0884e-06 - accuracy: 1.0000 - val_loss: 7.6169e-06 - val_accuracy: 1.0000
# Epoch 96/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 7.5874e-06 - accuracy: 1.0000 - val_loss: 6.9333e-06 - val_accuracy: 1.0000
# Epoch 97/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 7.0250e-06 - accuracy: 1.0000 - val_loss: 6.3953e-06 - val_accuracy: 1.0000
# Epoch 98/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 6.4402e-06 - accuracy: 1.0000 - val_loss: 5.8973e-06 - val_accuracy: 1.0000
# Epoch 99/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 5.9659e-06 - accuracy: 1.0000 - val_loss: 5.3902e-06 - val_accuracy: 1.0000
# Epoch 100/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 5.4102e-06 - accuracy: 1.0000 - val_loss: 5.2469e-06 - val_accuracy: 1.0000
# test_avg_loss: 0.275, test_avg_acc: 0.958,
#
#  input train and test X shape is (9401, 102, 102, 5), (1045, 102, 102, 5)
# MultiClassEstimator(batch_size=64, epochs=100, gpuid='4', lr=0.001,
#                     metric='ACC', verbose=1)
# Train on 9401 samples, validate on 9401 samples
# Epoch 1/100
# 9401/9401 [==============================] - 25s 3ms/sample - loss: 1.9124 - accuracy: 0.4812 - val_loss: 1.0384 - val_accuracy: 0.6774
# Epoch 2/100
# 9401/9401 [==============================] - 19s 2ms/sample - loss: 0.7158 - accuracy: 0.7927 - val_loss: 0.5058 - val_accuracy: 0.8561
# Epoch 3/100
# 9401/9401 [==============================] - 19s 2ms/sample - loss: 0.4347 - accuracy: 0.8736 - val_loss: 0.4047 - val_accuracy: 0.8784
# Epoch 4/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.3303 - accuracy: 0.8993 - val_loss: 0.2961 - val_accuracy: 0.9097
# Epoch 5/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.2703 - accuracy: 0.9165 - val_loss: 0.2913 - val_accuracy: 0.9175
# Epoch 6/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.2321 - accuracy: 0.9259 - val_loss: 0.1875 - val_accuracy: 0.9367
# Epoch 7/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1971 - accuracy: 0.9361 - val_loss: 0.1583 - val_accuracy: 0.9449
# Epoch 8/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1856 - accuracy: 0.9385 - val_loss: 0.1452 - val_accuracy: 0.9473
# Epoch 9/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1673 - accuracy: 0.9432 - val_loss: 0.1618 - val_accuracy: 0.9443
# Epoch 10/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.1553 - accuracy: 0.9480 - val_loss: 0.1264 - val_accuracy: 0.9548
# Epoch 11/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.1370 - accuracy: 0.9515 - val_loss: 0.1362 - val_accuracy: 0.9510
# Epoch 12/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1330 - accuracy: 0.9563 - val_loss: 0.1103 - val_accuracy: 0.9632
# Epoch 13/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.1281 - accuracy: 0.9555 - val_loss: 0.0976 - val_accuracy: 0.9657
# Epoch 14/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.1157 - accuracy: 0.9589 - val_loss: 0.1357 - val_accuracy: 0.9482
# Epoch 15/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1119 - accuracy: 0.9595 - val_loss: 0.1048 - val_accuracy: 0.9606
# Epoch 16/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1051 - accuracy: 0.9615 - val_loss: 0.0972 - val_accuracy: 0.9626
# Epoch 17/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0913 - accuracy: 0.9659 - val_loss: 0.1084 - val_accuracy: 0.9602
# Epoch 18/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0936 - accuracy: 0.9643 - val_loss: 0.0605 - val_accuracy: 0.9792
# Epoch 19/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0793 - accuracy: 0.9697 - val_loss: 0.0919 - val_accuracy: 0.9636
# Epoch 20/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0726 - accuracy: 0.9723 - val_loss: 0.0609 - val_accuracy: 0.9757
# Epoch 21/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0740 - accuracy: 0.9733 - val_loss: 0.0855 - val_accuracy: 0.9653
# Epoch 22/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0707 - accuracy: 0.9720 - val_loss: 0.0649 - val_accuracy: 0.9743
# Epoch 23/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0604 - accuracy: 0.9768 - val_loss: 0.0497 - val_accuracy: 0.9861
# Epoch 24/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0518 - accuracy: 0.9804 - val_loss: 0.0664 - val_accuracy: 0.9735
# Epoch 25/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0621 - accuracy: 0.9780 - val_loss: 0.0696 - val_accuracy: 0.9738
# Epoch 26/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0528 - accuracy: 0.9820 - val_loss: 0.0508 - val_accuracy: 0.9822
# Epoch 27/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0558 - accuracy: 0.9789 - val_loss: 0.0578 - val_accuracy: 0.9795
# Epoch 28/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0649 - accuracy: 0.9773 - val_loss: 0.0262 - val_accuracy: 0.9890
# Epoch 29/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0390 - accuracy: 0.9864 - val_loss: 0.0397 - val_accuracy: 0.9863
# Epoch 30/100
# 9401/9401 [==============================] - 24s 3ms/sample - loss: 0.0330 - accuracy: 0.9879 - val_loss: 0.0555 - val_accuracy: 0.9778
# Epoch 31/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0334 - accuracy: 0.9868 - val_loss: 0.0242 - val_accuracy: 0.9907
# Epoch 32/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0250 - accuracy: 0.9910 - val_loss: 0.0273 - val_accuracy: 0.9887
# Epoch 33/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0310 - accuracy: 0.9892 - val_loss: 0.0629 - val_accuracy: 0.9761
# Epoch 34/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0466 - accuracy: 0.9831 - val_loss: 0.0588 - val_accuracy: 0.9816
# Epoch 35/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0361 - accuracy: 0.9865 - val_loss: 0.0231 - val_accuracy: 0.9910
# Epoch 36/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0267 - accuracy: 0.9909 - val_loss: 0.0331 - val_accuracy: 0.9889
# Epoch 37/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0544 - accuracy: 0.9815 - val_loss: 0.0179 - val_accuracy: 0.9955
# Epoch 38/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0218 - accuracy: 0.9927 - val_loss: 0.0078 - val_accuracy: 0.9983
# Epoch 39/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0176 - accuracy: 0.9941 - val_loss: 0.0248 - val_accuracy: 0.9918
# Epoch 40/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0245 - accuracy: 0.9922 - val_loss: 0.0540 - val_accuracy: 0.9809
# Epoch 41/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0391 - accuracy: 0.9851 - val_loss: 0.0265 - val_accuracy: 0.9922
# Epoch 42/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0328 - accuracy: 0.9880 - val_loss: 0.0764 - val_accuracy: 0.9752
# Epoch 43/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.0129 - val_accuracy: 0.9956
# Epoch 44/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0073 - accuracy: 0.9983 - val_loss: 0.0043 - val_accuracy: 0.9994
# Epoch 45/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0110 - accuracy: 0.9966 - val_loss: 0.0338 - val_accuracy: 0.9856
# Epoch 46/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0250 - accuracy: 0.9912 - val_loss: 0.0198 - val_accuracy: 0.9924
# Epoch 47/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0357 - accuracy: 0.9879 - val_loss: 0.0105 - val_accuracy: 0.9980
# Epoch 48/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0169 - accuracy: 0.9939 - val_loss: 0.0129 - val_accuracy: 0.9949
# Epoch 49/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0190 - accuracy: 0.9944 - val_loss: 0.0153 - val_accuracy: 0.9954
# Epoch 50/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0150 - accuracy: 0.9947 - val_loss: 0.0035 - val_accuracy: 0.9994
# Epoch 51/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0028 - accuracy: 0.9996 - val_loss: 8.7531e-04 - val_accuracy: 1.0000
# Epoch 52/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 4.8131e-04 - accuracy: 1.0000 - val_loss: 3.1040e-04 - val_accuracy: 1.0000
# Epoch 53/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 3.1708e-04 - accuracy: 1.0000 - val_loss: 2.4318e-04 - val_accuracy: 1.0000
# Epoch 54/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 2.2316e-04 - accuracy: 1.0000 - val_loss: 1.8794e-04 - val_accuracy: 1.0000
# Epoch 55/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 1.8096e-04 - accuracy: 1.0000 - val_loss: 1.6482e-04 - val_accuracy: 1.0000
# Epoch 56/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.5578e-04 - accuracy: 1.0000 - val_loss: 1.3627e-04 - val_accuracy: 1.0000
# Epoch 57/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.3359e-04 - accuracy: 1.0000 - val_loss: 1.1275e-04 - val_accuracy: 1.0000
# Epoch 58/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.1928e-04 - accuracy: 1.0000 - val_loss: 1.0022e-04 - val_accuracy: 1.0000
# Epoch 59/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.0238e-04 - accuracy: 1.0000 - val_loss: 9.3510e-05 - val_accuracy: 1.0000
# Epoch 60/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 9.3369e-05 - accuracy: 1.0000 - val_loss: 8.1291e-05 - val_accuracy: 1.0000
# Epoch 61/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 8.1637e-05 - accuracy: 1.0000 - val_loss: 7.3615e-05 - val_accuracy: 1.0000
# Epoch 62/100
# 9401/9401 [==============================] - 26s 3ms/sample - loss: 7.4090e-05 - accuracy: 1.0000 - val_loss: 6.5566e-05 - val_accuracy: 1.0000
# Epoch 63/100
# 9401/9401 [==============================] - 17s 2ms/sample - loss: 6.7646e-05 - accuracy: 1.0000 - val_loss: 6.1559e-05 - val_accuracy: 1.0000
# Epoch 64/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 6.0359e-05 - accuracy: 1.0000 - val_loss: 5.4397e-05 - val_accuracy: 1.0000
# Epoch 65/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 5.4081e-05 - accuracy: 1.0000 - val_loss: 4.9108e-05 - val_accuracy: 1.0000
# Epoch 66/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 5.0061e-05 - accuracy: 1.0000 - val_loss: 4.4589e-05 - val_accuracy: 1.0000
# Epoch 67/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 4.5686e-05 - accuracy: 1.0000 - val_loss: 4.0344e-05 - val_accuracy: 1.0000
# Epoch 68/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 4.2498e-05 - accuracy: 1.0000 - val_loss: 3.8161e-05 - val_accuracy: 1.0000
# Epoch 69/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 3.9455e-05 - accuracy: 1.0000 - val_loss: 3.5379e-05 - val_accuracy: 1.0000
# Epoch 70/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 3.6195e-05 - accuracy: 1.0000 - val_loss: 3.1234e-05 - val_accuracy: 1.0000
# Epoch 71/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 3.1704e-05 - accuracy: 1.0000 - val_loss: 3.7154e-05 - val_accuracy: 1.0000
# Epoch 72/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 3.0462e-05 - accuracy: 1.0000 - val_loss: 2.6083e-05 - val_accuracy: 1.0000
# Epoch 73/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 2.6895e-05 - accuracy: 1.0000 - val_loss: 2.4161e-05 - val_accuracy: 1.0000
# Epoch 74/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 2.4862e-05 - accuracy: 1.0000 - val_loss: 2.2067e-05 - val_accuracy: 1.0000
# Epoch 75/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 2.2723e-05 - accuracy: 1.0000 - val_loss: 2.0190e-05 - val_accuracy: 1.0000
# Epoch 76/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 2.0783e-05 - accuracy: 1.0000 - val_loss: 1.9118e-05 - val_accuracy: 1.0000
# Epoch 77/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.9065e-05 - accuracy: 1.0000 - val_loss: 1.8192e-05 - val_accuracy: 1.0000
# Epoch 78/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 1.8194e-05 - accuracy: 1.0000 - val_loss: 1.5978e-05 - val_accuracy: 1.0000
# Epoch 79/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.7010e-05 - accuracy: 1.0000 - val_loss: 1.4578e-05 - val_accuracy: 1.0000
# Epoch 80/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.5177e-05 - accuracy: 1.0000 - val_loss: 1.4766e-05 - val_accuracy: 1.0000
# Epoch 81/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.4388e-05 - accuracy: 1.0000 - val_loss: 1.3922e-05 - val_accuracy: 1.0000
# Epoch 82/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.2917e-05 - accuracy: 1.0000 - val_loss: 1.1673e-05 - val_accuracy: 1.0000
# Epoch 83/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 1.2000e-05 - accuracy: 1.0000 - val_loss: 1.0937e-05 - val_accuracy: 1.0000
# Epoch 84/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.1248e-05 - accuracy: 1.0000 - val_loss: 1.0157e-05 - val_accuracy: 1.0000
# Epoch 85/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 1.0045e-05 - accuracy: 1.0000 - val_loss: 8.9503e-06 - val_accuracy: 1.0000
# Epoch 86/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 9.5444e-06 - accuracy: 1.0000 - val_loss: 8.3080e-06 - val_accuracy: 1.0000
# Epoch 87/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 8.9752e-06 - accuracy: 1.0000 - val_loss: 7.5005e-06 - val_accuracy: 1.0000
# Epoch 88/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 7.8869e-06 - accuracy: 1.0000 - val_loss: 6.9934e-06 - val_accuracy: 1.0000
# Epoch 89/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 7.1673e-06 - accuracy: 1.0000 - val_loss: 6.7387e-06 - val_accuracy: 1.0000
# Epoch 90/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 6.8455e-06 - accuracy: 1.0000 - val_loss: 5.9022e-06 - val_accuracy: 1.0000
# Epoch 91/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 6.1647e-06 - accuracy: 1.0000 - val_loss: 5.3748e-06 - val_accuracy: 1.0000
# Epoch 92/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 5.5961e-06 - accuracy: 1.0000 - val_loss: 4.9458e-06 - val_accuracy: 1.0000
# Epoch 93/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 5.1507e-06 - accuracy: 1.0000 - val_loss: 4.5201e-06 - val_accuracy: 1.0000
# Epoch 94/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 4.8024e-06 - accuracy: 1.0000 - val_loss: 4.4869e-06 - val_accuracy: 1.0000
# Epoch 95/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 4.5240e-06 - accuracy: 1.0000 - val_loss: 3.7381e-06 - val_accuracy: 1.0000
# Epoch 96/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 3.9069e-06 - accuracy: 1.0000 - val_loss: 3.8273e-06 - val_accuracy: 1.0000
# Epoch 97/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 3.6638e-06 - accuracy: 1.0000 - val_loss: 3.2175e-06 - val_accuracy: 1.0000
# Epoch 98/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 3.3094e-06 - accuracy: 1.0000 - val_loss: 3.5817e-06 - val_accuracy: 1.0000
# Epoch 99/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 3.1712e-06 - accuracy: 1.0000 - val_loss: 3.2285e-06 - val_accuracy: 1.0000
# Epoch 100/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 2.9321e-06 - accuracy: 1.0000 - val_loss: 2.7482e-06 - val_accuracy: 1.0000
# test_avg_loss: 0.209, test_avg_acc: 0.968,
#
#  input train and test X shape is (9401, 102, 102, 5), (1045, 102, 102, 5)
# MultiClassEstimator(batch_size=64, epochs=100, gpuid='4', lr=0.001,
#                     metric='ACC', verbose=1)
# Train on 9401 samples, validate on 9401 samples
# Epoch 1/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 1.8644 - accuracy: 0.5040 - val_loss: 0.8743 - val_accuracy: 0.7265
# Epoch 2/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.6101 - accuracy: 0.8249 - val_loss: 0.5070 - val_accuracy: 0.8385
# Epoch 3/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.3937 - accuracy: 0.8843 - val_loss: 0.3260 - val_accuracy: 0.9099
# Epoch 4/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.2963 - accuracy: 0.9095 - val_loss: 0.2727 - val_accuracy: 0.9188
# Epoch 5/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.2606 - accuracy: 0.9192 - val_loss: 0.2587 - val_accuracy: 0.9206
# Epoch 6/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.2243 - accuracy: 0.9267 - val_loss: 0.1918 - val_accuracy: 0.9378
# Epoch 7/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1992 - accuracy: 0.9338 - val_loss: 0.1526 - val_accuracy: 0.9484
# Epoch 8/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1944 - accuracy: 0.9359 - val_loss: 0.1885 - val_accuracy: 0.9361
# Epoch 9/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1768 - accuracy: 0.9415 - val_loss: 0.1281 - val_accuracy: 0.9582
# Epoch 10/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1516 - accuracy: 0.9492 - val_loss: 0.1472 - val_accuracy: 0.9451
# Epoch 11/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1427 - accuracy: 0.9486 - val_loss: 0.1260 - val_accuracy: 0.9578
# Epoch 12/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.1452 - accuracy: 0.9510 - val_loss: 0.1409 - val_accuracy: 0.9488
# Epoch 13/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1324 - accuracy: 0.9551 - val_loss: 0.1027 - val_accuracy: 0.9634
# Epoch 14/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1206 - accuracy: 0.9559 - val_loss: 0.1440 - val_accuracy: 0.9473
# Epoch 15/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.1123 - accuracy: 0.9582 - val_loss: 0.1138 - val_accuracy: 0.9559
# Epoch 16/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0995 - accuracy: 0.9650 - val_loss: 0.1713 - val_accuracy: 0.9446
# Epoch 17/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0999 - accuracy: 0.9651 - val_loss: 0.0907 - val_accuracy: 0.9697
# Epoch 18/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0900 - accuracy: 0.9676 - val_loss: 0.0821 - val_accuracy: 0.9693
# Epoch 19/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0863 - accuracy: 0.9668 - val_loss: 0.1062 - val_accuracy: 0.9636
# Epoch 20/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0844 - accuracy: 0.9685 - val_loss: 0.0983 - val_accuracy: 0.9642
# Epoch 21/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0749 - accuracy: 0.9697 - val_loss: 0.0514 - val_accuracy: 0.9821
# Epoch 22/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0627 - accuracy: 0.9771 - val_loss: 0.0582 - val_accuracy: 0.9799
# Epoch 23/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0739 - accuracy: 0.9733 - val_loss: 0.0577 - val_accuracy: 0.9767
# Epoch 24/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0722 - accuracy: 0.9732 - val_loss: 0.0614 - val_accuracy: 0.9772
# Epoch 25/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0668 - accuracy: 0.9762 - val_loss: 0.0808 - val_accuracy: 0.9688
# Epoch 26/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0547 - accuracy: 0.9806 - val_loss: 0.0363 - val_accuracy: 0.9880
# Epoch 27/100
# 9401/9401 [==============================] - 26s 3ms/sample - loss: 0.0478 - accuracy: 0.9827 - val_loss: 0.0475 - val_accuracy: 0.9812
# Epoch 28/100
# 9401/9401 [==============================] - 19s 2ms/sample - loss: 0.0489 - accuracy: 0.9811 - val_loss: 0.0779 - val_accuracy: 0.9746
# Epoch 29/100
# 9401/9401 [==============================] - 19s 2ms/sample - loss: 0.0447 - accuracy: 0.9843 - val_loss: 0.0429 - val_accuracy: 0.9822
# Epoch 30/100
# 9401/9401 [==============================] - 19s 2ms/sample - loss: 0.0471 - accuracy: 0.9840 - val_loss: 0.0340 - val_accuracy: 0.9883
# Epoch 31/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0445 - accuracy: 0.9831 - val_loss: 0.0281 - val_accuracy: 0.9923
# Epoch 32/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0434 - accuracy: 0.9850 - val_loss: 0.0247 - val_accuracy: 0.9932
# Epoch 33/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0370 - accuracy: 0.9864 - val_loss: 0.0327 - val_accuracy: 0.9870
# Epoch 34/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0328 - accuracy: 0.9870 - val_loss: 0.0262 - val_accuracy: 0.9904
# Epoch 35/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0207 - accuracy: 0.9935 - val_loss: 0.0210 - val_accuracy: 0.9928
# Epoch 36/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0363 - accuracy: 0.9877 - val_loss: 0.0132 - val_accuracy: 0.9972
# Epoch 37/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0233 - accuracy: 0.9922 - val_loss: 0.0227 - val_accuracy: 0.9898
# Epoch 38/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0256 - accuracy: 0.9914 - val_loss: 0.0615 - val_accuracy: 0.9807
# Epoch 39/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0507 - accuracy: 0.9816 - val_loss: 0.0580 - val_accuracy: 0.9774
# Epoch 40/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0241 - accuracy: 0.9915 - val_loss: 0.0430 - val_accuracy: 0.9862
# Epoch 41/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0218 - accuracy: 0.9928 - val_loss: 0.0189 - val_accuracy: 0.9928
# Epoch 42/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0196 - accuracy: 0.9929 - val_loss: 0.0373 - val_accuracy: 0.9836
# Epoch 43/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0269 - accuracy: 0.9904 - val_loss: 0.0359 - val_accuracy: 0.9868
# Epoch 44/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0160 - accuracy: 0.9946 - val_loss: 0.0118 - val_accuracy: 0.9972
# Epoch 45/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0262 - accuracy: 0.9905 - val_loss: 0.0187 - val_accuracy: 0.9938
# Epoch 46/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0195 - accuracy: 0.9933 - val_loss: 0.0144 - val_accuracy: 0.9949
# Epoch 47/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0152 - accuracy: 0.9950 - val_loss: 0.0198 - val_accuracy: 0.9929
# Epoch 48/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0275 - accuracy: 0.9896 - val_loss: 0.0217 - val_accuracy: 0.9922
# Epoch 49/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0203 - accuracy: 0.9927 - val_loss: 0.0675 - val_accuracy: 0.9774
# Epoch 50/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0307 - accuracy: 0.9894 - val_loss: 0.0071 - val_accuracy: 0.9983
# Epoch 51/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0039 - val_accuracy: 0.9991
# Epoch 52/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 0.0030 - accuracy: 0.9991 - val_loss: 8.1094e-04 - val_accuracy: 1.0000
# Epoch 53/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 6.7507e-04 - accuracy: 1.0000 - val_loss: 4.6445e-04 - val_accuracy: 1.0000
# Epoch 54/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 3.7549e-04 - accuracy: 1.0000 - val_loss: 2.7373e-04 - val_accuracy: 1.0000
# Epoch 55/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0033 - val_accuracy: 0.9997
# Epoch 56/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.0065 - val_accuracy: 0.9974
# Epoch 57/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0650 - accuracy: 0.9787 - val_loss: 0.0285 - val_accuracy: 0.9895
# Epoch 58/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 0.0440 - accuracy: 0.9847 - val_loss: 0.0389 - val_accuracy: 0.9883
# Epoch 59/100
# 9401/9401 [==============================] - 20s 2ms/sample - loss: 0.0211 - accuracy: 0.9933 - val_loss: 0.0076 - val_accuracy: 0.9981
# Epoch 60/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0087 - accuracy: 0.9971 - val_loss: 0.0058 - val_accuracy: 0.9982
# Epoch 61/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0202 - accuracy: 0.9934 - val_loss: 0.0510 - val_accuracy: 0.9856
# Epoch 62/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 0.0123 - accuracy: 0.9955 - val_loss: 0.0059 - val_accuracy: 0.9984
# Epoch 63/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 0.0106 - accuracy: 0.9969 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 64/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.0018 - val_accuracy: 0.9995
# Epoch 65/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 3.0828e-04 - accuracy: 1.0000 - val_loss: 1.5493e-04 - val_accuracy: 1.0000
# Epoch 66/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 1.3453e-04 - accuracy: 1.0000 - val_loss: 1.0628e-04 - val_accuracy: 1.0000
# Epoch 67/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 9.7894e-05 - accuracy: 1.0000 - val_loss: 8.9191e-05 - val_accuracy: 1.0000
# Epoch 68/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 8.3541e-05 - accuracy: 1.0000 - val_loss: 7.1787e-05 - val_accuracy: 1.0000
# Epoch 69/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 7.1133e-05 - accuracy: 1.0000 - val_loss: 6.3822e-05 - val_accuracy: 1.0000
# Epoch 70/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 6.2051e-05 - accuracy: 1.0000 - val_loss: 5.8082e-05 - val_accuracy: 1.0000
# Epoch 71/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 5.5590e-05 - accuracy: 1.0000 - val_loss: 5.1121e-05 - val_accuracy: 1.0000
# Epoch 72/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 5.0416e-05 - accuracy: 1.0000 - val_loss: 4.5610e-05 - val_accuracy: 1.0000
# Epoch 73/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 4.5268e-05 - accuracy: 1.0000 - val_loss: 4.0894e-05 - val_accuracy: 1.0000
# Epoch 74/100
# 9401/9401 [==============================] - 24s 3ms/sample - loss: 4.0863e-05 - accuracy: 1.0000 - val_loss: 3.7446e-05 - val_accuracy: 1.0000
# Epoch 75/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 3.7685e-05 - accuracy: 1.0000 - val_loss: 3.4106e-05 - val_accuracy: 1.0000
# Epoch 76/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 3.3989e-05 - accuracy: 1.0000 - val_loss: 3.1015e-05 - val_accuracy: 1.0000
# Epoch 77/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 3.1412e-05 - accuracy: 1.0000 - val_loss: 2.8673e-05 - val_accuracy: 1.0000
# Epoch 78/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 2.8482e-05 - accuracy: 1.0000 - val_loss: 2.6080e-05 - val_accuracy: 1.0000
# Epoch 79/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 2.6081e-05 - accuracy: 1.0000 - val_loss: 2.4422e-05 - val_accuracy: 1.0000
# Epoch 80/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 2.4135e-05 - accuracy: 1.0000 - val_loss: 2.2023e-05 - val_accuracy: 1.0000
# Epoch 81/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 2.2526e-05 - accuracy: 1.0000 - val_loss: 2.0117e-05 - val_accuracy: 1.0000
# Epoch 82/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 2.0839e-05 - accuracy: 1.0000 - val_loss: 1.8693e-05 - val_accuracy: 1.0000
# Epoch 83/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.8985e-05 - accuracy: 1.0000 - val_loss: 1.7686e-05 - val_accuracy: 1.0000
# Epoch 84/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 1.7594e-05 - accuracy: 1.0000 - val_loss: 1.5994e-05 - val_accuracy: 1.0000
# Epoch 85/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 1.6491e-05 - accuracy: 1.0000 - val_loss: 1.4965e-05 - val_accuracy: 1.0000
# Epoch 86/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.5238e-05 - accuracy: 1.0000 - val_loss: 1.3878e-05 - val_accuracy: 1.0000
# Epoch 87/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 1.3975e-05 - accuracy: 1.0000 - val_loss: 1.2662e-05 - val_accuracy: 1.0000
# Epoch 88/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 1.3062e-05 - accuracy: 1.0000 - val_loss: 1.1871e-05 - val_accuracy: 1.0000
# Epoch 89/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 1.2075e-05 - accuracy: 1.0000 - val_loss: 1.1066e-05 - val_accuracy: 1.0000
# Epoch 90/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 1.1234e-05 - accuracy: 1.0000 - val_loss: 1.0237e-05 - val_accuracy: 1.0000
# Epoch 91/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 1.0467e-05 - accuracy: 1.0000 - val_loss: 9.4503e-06 - val_accuracy: 1.0000
# Epoch 92/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 9.8087e-06 - accuracy: 1.0000 - val_loss: 9.0560e-06 - val_accuracy: 1.0000
# Epoch 93/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 9.0417e-06 - accuracy: 1.0000 - val_loss: 8.3066e-06 - val_accuracy: 1.0000
# Epoch 94/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 8.3316e-06 - accuracy: 1.0000 - val_loss: 7.9153e-06 - val_accuracy: 1.0000
# Epoch 95/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 7.7823e-06 - accuracy: 1.0000 - val_loss: 7.1217e-06 - val_accuracy: 1.0000
# Epoch 96/100
# 9401/9401 [==============================] - 27s 3ms/sample - loss: 7.1512e-06 - accuracy: 1.0000 - val_loss: 6.6975e-06 - val_accuracy: 1.0000
# Epoch 97/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 6.7772e-06 - accuracy: 1.0000 - val_loss: 6.0872e-06 - val_accuracy: 1.0000
# Epoch 98/100
# 9401/9401 [==============================] - 21s 2ms/sample - loss: 6.2738e-06 - accuracy: 1.0000 - val_loss: 5.5979e-06 - val_accuracy: 1.0000
# Epoch 99/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 5.8416e-06 - accuracy: 1.0000 - val_loss: 5.3672e-06 - val_accuracy: 1.0000
# Epoch 100/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 5.3608e-06 - accuracy: 1.0000 - val_loss: 5.0670e-06 - val_accuracy: 1.0000
# test_avg_loss: 0.338, test_avg_acc: 0.957,
#
#  input train and test X shape is (9401, 102, 102, 5), (1045, 102, 102, 5)
# MultiClassEstimator(batch_size=64, epochs=100, gpuid='4', lr=0.001,
#                     metric='ACC', verbose=1)
# Train on 9401 samples, validate on 9401 samples
# Epoch 1/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 1.9155 - accuracy: 0.4745 - val_loss: 0.9746 - val_accuracy: 0.6872
# Epoch 2/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.7075 - accuracy: 0.7969 - val_loss: 0.4722 - val_accuracy: 0.8693
# Epoch 3/100
# 9401/9401 [==============================] - 22s 2ms/sample - loss: 0.4391 - accuracy: 0.8678 - val_loss: 0.3571 - val_accuracy: 0.9005
# Epoch 4/100
# 9401/9401 [==============================] - 24s 3ms/sample - loss: 0.3438 - accuracy: 0.8984 - val_loss: 0.2714 - val_accuracy: 0.9138
# Epoch 5/100
# 9401/9401 [==============================] - 24s 3ms/sample - loss: 0.2783 - accuracy: 0.9148 - val_loss: 0.3665 - val_accuracy: 0.8680
# Epoch 6/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 0.2485 - accuracy: 0.9192 - val_loss: 0.2002 - val_accuracy: 0.9331
# Epoch 7/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 0.2076 - accuracy: 0.9335 - val_loss: 0.1545 - val_accuracy: 0.9498
# Epoch 8/100
# 9401/9401 [==============================] - 23s 2ms/sample - loss: 0.1921 - accuracy: 0.9393 - val_loss: 0.1544 - val_accuracy: 0.9511
# Epoch 9/100
# ...
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 3.3427e-06 - accuracy: 1.0000 - val_loss: 3.0172e-06 - val_accuracy: 1.0000
# Epoch 99/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 3.1298e-06 - accuracy: 1.0000 - val_loss: 2.8553e-06 - val_accuracy: 1.0000
# Epoch 100/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 2.9176e-06 - accuracy: 1.0000 - val_loss: 2.6791e-06 - val_accuracy: 1.0000
# test_avg_loss: 0.351, test_avg_acc: 0.957,
#
#  input train and test X shape is (9402, 102, 102, 5), (1044, 102, 102, 5)
# MultiClassEstimator(batch_size=64, epochs=100, gpuid='4', lr=0.001,
#                     metric='ACC', verbose=1)
# Train on 9402 samples, validate on 9402 samples
# Epoch 1/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 1.9983 - accuracy: 0.4646 - val_loss: 1.1076 - val_accuracy: 0.6912
# Epoch 2/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.7161 - accuracy: 0.7864 - val_loss: 0.5588 - val_accuracy: 0.8297
# Epoch 3/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.4336 - accuracy: 0.8692 - val_loss: 0.3364 - val_accuracy: 0.8976
# Epoch 4/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.3474 - accuracy: 0.8954 - val_loss: 0.2674 - val_accuracy: 0.9144
# Epoch 5/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.2743 - accuracy: 0.9144 - val_loss: 0.2358 - val_accuracy: 0.9294
# Epoch 6/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.2333 - accuracy: 0.9245 - val_loss: 0.2293 - val_accuracy: 0.9378
# Epoch 7/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.2083 - accuracy: 0.9359 - val_loss: 0.2041 - val_accuracy: 0.9298
# Epoch 8/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.1938 - accuracy: 0.9340 - val_loss: 0.1876 - val_accuracy: 0.9330
# Epoch 9/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.1770 - accuracy: 0.9419 - val_loss: 0.1562 - val_accuracy: 0.9472
# Epoch 10/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.1612 - accuracy: 0.9456 - val_loss: 0.1483 - val_accuracy: 0.9472
# Epoch 11/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.1514 - accuracy: 0.9469 - val_loss: 0.1672 - val_accuracy: 0.9408
# Epoch 12/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.1391 - accuracy: 0.9513 - val_loss: 0.1290 - val_accuracy: 0.9530
# Epoch 13/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.1345 - accuracy: 0.9517 - val_loss: 0.1539 - val_accuracy: 0.9441
# Epoch 14/100
# 9402/9402 [==============================] - 20s 2ms/sample - loss: 0.1271 - accuracy: 0.9527 - val_loss: 0.1196 - val_accuracy: 0.9589
# Epoch 15/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.1125 - accuracy: 0.9594 - val_loss: 0.1062 - val_accuracy: 0.9622
# Epoch 16/100
# 9402/9402 [==============================] - 12s 1ms/sample - loss: 0.1089 - accuracy: 0.9608 - val_loss: 0.1110 - val_accuracy: 0.9609
# Epoch 17/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.1016 - accuracy: 0.9618 - val_loss: 0.0831 - val_accuracy: 0.9692
# Epoch 18/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.0939 - accuracy: 0.9646 - val_loss: 0.0816 - val_accuracy: 0.9668
# Epoch 19/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.1007 - accuracy: 0.9627 - val_loss: 0.1456 - val_accuracy: 0.9478
# Epoch 20/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0881 - accuracy: 0.9676 - val_loss: 0.0569 - val_accuracy: 0.9788
# Epoch 21/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.0812 - accuracy: 0.9692 - val_loss: 0.0586 - val_accuracy: 0.9799
# Epoch 22/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.0749 - accuracy: 0.9714 - val_loss: 0.0494 - val_accuracy: 0.9854
# Epoch 23/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.0803 - accuracy: 0.9711 - val_loss: 0.0882 - val_accuracy: 0.9675
# Epoch 24/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.0705 - accuracy: 0.9746 - val_loss: 0.0523 - val_accuracy: 0.9803
# Epoch 25/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0649 - accuracy: 0.9745 - val_loss: 0.0893 - val_accuracy: 0.9705
# Epoch 26/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.0645 - accuracy: 0.9767 - val_loss: 0.0533 - val_accuracy: 0.9818
# Epoch 27/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.0585 - accuracy: 0.9773 - val_loss: 0.0445 - val_accuracy: 0.9867
# Epoch 28/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0473 - accuracy: 0.9820 - val_loss: 0.0365 - val_accuracy: 0.9847
# Epoch 29/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.0375 - accuracy: 0.9852 - val_loss: 0.0274 - val_accuracy: 0.9911
# Epoch 30/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0360 - accuracy: 0.9874 - val_loss: 0.0280 - val_accuracy: 0.9910
# Epoch 31/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0403 - accuracy: 0.9872 - val_loss: 0.0352 - val_accuracy: 0.9885
# Epoch 32/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0470 - accuracy: 0.9820 - val_loss: 0.0298 - val_accuracy: 0.9913
# Epoch 33/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0344 - accuracy: 0.9869 - val_loss: 0.0232 - val_accuracy: 0.9939
# Epoch 34/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0302 - accuracy: 0.9888 - val_loss: 0.0259 - val_accuracy: 0.9883
# Epoch 35/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.0225 - accuracy: 0.9929 - val_loss: 0.0141 - val_accuracy: 0.9971
# Epoch 36/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0199 - accuracy: 0.9936 - val_loss: 0.0206 - val_accuracy: 0.9926
# Epoch 37/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0371 - accuracy: 0.9867 - val_loss: 0.0218 - val_accuracy: 0.9930
# Epoch 38/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0490 - accuracy: 0.9832 - val_loss: 0.0681 - val_accuracy: 0.9718
# Epoch 39/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0356 - accuracy: 0.9884 - val_loss: 0.0146 - val_accuracy: 0.9950
# Epoch 40/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0140 - accuracy: 0.9964 - val_loss: 0.0058 - val_accuracy: 0.9988
# Epoch 41/100
# 9402/9402 [==============================] - 18s 2ms/sample - loss: 0.0171 - accuracy: 0.9942 - val_loss: 0.0059 - val_accuracy: 0.9991
# Epoch 42/100
# 9402/9402 [==============================] - 12s 1ms/sample - loss: 0.0175 - accuracy: 0.9937 - val_loss: 0.0354 - val_accuracy: 0.9883
# Epoch 43/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0254 - accuracy: 0.9902 - val_loss: 0.0383 - val_accuracy: 0.9878
# Epoch 44/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0298 - accuracy: 0.9912 - val_loss: 0.0299 - val_accuracy: 0.9928
# Epoch 45/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.0168 - accuracy: 0.9952 - val_loss: 0.0126 - val_accuracy: 0.9963
# Epoch 46/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0234 - accuracy: 0.9920 - val_loss: 0.0111 - val_accuracy: 0.9962
# Epoch 47/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0305 - accuracy: 0.9899 - val_loss: 0.0112 - val_accuracy: 0.9967
# Epoch 48/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0278 - accuracy: 0.9913 - val_loss: 0.0195 - val_accuracy: 0.9931
# Epoch 49/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.0173 - accuracy: 0.9940 - val_loss: 0.0258 - val_accuracy: 0.9896
# Epoch 50/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.0052 - val_accuracy: 0.9978
# Epoch 51/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.0044 - val_accuracy: 0.9994
# Epoch 52/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0150 - accuracy: 0.9950 - val_loss: 0.0079 - val_accuracy: 0.9976
# Epoch 53/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0045 - val_accuracy: 0.9988
# Epoch 54/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0065 - val_accuracy: 0.9984
# Epoch 55/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.0307 - val_accuracy: 0.9890
# Epoch 56/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0161 - accuracy: 0.9942 - val_loss: 0.0277 - val_accuracy: 0.9907
# Epoch 57/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0471 - accuracy: 0.9827 - val_loss: 0.0215 - val_accuracy: 0.9926
# Epoch 58/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0229 - accuracy: 0.9918 - val_loss: 0.0329 - val_accuracy: 0.9898
# Epoch 59/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 0.0209 - accuracy: 0.9924 - val_loss: 0.0037 - val_accuracy: 0.9991
# Epoch 60/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0012 - val_accuracy: 0.9999
# Epoch 61/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 7.8543e-04 - accuracy: 0.9998 - val_loss: 2.7127e-04 - val_accuracy: 1.0000
# Epoch 62/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 2.6395e-04 - accuracy: 1.0000 - val_loss: 1.7097e-04 - val_accuracy: 1.0000
# Epoch 63/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 1.5392e-04 - accuracy: 1.0000 - val_loss: 1.2478e-04 - val_accuracy: 1.0000
# Epoch 64/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 1.2301e-04 - accuracy: 1.0000 - val_loss: 1.0409e-04 - val_accuracy: 1.0000
# Epoch 65/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 1.0329e-04 - accuracy: 1.0000 - val_loss: 8.9911e-05 - val_accuracy: 1.0000
# Epoch 66/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 8.8572e-05 - accuracy: 1.0000 - val_loss: 7.7270e-05 - val_accuracy: 1.0000
# Epoch 67/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 7.7587e-05 - accuracy: 1.0000 - val_loss: 6.9085e-05 - val_accuracy: 1.0000
# Epoch 68/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 6.9204e-05 - accuracy: 1.0000 - val_loss: 6.1301e-05 - val_accuracy: 1.0000
# Epoch 69/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 6.1340e-05 - accuracy: 1.0000 - val_loss: 5.5719e-05 - val_accuracy: 1.0000
# Epoch 70/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 5.5372e-05 - accuracy: 1.0000 - val_loss: 5.0019e-05 - val_accuracy: 1.0000
# Epoch 71/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 5.0262e-05 - accuracy: 1.0000 - val_loss: 4.6251e-05 - val_accuracy: 1.0000
# Epoch 72/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 4.5237e-05 - accuracy: 1.0000 - val_loss: 4.0925e-05 - val_accuracy: 1.0000
# Epoch 73/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 4.1531e-05 - accuracy: 1.0000 - val_loss: 3.8167e-05 - val_accuracy: 1.0000
# Epoch 74/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 3.8334e-05 - accuracy: 1.0000 - val_loss: 3.4550e-05 - val_accuracy: 1.0000
# Epoch 75/100
# 9402/9402 [==============================] - 19s 2ms/sample - loss: 3.4866e-05 - accuracy: 1.0000 - val_loss: 3.1810e-05 - val_accuracy: 1.0000
# Epoch 76/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 3.2512e-05 - accuracy: 1.0000 - val_loss: 2.9198e-05 - val_accuracy: 1.0000
# Epoch 77/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 3.0041e-05 - accuracy: 1.0000 - val_loss: 2.7173e-05 - val_accuracy: 1.0000
# Epoch 78/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 2.7512e-05 - accuracy: 1.0000 - val_loss: 2.5873e-05 - val_accuracy: 1.0000
# Epoch 79/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 2.5557e-05 - accuracy: 1.0000 - val_loss: 2.2987e-05 - val_accuracy: 1.0000
# Epoch 80/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 2.3537e-05 - accuracy: 1.0000 - val_loss: 2.1584e-05 - val_accuracy: 1.0000
# Epoch 81/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 2.1869e-05 - accuracy: 1.0000 - val_loss: 1.9888e-05 - val_accuracy: 1.0000
# Epoch 82/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 2.0278e-05 - accuracy: 1.0000 - val_loss: 1.9175e-05 - val_accuracy: 1.0000
# Epoch 83/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 1.8892e-05 - accuracy: 1.0000 - val_loss: 1.6911e-05 - val_accuracy: 1.0000
# Epoch 84/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 1.7365e-05 - accuracy: 1.0000 - val_loss: 1.6163e-05 - val_accuracy: 1.0000
# Epoch 85/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 1.6035e-05 - accuracy: 1.0000 - val_loss: 1.4853e-05 - val_accuracy: 1.0000
# Epoch 86/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 1.5183e-05 - accuracy: 1.0000 - val_loss: 1.3804e-05 - val_accuracy: 1.0000
# Epoch 87/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 1.3790e-05 - accuracy: 1.0000 - val_loss: 1.2824e-05 - val_accuracy: 1.0000
# Epoch 88/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 1.2916e-05 - accuracy: 1.0000 - val_loss: 1.2380e-05 - val_accuracy: 1.0000
# Epoch 89/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 1.2140e-05 - accuracy: 1.0000 - val_loss: 1.0923e-05 - val_accuracy: 1.0000
# Epoch 90/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 1.1195e-05 - accuracy: 1.0000 - val_loss: 1.0363e-05 - val_accuracy: 1.0000
# Epoch 91/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 1.0336e-05 - accuracy: 1.0000 - val_loss: 9.7592e-06 - val_accuracy: 1.0000
# Epoch 92/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 9.6893e-06 - accuracy: 1.0000 - val_loss: 9.2080e-06 - val_accuracy: 1.0000
# Epoch 93/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 9.0623e-06 - accuracy: 1.0000 - val_loss: 8.1457e-06 - val_accuracy: 1.0000
# Epoch 94/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 8.3125e-06 - accuracy: 1.0000 - val_loss: 7.9198e-06 - val_accuracy: 1.0000
# Epoch 95/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 7.7733e-06 - accuracy: 1.0000 - val_loss: 7.0353e-06 - val_accuracy: 1.0000
# Epoch 96/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 7.1526e-06 - accuracy: 1.0000 - val_loss: 6.6365e-06 - val_accuracy: 1.0000
# Epoch 97/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 6.8369e-06 - accuracy: 1.0000 - val_loss: 6.0956e-06 - val_accuracy: 1.0000
# Epoch 98/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 6.2253e-06 - accuracy: 1.0000 - val_loss: 5.9757e-06 - val_accuracy: 1.0000
# Epoch 99/100
# 9402/9402 [==============================] - 15s 2ms/sample - loss: 5.8863e-06 - accuracy: 1.0000 - val_loss: 5.3806e-06 - val_accuracy: 1.0000
# Epoch 100/100
# 9402/9402 [==============================] - 16s 2ms/sample - loss: 5.4928e-06 - accuracy: 1.0000 - val_loss: 4.9060e-06 - val_accuracy: 1.0000
# test_avg_loss: 0.234, test_avg_acc: 0.975,

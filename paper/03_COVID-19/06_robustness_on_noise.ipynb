# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Aug 16 17:10:53 2020

@author: wanxiang.shen@u.nus.edu
"""

import warnings,os
warnings.filterwarnings("ignore")


import pandas as pd
import numpy as np

from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import auc as calculate_auc

import matplotlib.pyplot as plt
import seaborn as sns
from joblib import load, dump

from aggmap import AggMap, AggModel, loadmap
from aggmap import show
np.random.seed(666) #just for reaptable results


from tqdm import tqdm

tqdm.pandas(ascii=True)

color = sns.color_palette("rainbow_r", 6) #PiYG
sns.palplot(color)

# %%
dfx  = pd.read_excel('./COVID19.xlsx', sheet_name='data')
dfy  = pd.read_excel('./COVID19.xlsx', sheet_name='sample_info')
mp = loadmap('./saved_model/aggmap.mp')

scale_method = 'standard'


dfx = dfx[dfx.columns[1:]]
cols = ["p-%s" % c for c in dfx.columns]
dfx.columns = cols


Y = pd.get_dummies(dfy['class']).values.astype(float)

# %%
data_save_folder = '/raid/shenwanxiang/COVID-19/COV-C'
X_noisys_5 = load(os.path.join(data_save_folder, 'Agg5_noisys.data')) 
X_noisys_1 = load(os.path.join(data_save_folder, 'Agg1_noisys.data'))

# %%
X_clean_5 = X_noisys_5[0] # the first one is the clean set that used for training
X_clean_1 = X_noisys_1[0] # the first one is the clean set that used for training

# %% [markdown]
# ## single channel

# %%
n_splits = 5 #5-fold reapeat 5 times

run_all = []

stddevs = np.arange(0, 0.5, 0.08)

for repeat_seed in [8, 16, 32, 64, 128]: #repeats random seeds
    outer = KFold(n_splits = n_splits, shuffle = True, random_state = repeat_seed)
    outer_idx = list(outer.split(range(len(Y))))

    for i, idx in enumerate(outer_idx):

        train_idx, valid_idx = idx
        fold_num = "fold_%s" % str(i+1).zfill(2) 

        ## clean set to train
        trainX = X_clean_1[train_idx]
        validX = X_clean_1[valid_idx]
        
        trainY = Y[train_idx]
        validY = Y[valid_idx]
        
        
        print("\n input train and test X shape is %s, %s " % (trainX.shape,  validX.shape))
        clf = AggModel.MultiClassEstimator(epochs = 50, 
                                           batch_size = 4,
                                           verbose = 0, gpuid=2)
        clf.fit(trainX, trainY, validX, validY)
        
        for X, std in zip(X_noisys_1, stddevs): 
             ## noise set to valid
            TestX = X[valid_idx]
            TestY = Y[valid_idx]
            loss, acc = clf._model.evaluate(TestX, TestY, verbose=0)
            res = {'fold_num':fold_num, 'repeat_seed':repeat_seed, 'std':std, 'acc':acc, 'loss':loss}
            print(res)
            run_all.append(res)
# Out:
#  input train and test X shape is (289, 10, 9, 1), (73, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.0, 'acc': 0.9726027, 'loss': 0.056679780352605534}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.08, 'acc': 0.9726027, 'loss': 0.08222468421883779}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.16, 'acc': 0.89041096, 'loss': 0.2881857352714016}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.24, 'acc': 0.7671233, 'loss': 0.6910792507537423}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.32, 'acc': 0.6849315, 'loss': 1.052782176292106}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.4, 'acc': 0.60273975, 'loss': 1.4129714214638487}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.48, 'acc': 0.6164383, 'loss': 1.7690476718014234}
#
#  input train and test X shape is (289, 10, 9, 1), (73, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.0, 'acc': 0.91780823, 'loss': 0.17213016916831878}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.08, 'acc': 0.9589041, 'loss': 0.13091603901288282}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.16, 'acc': 0.91780823, 'loss': 0.21875364853911203}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.24, 'acc': 0.79452056, 'loss': 0.4477025221471917}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.32, 'acc': 0.739726, 'loss': 0.7227445816340512}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.4, 'acc': 0.6849315, 'loss': 0.9695397174521668}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.48, 'acc': 0.6438356, 'loss': 1.1916976464937812}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.0, 'acc': 0.875, 'loss': 0.33204323053359985}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.08, 'acc': 0.875, 'loss': 0.32421162393358016}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.16, 'acc': 0.8194444, 'loss': 0.42835455470614964}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.24, 'acc': 0.7361111, 'loss': 0.5715389781528049}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.32, 'acc': 0.75, 'loss': 0.7594036261240641}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.4, 'acc': 0.6944444, 'loss': 0.9517983595530192}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.48, 'acc': 0.6666667, 'loss': 1.113120396931966}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.0, 'acc': 0.9305556, 'loss': 0.22620046966605717}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.08, 'acc': 0.9166667, 'loss': 0.2859700719515483}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.16, 'acc': 0.875, 'loss': 0.4209805594550239}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.24, 'acc': 0.8194444, 'loss': 0.6053368846575419}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.32, 'acc': 0.7083333, 'loss': 0.8246493140856425}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.4, 'acc': 0.625, 'loss': 1.0905470583173964}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.48, 'acc': 0.5694444, 'loss': 1.4211538831392925}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.0, 'acc': 0.9722222, 'loss': 0.08374186439646615}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.08, 'acc': 0.9027778, 'loss': 0.176387467318111}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.16, 'acc': 0.8333333, 'loss': 0.38620036509301925}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.24, 'acc': 0.75, 'loss': 0.6518950329886543}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.32, 'acc': 0.7222222, 'loss': 0.9497039318084717}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.4, 'acc': 0.6805556, 'loss': 1.2521641121970282}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.48, 'acc': 0.5972222, 'loss': 1.511092530356513}
#
#  input train and test X shape is (289, 10, 9, 1), (73, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.0, 'acc': 0.9315069, 'loss': 0.15055057079824682}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.08, 'acc': 0.94520545, 'loss': 0.16911125428056065}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.16, 'acc': 0.8767123, 'loss': 0.3259868948426965}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.24, 'acc': 0.75342464, 'loss': 0.6436712970472362}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.32, 'acc': 0.7123288, 'loss': 1.004799290879132}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.4, 'acc': 0.6712329, 'loss': 1.3857708401875952}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.48, 'acc': 0.6712329, 'loss': 1.7093305032547206}
#
#  input train and test X shape is (289, 10, 9, 1), (73, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.0, 'acc': 0.9315069, 'loss': 0.18705087491910752}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.08, 'acc': 0.89041096, 'loss': 0.2667714104260484}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.16, 'acc': 0.84931505, 'loss': 0.5339889461047029}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.24, 'acc': 0.69863015, 'loss': 0.8238768544915605}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.32, 'acc': 0.6712329, 'loss': 1.1035686519047985}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.4, 'acc': 0.6438356, 'loss': 1.300499435973494}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.48, 'acc': 0.6438356, 'loss': 1.4618777118317068}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.0, 'acc': 0.9722222, 'loss': 0.06876793007055919}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.08, 'acc': 0.9444444, 'loss': 0.17080812321768868}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.16, 'acc': 0.875, 'loss': 0.37182627783881295}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.24, 'acc': 0.7638889, 'loss': 0.6557882825533549}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.32, 'acc': 0.6666667, 'loss': 1.0176232655843098}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.4, 'acc': 0.625, 'loss': 1.4121642377641466}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.48, 'acc': 0.5277778, 'loss': 1.8090791437360976}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.0, 'acc': 0.8333333, 'loss': 0.36001067029105294}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.08, 'acc': 0.8194444, 'loss': 0.40199416213565403}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.16, 'acc': 0.7361111, 'loss': 0.5313606195979648}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.24, 'acc': 0.625, 'loss': 0.7276360392570496}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.32, 'acc': 0.5833333, 'loss': 0.955365326669481}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.4, 'acc': 0.5277778, 'loss': 1.215138806237115}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.48, 'acc': 0.5138889, 'loss': 1.4455056852764554}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.0, 'acc': 0.9583333, 'loss': 0.1744977699385749}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.08, 'acc': 0.9583333, 'loss': 0.22408278617593977}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.16, 'acc': 0.9166667, 'loss': 0.3074123329586453}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.24, 'acc': 0.8333333, 'loss': 0.4189096573326323}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.32, 'acc': 0.75, 'loss': 0.5540291435188718}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.4, 'acc': 0.7222222, 'loss': 0.6909245186381869}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.48, 'acc': 0.6944444, 'loss': 0.8180985119607713}
#
#  input train and test X shape is (289, 10, 9, 1), (73, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.0, 'acc': 0.8630137, 'loss': 0.3416507750341337}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.08, 'acc': 0.8767123, 'loss': 0.33641821064361155}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.16, 'acc': 0.8356164, 'loss': 0.4208359620342516}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.24, 'acc': 0.75342464, 'loss': 0.5620181568681377}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.32, 'acc': 0.69863015, 'loss': 0.7123725789867036}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.4, 'acc': 0.65753424, 'loss': 0.8814216754207872}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.48, 'acc': 0.56164384, 'loss': 1.0565930996855644}
#
#  input train and test X shape is (289, 10, 9, 1), (73, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.0, 'acc': 0.98630136, 'loss': 0.0225614264403304}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.08, 'acc': 0.98630136, 'loss': 0.06547229236935916}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.16, 'acc': 0.8630137, 'loss': 0.3597954866820819}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.24, 'acc': 0.7671233, 'loss': 1.0153265619931156}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.32, 'acc': 0.72602737, 'loss': 1.621515790077105}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.4, 'acc': 0.7123288, 'loss': 2.0827904531400496}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.48, 'acc': 0.6849315, 'loss': 2.418063167023332}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.0, 'acc': 0.9305556, 'loss': 0.22924286789364284}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.08, 'acc': 0.9027778, 'loss': 0.27722127238909405}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.16, 'acc': 0.8194444, 'loss': 0.43842701117197674}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.24, 'acc': 0.7083333, 'loss': 0.6533874207072787}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.32, 'acc': 0.6111111, 'loss': 0.8655169871118333}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.4, 'acc': 0.5694444, 'loss': 1.0748730765448675}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.48, 'acc': 0.5416667, 'loss': 1.2607998583051894}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.0, 'acc': 0.9305556, 'loss': 0.13186341689692604}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.08, 'acc': 0.9583333, 'loss': 0.15864975916014779}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.16, 'acc': 0.9027778, 'loss': 0.3046991063488854}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.24, 'acc': 0.8194444, 'loss': 0.5620952579710219}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.32, 'acc': 0.7916667, 'loss': 0.8837976985507541}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.4, 'acc': 0.7222222, 'loss': 1.266794787512885}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.48, 'acc': 0.7222222, 'loss': 1.6363641950819228}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.0, 'acc': 0.9444444, 'loss': 0.16556892957952288}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.08, 'acc': 0.9166667, 'loss': 0.2337739368279775}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.16, 'acc': 0.875, 'loss': 0.34440558155377704}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.24, 'acc': 0.7777778, 'loss': 0.4855622483624352}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.32, 'acc': 0.75, 'loss': 0.6462051537301805}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.4, 'acc': 0.6527778, 'loss': 0.860468692249722}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.48, 'acc': 0.5972222, 'loss': 1.0945568184057872}
#
#  input train and test X shape is (289, 10, 9, 1), (73, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.0, 'acc': 0.94520545, 'loss': 0.18233493832896833}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.08, 'acc': 0.94520545, 'loss': 0.18235923579498514}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.16, 'acc': 0.8767123, 'loss': 0.2980364058932213}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.24, 'acc': 0.739726, 'loss': 0.5328079609021749}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.32, 'acc': 0.7123288, 'loss': 0.8103049691409281}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.4, 'acc': 0.69863015, 'loss': 1.0610888755484804}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.48, 'acc': 0.6164383, 'loss': 1.2876370443056708}
#
#  input train and test X shape is (289, 10, 9, 1), (73, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.0, 'acc': 0.94520545, 'loss': 0.11589281873343742}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.08, 'acc': 0.9041096, 'loss': 0.2742567922766895}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.16, 'acc': 0.8356164, 'loss': 0.5596303091677901}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.24, 'acc': 0.75342464, 'loss': 0.8919434416783999}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.32, 'acc': 0.7123288, 'loss': 1.2192466348817903}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.4, 'acc': 0.6849315, 'loss': 1.5791409840322521}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.48, 'acc': 0.63013697, 'loss': 1.9910864364610958}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.0, 'acc': 0.8888889, 'loss': 0.27064622773064506}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.08, 'acc': 0.875, 'loss': 0.28245435158411664}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.16, 'acc': 0.8333333, 'loss': 0.39390454689661664}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.24, 'acc': 0.7638889, 'loss': 0.6302289035585191}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.32, 'acc': 0.7083333, 'loss': 0.9411943223741319}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.4, 'acc': 0.6388889, 'loss': 1.3066670099894206}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.48, 'acc': 0.6111111, 'loss': 1.6545950041876898}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.0, 'acc': 0.9722222, 'loss': 0.09094959704412355}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.08, 'acc': 0.9583333, 'loss': 0.09201430115434858}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.16, 'acc': 0.8472222, 'loss': 0.280410024854872}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.24, 'acc': 0.7638889, 'loss': 0.6408443186018202}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.32, 'acc': 0.6944444, 'loss': 1.1293002367019653}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.4, 'acc': 0.6388889, 'loss': 1.721352842119005}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.48, 'acc': 0.6527778, 'loss': 2.310520807902018}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.0, 'acc': 0.9444444, 'loss': 0.20966456333796182}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.08, 'acc': 0.8888889, 'loss': 0.279702623685201}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.16, 'acc': 0.8333333, 'loss': 0.48223700126012164}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.24, 'acc': 0.8194444, 'loss': 0.7434959146711562}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.32, 'acc': 0.7083333, 'loss': 0.9832973082860311}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.4, 'acc': 0.625, 'loss': 1.235197385152181}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.48, 'acc': 0.5555556, 'loss': 1.4754039181603327}
#
#  input train and test X shape is (289, 10, 9, 1), (73, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.0, 'acc': 0.8630137, 'loss': 0.27775718088019385}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.08, 'acc': 0.9041096, 'loss': 0.27637728028101466}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.16, 'acc': 0.82191783, 'loss': 0.38402715447830826}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.24, 'acc': 0.7808219, 'loss': 0.5000039535026027}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.32, 'acc': 0.739726, 'loss': 0.5998673275725482}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.4, 'acc': 0.7123288, 'loss': 0.6990162918012436}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.48, 'acc': 0.6849315, 'loss': 0.7741497036528914}
#
#  input train and test X shape is (289, 10, 9, 1), (73, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.0, 'acc': 0.91780823, 'loss': 0.1533009654855075}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.08, 'acc': 0.9041096, 'loss': 0.24354393188267537}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.16, 'acc': 0.82191783, 'loss': 0.4692660390514217}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.24, 'acc': 0.739726, 'loss': 0.7763428345118484}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.32, 'acc': 0.69863015, 'loss': 1.1265768645560905}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.4, 'acc': 0.65753424, 'loss': 1.4643327112067235}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.48, 'acc': 0.5753425, 'loss': 1.797998604709155}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.0, 'acc': 0.9166667, 'loss': 0.1259404569864273}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.08, 'acc': 0.9583333, 'loss': 0.09352871858411366}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.16, 'acc': 0.9305556, 'loss': 0.153107564482424}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.24, 'acc': 0.8194444, 'loss': 0.36318088074525195}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.32, 'acc': 0.6944444, 'loss': 0.6662652393182119}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.4, 'acc': 0.6805556, 'loss': 0.9548856814702352}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.48, 'acc': 0.6388889, 'loss': 1.218657049867842}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.0, 'acc': 0.9583333, 'loss': 0.1296087536546919}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.08, 'acc': 0.9027778, 'loss': 0.2334283987681071}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.16, 'acc': 0.8472222, 'loss': 0.4151735305786133}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.24, 'acc': 0.7638889, 'loss': 0.6565128962198893}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.32, 'acc': 0.7222222, 'loss': 0.9227944215138754}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.4, 'acc': 0.6944444, 'loss': 1.1738457679748535}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.48, 'acc': 0.7222222, 'loss': 1.3612153795030382}
#
#  input train and test X shape is (290, 10, 9, 1), (72, 10, 9, 1)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.0, 'acc': 0.9722222, 'loss': 0.11102950241830614}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.08, 'acc': 0.9722222, 'loss': 0.15653865701622433}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.16, 'acc': 0.8333333, 'loss': 0.35940855410363937}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.24, 'acc': 0.7361111, 'loss': 0.7879565623071458}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.32, 'acc': 0.6666667, 'loss': 1.2968456612692938}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.4, 'acc': 0.5555556, 'loss': 1.8555201159583197}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.48, 'acc': 0.5277778, 'loss': 2.39644185702006}

# %%
df1 = pd.DataFrame(run_all)

# %%
df1.groupby('std').mean()
# Out:
#       repeat_seed       acc      loss
# std
# 0.00         49.6  0.930959  0.174787
# 0.08         49.6  0.921507  0.216729
# 0.16         49.6  0.854673  0.379057
# 0.24         49.6  0.761918  0.641566
# 0.32         49.6  0.704947  0.934791
# 0.40         49.6  0.655152  1.235957
# 0.48         49.6  0.618706  1.519363

# %% [markdown]
# ## multi-channel

# %%
n_splits = 5 #5-fold reapeat 5 times
run_all_5 = []

for repeat_seed in [8, 16, 32, 64, 128]: #repeats random seeds
    outer = KFold(n_splits = n_splits, shuffle = True, random_state = repeat_seed)
    outer_idx = list(outer.split(range(len(Y))))

    for i, idx in enumerate(outer_idx):

        train_idx, valid_idx = idx
        fold_num = "fold_%s" % str(i+1).zfill(2) 

        ## clean set to train
        trainX = X_clean_5[train_idx]
        validX = X_clean_5[valid_idx]
        
        trainY = Y[train_idx]
        validY = Y[valid_idx]

        print("\n input train and test X shape is %s, %s " % (trainX.shape,  validX.shape))
        clf = AggModel.MultiClassEstimator(epochs = 50,
                                           batch_size = 4,
                                           verbose = 0, gpuid=2)
        clf.fit(trainX, trainY, validX, validY)
        
        for X, std in zip(X_noisys_5, stddevs): 
             ## noise set to valid
            TestX = X[valid_idx]
            TestY = Y[valid_idx]
            loss, acc = clf._model.evaluate(TestX, TestY, verbose=0)
            res = {'fold_num':fold_num, 'repeat_seed':repeat_seed, 'std':std, 'acc':acc, 'loss':loss}
            print(res)
            run_all_5.append(res)
# Out:
#  input train and test X shape is (289, 10, 9, 5), (73, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.0, 'acc': 0.94520545, 'loss': 0.11625060826948244}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.08, 'acc': 0.9589041, 'loss': 0.13956762217495539}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.16, 'acc': 0.82191783, 'loss': 0.4495305990519589}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.24, 'acc': 0.739726, 'loss': 0.9942153577935205}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.32, 'acc': 0.65753424, 'loss': 1.582890321130622}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.4, 'acc': 0.6438356, 'loss': 2.1917784801901203}
# {'fold_num': 'fold_01', 'repeat_seed': 8, 'std': 0.48, 'acc': 0.5890411, 'loss': 2.742942359349499}
#
#  input train and test X shape is (289, 10, 9, 5), (73, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.0, 'acc': 0.9589041, 'loss': 0.11992714002932588}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.08, 'acc': 0.9589041, 'loss': 0.1351089402012629}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.16, 'acc': 0.8630137, 'loss': 0.27901125770725616}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.24, 'acc': 0.75342464, 'loss': 0.5543349422004125}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.32, 'acc': 0.6849315, 'loss': 0.8881371041683301}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.4, 'acc': 0.6438356, 'loss': 1.232416084367935}
# {'fold_num': 'fold_02', 'repeat_seed': 8, 'std': 0.48, 'acc': 0.5753425, 'loss': 1.5446959693137914}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.0, 'acc': 0.9166667, 'loss': 0.2449786431259579}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.08, 'acc': 0.8888889, 'loss': 0.24859091308381823}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.16, 'acc': 0.8333333, 'loss': 0.3448478612634871}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.24, 'acc': 0.7361111, 'loss': 0.5499089492691888}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.32, 'acc': 0.7083333, 'loss': 0.7802492578824362}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.4, 'acc': 0.6944444, 'loss': 0.9811142285664877}
# {'fold_num': 'fold_03', 'repeat_seed': 8, 'std': 0.48, 'acc': 0.6944444, 'loss': 1.170816765891181}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.0, 'acc': 0.9444444, 'loss': 0.15793670382764605}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.08, 'acc': 0.9305556, 'loss': 0.17714645796351963}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.16, 'acc': 0.8611111, 'loss': 0.3210112022029029}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.24, 'acc': 0.7083333, 'loss': 0.6514265967739953}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.32, 'acc': 0.5833333, 'loss': 1.1167904535929363}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.4, 'acc': 0.5277778, 'loss': 1.6344985564549763}
# {'fold_num': 'fold_04', 'repeat_seed': 8, 'std': 0.48, 'acc': 0.4861111, 'loss': 2.141913096110026}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.0, 'acc': 0.9861111, 'loss': 0.03940177087982496}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.08, 'acc': 0.9305556, 'loss': 0.13107889973455006}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.16, 'acc': 0.875, 'loss': 0.4185474051369561}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.24, 'acc': 0.75, 'loss': 1.1308968596988254}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.32, 'acc': 0.625, 'loss': 2.029405885272556}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.4, 'acc': 0.5555556, 'loss': 3.031661139594184}
# {'fold_num': 'fold_05', 'repeat_seed': 8, 'std': 0.48, 'acc': 0.4861111, 'loss': 4.108718342251247}
#
#  input train and test X shape is (289, 10, 9, 5), (73, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.0, 'acc': 0.9589041, 'loss': 0.1401729798072005}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.08, 'acc': 0.94520545, 'loss': 0.12982722443260558}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.16, 'acc': 0.89041096, 'loss': 0.26723805518999494}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.24, 'acc': 0.7671233, 'loss': 0.6488410544722047}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.32, 'acc': 0.72602737, 'loss': 1.1530144769851476}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.4, 'acc': 0.6438356, 'loss': 1.6877258607785997}
# {'fold_num': 'fold_01', 'repeat_seed': 16, 'std': 0.48, 'acc': 0.6164383, 'loss': 2.2131882236428457}
#
#  input train and test X shape is (289, 10, 9, 5), (73, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.0, 'acc': 0.9589041, 'loss': 0.12757855408812221}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.08, 'acc': 0.9315069, 'loss': 0.14647770581180103}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.16, 'acc': 0.89041096, 'loss': 0.2153708767401029}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.24, 'acc': 0.82191783, 'loss': 0.42717729365988955}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.32, 'acc': 0.7671233, 'loss': 0.7424295413984011}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.4, 'acc': 0.72602737, 'loss': 1.1003283833804196}
# {'fold_num': 'fold_02', 'repeat_seed': 16, 'std': 0.48, 'acc': 0.6849315, 'loss': 1.4632517997532675}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.0, 'acc': 0.9722222, 'loss': 0.059307638141844005}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.08, 'acc': 0.9444444, 'loss': 0.13240572727388805}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.16, 'acc': 0.8194444, 'loss': 0.4510636329650879}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.24, 'acc': 0.7222222, 'loss': 0.9948969417148166}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.32, 'acc': 0.5972222, 'loss': 1.5608314010832045}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.4, 'acc': 0.5694444, 'loss': 2.150917265150282}
# {'fold_num': 'fold_03', 'repeat_seed': 16, 'std': 0.48, 'acc': 0.5555556, 'loss': 2.678231530719333}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.0, 'acc': 0.8611111, 'loss': 0.289980196290546}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.08, 'acc': 0.875, 'loss': 0.2696760694185893}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.16, 'acc': 0.7916667, 'loss': 0.4232090910275777}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.24, 'acc': 0.7083333, 'loss': 0.7504040267732408}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.32, 'acc': 0.625, 'loss': 1.13722825050354}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.4, 'acc': 0.5416667, 'loss': 1.5447928508122761}
# {'fold_num': 'fold_04', 'repeat_seed': 16, 'std': 0.48, 'acc': 0.5, 'loss': 1.943100048436059}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.0, 'acc': 0.9583333, 'loss': 0.09907946383787526}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.08, 'acc': 0.9444444, 'loss': 0.14026608069737753}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.16, 'acc': 0.875, 'loss': 0.2943334033091863}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.24, 'acc': 0.7222222, 'loss': 0.6810535391171774}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.32, 'acc': 0.6388889, 'loss': 1.176739467514886}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.4, 'acc': 0.625, 'loss': 1.69523376888699}
# {'fold_num': 'fold_05', 'repeat_seed': 16, 'std': 0.48, 'acc': 0.5555556, 'loss': 2.1613553365071616}
#
#  input train and test X shape is (289, 10, 9, 5), (73, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.0, 'acc': 0.8767123, 'loss': 0.28032214674231126}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.08, 'acc': 0.8767123, 'loss': 0.2678242472753133}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.16, 'acc': 0.79452056, 'loss': 0.4035200737927058}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.24, 'acc': 0.7671233, 'loss': 0.5948337136882625}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.32, 'acc': 0.75342464, 'loss': 0.8576369195768277}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.4, 'acc': 0.63013697, 'loss': 1.2148498884619099}
# {'fold_num': 'fold_01', 'repeat_seed': 32, 'std': 0.48, 'acc': 0.5890411, 'loss': 1.610889490336588}
#
#  input train and test X shape is (289, 10, 9, 5), (73, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.0, 'acc': 0.98630136, 'loss': 0.024217712884284044}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.08, 'acc': 0.98630136, 'loss': 0.04862252328136604}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.16, 'acc': 0.9041096, 'loss': 0.23303405797644838}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.24, 'acc': 0.79452056, 'loss': 0.7846024387503323}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.32, 'acc': 0.6164383, 'loss': 1.633057568171253}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.4, 'acc': 0.53424656, 'loss': 2.5529742567506557}
# {'fold_num': 'fold_02', 'repeat_seed': 32, 'std': 0.48, 'acc': 0.49315068, 'loss': 3.420128293233375}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.0, 'acc': 0.9722222, 'loss': 0.15492236324482495}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.08, 'acc': 0.9166667, 'loss': 0.2309812241130405}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.16, 'acc': 0.8333333, 'loss': 0.4603825310866038}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.24, 'acc': 0.6944444, 'loss': 0.9450159205330743}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.32, 'acc': 0.5972222, 'loss': 1.5172097815407648}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.4, 'acc': 0.625, 'loss': 2.0857143667009144}
# {'fold_num': 'fold_03', 'repeat_seed': 32, 'std': 0.48, 'acc': 0.5555556, 'loss': 2.6750222312079535}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.0, 'acc': 0.9722222, 'loss': 0.07092723747094472}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.08, 'acc': 0.9583333, 'loss': 0.11292288700739543}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.16, 'acc': 0.8333333, 'loss': 0.33056962490081787}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.24, 'acc': 0.7083333, 'loss': 0.92643227842119}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.32, 'acc': 0.6527778, 'loss': 1.7482795715332031}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.4, 'acc': 0.5972222, 'loss': 2.607551919089423}
# {'fold_num': 'fold_04', 'repeat_seed': 32, 'std': 0.48, 'acc': 0.5555556, 'loss': 3.344787703620063}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.0, 'acc': 0.9444444, 'loss': 0.1461255339284738}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.08, 'acc': 0.9166667, 'loss': 0.169551819562912}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.16, 'acc': 0.8194444, 'loss': 0.36391110221544903}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.24, 'acc': 0.7083333, 'loss': 0.7084134088622199}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.32, 'acc': 0.6666667, 'loss': 1.122094710667928}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.4, 'acc': 0.6527778, 'loss': 1.535218702422248}
# {'fold_num': 'fold_05', 'repeat_seed': 32, 'std': 0.48, 'acc': 0.5972222, 'loss': 1.9173227813508775}
#
#  input train and test X shape is (289, 10, 9, 5), (73, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.0, 'acc': 0.94520545, 'loss': 0.16685355903759394}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.08, 'acc': 0.94520545, 'loss': 0.15594916224275548}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.16, 'acc': 0.82191783, 'loss': 0.33674707682165383}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.24, 'acc': 0.7123288, 'loss': 0.8238556809621315}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.32, 'acc': 0.6712329, 'loss': 1.3887028841123188}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.4, 'acc': 0.60273975, 'loss': 1.9840027142877448}
# {'fold_num': 'fold_01', 'repeat_seed': 64, 'std': 0.48, 'acc': 0.6164383, 'loss': 2.545614049859243}
#
#  input train and test X shape is (289, 10, 9, 5), (73, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.0, 'acc': 0.9315069, 'loss': 0.10455849797350086}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.08, 'acc': 0.94520545, 'loss': 0.17493261871476695}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.16, 'acc': 0.84931505, 'loss': 0.39568778030472257}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.24, 'acc': 0.72602737, 'loss': 0.8759979481158191}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.32, 'acc': 0.69863015, 'loss': 1.4576998769420466}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.4, 'acc': 0.63013697, 'loss': 2.0833979355145806}
# {'fold_num': 'fold_02', 'repeat_seed': 64, 'std': 0.48, 'acc': 0.5479452, 'loss': 2.707713976298293}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.0, 'acc': 0.9166667, 'loss': 0.1989514728387197}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.08, 'acc': 0.9166667, 'loss': 0.20125309626261392}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.16, 'acc': 0.875, 'loss': 0.2793186439408196}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.24, 'acc': 0.8055556, 'loss': 0.4483070704672072}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.32, 'acc': 0.8055556, 'loss': 0.6861610346370273}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.4, 'acc': 0.7222222, 'loss': 0.9519179430272844}
# {'fold_num': 'fold_03', 'repeat_seed': 64, 'std': 0.48, 'acc': 0.6527778, 'loss': 1.232456299993727}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.0, 'acc': 0.9583333, 'loss': 0.11460551619529724}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.08, 'acc': 0.9444444, 'loss': 0.12382379505369398}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.16, 'acc': 0.8472222, 'loss': 0.34057875474294025}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.24, 'acc': 0.7222222, 'loss': 0.8809614976247152}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.32, 'acc': 0.625, 'loss': 1.5063990884357028}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.4, 'acc': 0.5555556, 'loss': 2.1834062735239663}
# {'fold_num': 'fold_04', 'repeat_seed': 64, 'std': 0.48, 'acc': 0.5138889, 'loss': 2.9624965720706515}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.0, 'acc': 0.9722222, 'loss': 0.09576790200339423}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.08, 'acc': 0.9444444, 'loss': 0.15471281939082676}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.16, 'acc': 0.8472222, 'loss': 0.38253453705045914}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.24, 'acc': 0.7638889, 'loss': 0.8497450881534152}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.32, 'acc': 0.5972222, 'loss': 1.4252883063422308}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.4, 'acc': 0.5138889, 'loss': 2.0401808155907526}
# {'fold_num': 'fold_05', 'repeat_seed': 64, 'std': 0.48, 'acc': 0.44444445, 'loss': 2.615616242090861}
#
#  input train and test X shape is (289, 10, 9, 5), (73, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.0, 'acc': 0.91780823, 'loss': 0.1673179277001995}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.08, 'acc': 0.91780823, 'loss': 0.2119742558427053}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.16, 'acc': 0.7808219, 'loss': 0.372122246925145}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.24, 'acc': 0.6849315, 'loss': 0.6792764475900833}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.32, 'acc': 0.6164383, 'loss': 1.0461895629151228}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.4, 'acc': 0.56164384, 'loss': 1.413138265479101}
# {'fold_num': 'fold_01', 'repeat_seed': 128, 'std': 0.48, 'acc': 0.5479452, 'loss': 1.7656846993590054}
#
#  input train and test X shape is (289, 10, 9, 5), (73, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.0, 'acc': 0.9726027, 'loss': 0.08457934795177147}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.08, 'acc': 0.9041096, 'loss': 0.15323909504772865}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.16, 'acc': 0.8082192, 'loss': 0.5358565702830276}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.24, 'acc': 0.7123288, 'loss': 1.1659272794854152}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.32, 'acc': 0.63013697, 'loss': 1.8224453403525156}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.4, 'acc': 0.56164384, 'loss': 2.504781037160795}
# {'fold_num': 'fold_02', 'repeat_seed': 128, 'std': 0.48, 'acc': 0.5205479, 'loss': 3.186182289907377}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.0, 'acc': 0.9583333, 'loss': 0.13237752185927498}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.08, 'acc': 0.9444444, 'loss': 0.10192167510588963}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.16, 'acc': 0.9305556, 'loss': 0.1794632168279754}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.24, 'acc': 0.7638889, 'loss': 0.45550646384557086}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.32, 'acc': 0.6944444, 'loss': 0.8395112289322747}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.4, 'acc': 0.6527778, 'loss': 1.2530588706334431}
# {'fold_num': 'fold_03', 'repeat_seed': 128, 'std': 0.48, 'acc': 0.5833333, 'loss': 1.6255271169874403}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.0, 'acc': 0.9583333, 'loss': 0.06063351035118103}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.08, 'acc': 0.9583333, 'loss': 0.09662495056788127}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.16, 'acc': 0.875, 'loss': 0.25863395465744865}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.24, 'acc': 0.7777778, 'loss': 0.61500350634257}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.32, 'acc': 0.6944444, 'loss': 1.105421827899085}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.4, 'acc': 0.6527778, 'loss': 1.6311250527699788}
# {'fold_num': 'fold_04', 'repeat_seed': 128, 'std': 0.48, 'acc': 0.6388889, 'loss': 2.147420644760132}
#
#  input train and test X shape is (290, 10, 9, 5), (72, 10, 9, 5)
# {'epochs': 50, 'lr': 0.0001, 'conv1_kernel_size': 13, 'dense_layers': [128], 'dense_avf': 'relu', 'batch_size': 4, 'dropout': 0.0, 'batch_norm': False, 'n_inception': 2, 'monitor': 'val_loss', 'patience': 10000, 'random_state': 32, 'verbose': 0, 'name': 'AggMap MultiClass Estimator', 'gpuid': '2'}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.0, 'acc': 0.9444444, 'loss': 0.10542382465468512}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.08, 'acc': 0.9166667, 'loss': 0.1389564805560642}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.16, 'acc': 0.8333333, 'loss': 0.41052237153053284}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.24, 'acc': 0.75, 'loss': 0.8252812756432427}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.32, 'acc': 0.625, 'loss': 1.4272497163878546}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.4, 'acc': 0.6111111, 'loss': 2.0747177600860596}
# {'fold_num': 'fold_05', 'repeat_seed': 128, 'std': 0.48, 'acc': 0.5416667, 'loss': 2.6578390730751886}

# %%
df5 = pd.DataFrame(run_all_5)

# %%
df5.groupby(['std']).mean()
# Out:
#       repeat_seed       acc      loss
# std
# 0.00         49.6  0.947527  0.132088
# 0.08         49.6  0.932017  0.159737
# 0.16         49.6  0.846986  0.349882
# 0.24         49.6  0.740845  0.758493
# 0.32         49.6  0.662321  1.270043
# 0.40         49.6  0.611012  1.814660
# 0.48         49.6  0.565677  2.343317

# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
from aggmap import AggMap, AggMapNet
# Out:
# /home/shenwanxiang/anaconda3/envs/molmap/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/shenwanxiang/anaconda3/envs/molmap/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/shenwanxiang/anaconda3/envs/molmap/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/shenwanxiang/anaconda3/envs/molmap/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/shenwanxiang/anaconda3/envs/molmap/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/shenwanxiang/anaconda3/envs/molmap/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data() #

# %%
_, w, h = x_train.shape
orignal_cols = ['p-%s' % str((i+1)).zfill(len(str(w*h))) for i in range(w*h)]
x_train_df = pd.DataFrame(x_train.reshape(x_train.shape[0], w*h), columns = orignal_cols)
x_test_df = pd.DataFrame(x_test.reshape(x_test.shape[0], w*h), columns = orignal_cols)

# %%
shuffled_cols = shuffle(orignal_cols, random_state=888)
x_train_df_shuffled = x_train_df[shuffled_cols]
x_test_df_shuffled = x_test_df[shuffled_cols]

# %% [markdown]
# ## Step2: AggMap pre-fitting on training set

# %%
mp = AggMap(x_train_df_shuffled, metric='correlation')
mp = mp.fit(cluster_channels=1, var_thr=0, verbose=0, fmap_shape = (w, h))
# Out:
# 2021-10-06 12:21:21,067 - INFO - [bidd-aggmap] - Calculating distance ...
# 2021-10-06 12:21:21,096 - INFO - [bidd-aggmap] - the number of process is 16
# 100%|##########| 306936/306936 [01:04<00:00, 4724.79it/s]
# 100%|##########| 306936/306936 [00:00<00:00, 2714216.82it/s]
# 100%|##########| 784/784 [00:01<00:00, 433.26it/s]
# 2021-10-06 12:22:28,190 - INFO - [bidd-aggmap] - applying hierarchical clustering to obtain group information ...
# 2021-10-06 12:22:33,367 - INFO - [bidd-aggmap] - Applying grid feature map(assignment), this may take several minutes(1~30 min)
# 2021-10-06 12:22:34,066 - INFO - [bidd-aggmap] - Finished

# %% [markdown]
# ## Step3: AggMap transformation on training and test test

# %%
X = mp.batch_transform(x_train_df_shuffled.values)
testX = mp.batch_transform(x_test_df_shuffled.values)
# Out:
# 100%|##########| 60000/60000 [00:24<00:00, 2410.97it/s]
# 100%|##########| 10000/10000 [00:03<00:00, 2670.10it/s]

# %%
Y = pd.get_dummies(pd.Series(y_train)).values
testY = pd.get_dummies(pd.Series(y_test)).values
trainX, validX, trainY, validY = train_test_split(X, Y, test_size = 0.1, random_state = 888)

#select 10 samples for each class
gidx = pd.DataFrame(y_test).groupby(0).apply(lambda x:x.index.tolist()).apply(lambda x:x[:10]) 
gidx
# Out:
# 0
# 0           [3, 10, 13, 25, 28, 55, 69, 71, 101, 126]
# 1              [2, 5, 14, 29, 31, 37, 39, 40, 46, 57]
# 2           [1, 35, 38, 43, 47, 72, 77, 82, 106, 119]
# 3            [18, 30, 32, 44, 51, 63, 68, 76, 87, 90]
# 4              [4, 6, 19, 24, 27, 33, 42, 48, 49, 56]
# 5          [8, 15, 23, 45, 52, 53, 59, 102, 120, 127]
# 6            [11, 21, 22, 50, 54, 66, 81, 88, 91, 98]
# 7             [0, 17, 26, 34, 36, 41, 60, 64, 70, 75]
# 8    [61, 84, 110, 128, 134, 146, 177, 179, 181, 184]
# 9              [7, 9, 12, 16, 20, 58, 62, 73, 78, 92]
# dtype: object

# %%
def gauss_noisy(X, c = 0.36):
    ''' 
    X: 4D array, n,w,h,c
    '''
    np.random.seed(123)
    X = np.clip(X + np.random.normal(size = X.shape, scale = c), 0, 1) 
    return X
sigma = 0.36
testX = testX.reshape(-1, mp.fmap_shape[0], mp.fmap_shape[1], 1)
testX_noisy = gauss_noisy(testX, c = sigma)

fig, axes = plt.subplots(ncols=2)
ax1, ax2 = axes
ax1.imshow(testX[1].reshape(*mp.fmap_shape))
ax2.imshow(testX_noisy[1].reshape(*mp.fmap_shape))

# %% [markdown]
# ## Step4: Training AggMapNet

# %%
clf = AggMapNet.MultiClassEstimator(epochs = 50,  batch_size = 64, verbose=1,
                                    conv1_kernel_size = 3, dense_layers = [128, 64], 
                                    lr = 0.0001,  gpuid=0,)
clf.fit(trainX, trainY, validX, validY)
# Out:
# Epoch 1/50
# 844/844 [==============================] - 9s 7ms/step - loss: 1.1679 - accuracy: 0.6715 - val_loss: 0.1522 - val_accuracy: 0.9573
# Epoch 2/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.1453 - accuracy: 0.9562 - val_loss: 0.0941 - val_accuracy: 0.9732
# Epoch 3/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0975 - accuracy: 0.9694 - val_loss: 0.0928 - val_accuracy: 0.9717
# Epoch 4/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0787 - accuracy: 0.9751 - val_loss: 0.0685 - val_accuracy: 0.9807
# Epoch 5/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0645 - accuracy: 0.9792 - val_loss: 0.0735 - val_accuracy: 0.9765
# Epoch 6/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0587 - accuracy: 0.9813 - val_loss: 0.0682 - val_accuracy: 0.9793
# Epoch 7/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0481 - accuracy: 0.9845 - val_loss: 0.0521 - val_accuracy: 0.9847
# Epoch 8/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0483 - accuracy: 0.9851 - val_loss: 0.0490 - val_accuracy: 0.9868
# Epoch 9/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0440 - accuracy: 0.9852 - val_loss: 0.0564 - val_accuracy: 0.9840
# Epoch 10/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0383 - accuracy: 0.9874 - val_loss: 0.0460 - val_accuracy: 0.9867
# Epoch 11/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0352 - accuracy: 0.9884 - val_loss: 0.0469 - val_accuracy: 0.9865
# Epoch 12/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0332 - accuracy: 0.9898 - val_loss: 0.0500 - val_accuracy: 0.9848
# Epoch 13/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0294 - accuracy: 0.9909 - val_loss: 0.0492 - val_accuracy: 0.9863
# Epoch 14/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0282 - accuracy: 0.9907 - val_loss: 0.0397 - val_accuracy: 0.9887
# Epoch 15/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0239 - accuracy: 0.9915 - val_loss: 0.0436 - val_accuracy: 0.9867
# Epoch 16/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0221 - accuracy: 0.9932 - val_loss: 0.0400 - val_accuracy: 0.9893
# Epoch 17/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0200 - accuracy: 0.9935 - val_loss: 0.0408 - val_accuracy: 0.9897
# Epoch 18/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0191 - accuracy: 0.9943 - val_loss: 0.0406 - val_accuracy: 0.9897
# Epoch 19/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0190 - accuracy: 0.9935 - val_loss: 0.0360 - val_accuracy: 0.9912
# Epoch 20/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0164 - accuracy: 0.9947 - val_loss: 0.0474 - val_accuracy: 0.9865
# Epoch 21/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0163 - accuracy: 0.9946 - val_loss: 0.0362 - val_accuracy: 0.9910
# Epoch 22/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 0.0378 - val_accuracy: 0.9900
# Epoch 23/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.0330 - val_accuracy: 0.9923
# Epoch 24/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0106 - accuracy: 0.9969 - val_loss: 0.0430 - val_accuracy: 0.9888
# Epoch 25/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0116 - accuracy: 0.9958 - val_loss: 0.0478 - val_accuracy: 0.9875
# Epoch 26/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0112 - accuracy: 0.9964 - val_loss: 0.0405 - val_accuracy: 0.9897
# Epoch 27/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0075 - accuracy: 0.9981 - val_loss: 0.0341 - val_accuracy: 0.9925
# Epoch 28/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0357 - val_accuracy: 0.9917
# Epoch 29/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 0.0363 - val_accuracy: 0.9918
# Epoch 30/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0069 - accuracy: 0.9978 - val_loss: 0.0392 - val_accuracy: 0.9915
# Epoch 31/50
# 844/844 [==============================] - 5s 6ms/step - loss: 0.0107 - accuracy: 0.9965 - val_loss: 0.0422 - val_accuracy: 0.9910
# Epoch 32/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0466 - val_accuracy: 0.9888
# Epoch 33/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 0.0642 - val_accuracy: 0.9862
# Epoch 34/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.0407 - val_accuracy: 0.9910
# Epoch 35/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0044 - accuracy: 0.9986 - val_loss: 0.0377 - val_accuracy: 0.9913
# Epoch 36/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0420 - val_accuracy: 0.9905
# Epoch 37/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0034 - accuracy: 0.9989 - val_loss: 0.0434 - val_accuracy: 0.9905
# Epoch 38/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 0.0399 - val_accuracy: 0.9910
# Epoch 39/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0420 - val_accuracy: 0.9910
# Epoch 40/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0029 - accuracy: 0.9989 - val_loss: 0.0560 - val_accuracy: 0.9872
# Epoch 41/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0374 - val_accuracy: 0.9927
# Epoch 42/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0040 - accuracy: 0.9988 - val_loss: 0.0395 - val_accuracy: 0.9925
# Epoch 43/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0357 - val_accuracy: 0.9937
# Epoch 44/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0417 - val_accuracy: 0.9923
# Epoch 45/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.0507 - val_accuracy: 0.9898
# Epoch 46/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0429 - val_accuracy: 0.9917
# Epoch 47/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.0380 - val_accuracy: 0.9918
# Epoch 48/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0373 - val_accuracy: 0.9928
# Epoch 49/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0549 - val_accuracy: 0.9887
# Epoch 50/50
# 844/844 [==============================] - 6s 7ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.0428 - val_accuracy: 0.9923
# MultiClassEstimator(batch_norm=False, batch_size=64, conv1_kernel_size=3,
#                     dense_avf='relu', dense_layers=[128, 64], dropout=0.0,
#                     epochs=50, gpuid='0', last_avf='softmax',
#                     loss='categorical_crossentropy', lr=0.0001,
#                     monitor='val_loss', n_inception=2,
#                     name='AggMap MultiClass Estimator', patience=10000,
#                     random_state=32, verbose=1)

# %%
from scipy.stats import pearsonr
from skimage.metrics import structural_similarity as ssim
import seaborn as sns
sns.set(font_scale=1.5, style='white')
def change_width(ax, new_value) :
    for patch in ax.patches :
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)
        
def _hm(IMP, ax, cmap = 'rainbow',):
    PCM = ax.imshow(IMP, cmap = cmap, vmin=0)
    ax.set_xticks([]) 
    ax.set_yticks([])
    clb = plt.colorbar(PCM, ax = ax, shrink = 0.7, pad = 0.04,  orientation = 'horizontal') #format = '%.2f'

# %% [markdown]
# ## Nosiey-free, local

# %%
fig, axes = plt.subplots(nrows= 3, ncols= 10, figsize=(28, 10.5), sharex = False, sharey = False, gridspec_kw={'height_ratios': [1.4, 1.4, 1.4]})

pcc_ssim = []

for l, i in gidx.apply(lambda x:x[0]).items():

    ax1, ax2, ax3 = axes[:, l]
    
    simp_explainer = AggMapNet.simply_explainer(clf, mp, apply_logrithm=True)
    I1 = simp_explainer.local_explain(testX[[i]], testY[[i]])
    IMP = I1.simply_importance.values.reshape(*mp.fmap_shape)
    IMP[IMP < 0.5] = 0 # smaller than 0 is 0 for simply


    shap_explainer = AggMapNet.shapley_explainer(clf, mp)
    I2 = shap_explainer.local_explain(testX[[i]])
    IMP2 = I2['shapley_importance_class_%s' % l].values.reshape(*mp.fmap_shape)

    
    tr = testX[i].reshape(*mp.fmap_shape)
    
    S1 = ssim(tr / tr.max(), IMP/IMP.max(), full=True)
    S2 = ssim(tr / tr.max(), IMP2/IMP2.max(), full=True) #the full structural similarity image

    df1 = pd.Series(S1[1].reshape(w*h, )).to_frame(name = 'SSIM to Groudtruth')
    df1['data'] = 'Simp-Explain.'


    df2 = pd.Series(S2[1].reshape(w*h, )).to_frame(name = 'SSIM to Groudtruth')
    df2['data'] = 'Shap-Explain.'

    df = df1.append(df2)

    p1, v1 = pearsonr(tr.reshape(w*h,), IMP.reshape(w*h,))
    p2, v2 = pearsonr(tr.reshape(w*h,), IMP2.reshape(w*h,))

    _hm(tr, ax=ax1, cmap = 'gray',)
    _hm(IMP, ax=ax2, cmap = 'rainbow',)    
    _hm(IMP2, ax=ax3, cmap = 'rainbow',)

    if l == 0:
        ax1.set_ylabel('Ground\nTruth', fontdict={'fontsize':28})
        ax2.set_ylabel('Simp-\nExplain.', fontdict={'fontsize':28})
        ax3.set_ylabel('Shap-\nExplain.', fontdict={'fontsize':28})
        #ax4.set_ylabel('SSIM to GroudTruth')
    plt.tight_layout()

    pcc_ssim.append([l, p1, p2, S1[0], S2[0]])
    
    
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.035, hspace=None)
fig.savefig('./free-local.svg', bbox_inches='tight', dpi=400)
# Out:
# 100%|##########| 784/784 [00:00<00:00, 9070.92it/s]
# 100%|##########| 1/1 [00:00<00:00,  4.57it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 655.97it/s]
#
#   0%|          | 0/2434 [00:00<?, ?it/s]
#   0%|          | 12/2434 [00:00<00:21, 114.17it/s]
#   1%|          | 24/2434 [00:00<00:22, 107.14it/s]
#   8%|7         | 192/2434 [00:00<00:03, 703.69it/s]
#  16%|#6        | 392/2434 [00:00<00:01, 1091.69it/s]
#  33%|###2      | 800/2434 [00:00<00:00, 1973.48it/s]
#  50%|####9     | 1208/2434 [00:00<00:00, 1766.89it/s]
#  61%|######    | 1480/2434 [00:01<00:00, 1706.04it/s]
#  72%|#######1  | 1752/2434 [00:01<00:00, 1642.29it/s]
#  79%|#######8  | 1921/2434 [00:01<00:00, 1523.25it/s]
#  89%|########8 | 2160/2434 [00:01<00:00, 1470.93it/s]
# 100%|##########| 2434/2434 [00:01<00:00, 1438.00it/s]
# 100%|##########| 784/784 [00:00<00:00, 8969.94it/s]
# 100%|##########| 1/1 [00:00<00:00, 1455.85it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 644.88it/s]
#
#   0%|          | 0/2176 [00:00<?, ?it/s]
#   1%|1         | 32/2176 [00:00<00:08, 265.15it/s]
#   3%|2         | 59/2176 [00:00<00:09, 230.48it/s]
#   7%|7         | 160/2176 [00:00<00:03, 518.43it/s]
#  18%|#8        | 392/2176 [00:00<00:01, 1100.17it/s]
#  31%|###       | 672/2176 [00:00<00:00, 1562.34it/s]
#  56%|#####5    | 1208/2176 [00:00<00:00, 2706.09it/s]
# 100%|##########| 2176/2176 [00:00<00:00, 2215.73it/s]
# 100%|##########| 784/784 [00:00<00:00, 9135.33it/s]
# 100%|##########| 1/1 [00:00<00:00, 1210.83it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 1332.79it/s]
#
#   0%|          | 0/2378 [00:00<?, ?it/s]
#   1%|1         | 32/2378 [00:00<00:08, 277.20it/s]
#   3%|2         | 60/2378 [00:00<00:09, 232.19it/s]
#   6%|6         | 144/2378 [00:00<00:04, 456.62it/s]
#  15%|#4        | 349/2378 [00:00<00:01, 1019.89it/s]
#  26%|##5       | 616/2378 [00:00<00:01, 1568.69it/s]
#  44%|####4     | 1056/2378 [00:00<00:00, 2383.33it/s]
#  71%|#######1  | 1696/2378 [00:00<00:00, 2762.20it/s]
# 100%|##########| 2378/2378 [00:01<00:00, 2177.90it/s]
# 100%|##########| 784/784 [00:00<00:00, 9222.46it/s]
# 100%|##########| 1/1 [00:00<00:00, 90.76it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 1540.32it/s]
#
#   0%|          | 0/2468 [00:00<?, ?it/s]
#   1%|          | 24/2468 [00:00<00:10, 228.25it/s]
#   2%|1         | 47/2468 [00:00<00:12, 195.20it/s]
#   5%|5         | 128/2468 [00:00<00:05, 410.09it/s]
#  14%|#4        | 352/2468 [00:00<00:02, 997.64it/s]
#  30%|##9       | 736/2468 [00:00<00:00, 1779.55it/s]
#  55%|#####4    | 1352/2468 [00:00<00:00, 3082.16it/s]
#  80%|#######9  | 1968/2468 [00:00<00:00, 3041.01it/s]
# 100%|##########| 2468/2468 [00:01<00:00, 2400.83it/s]
# 100%|##########| 784/784 [00:00<00:00, 9329.61it/s]
# 100%|##########| 1/1 [00:00<00:00, 1526.31it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 577.65it/s]
#
#   0%|          | 0/2288 [00:00<?, ?it/s]
#   1%|1         | 24/2288 [00:00<00:09, 239.15it/s]
#   2%|2         | 48/2288 [00:00<00:11, 190.43it/s]
#   7%|7         | 168/2288 [00:00<00:03, 562.76it/s]
#  16%|#5        | 366/2288 [00:00<00:01, 1014.75it/s]
#  33%|###2      | 748/2288 [00:00<00:00, 1885.57it/s]
#  62%|######1   | 1408/2288 [00:00<00:00, 3188.51it/s]
#  76%|#######5  | 1730/2288 [00:00<00:00, 3017.82it/s]
# 100%|##########| 2288/2288 [00:01<00:00, 2277.28it/s]
# 100%|##########| 784/784 [00:00<00:00, 9157.41it/s]
# 100%|##########| 1/1 [00:00<00:00, 1438.87it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 885.81it/s]
#
#   0%|          | 0/2396 [00:00<?, ?it/s]
#   1%|1         | 32/2396 [00:00<00:07, 308.13it/s]
#   3%|2         | 63/2396 [00:00<00:08, 263.45it/s]
#   6%|6         | 144/2396 [00:00<00:04, 470.59it/s]
#  14%|#4        | 336/2396 [00:00<00:02, 960.91it/s]
#  26%|##5       | 616/2396 [00:00<00:01, 1469.16it/s]
#  47%|####7     | 1136/2396 [00:00<00:00, 2562.58it/s]
#  67%|######6   | 1600/2396 [00:00<00:00, 2798.23it/s]
# 100%|##########| 2396/2396 [00:01<00:00, 2296.51it/s]
# 100%|##########| 784/784 [00:00<00:00, 9008.74it/s]
# 100%|##########| 1/1 [00:00<00:00, 848.02it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 1488.40it/s]
#
#   0%|          | 0/2392 [00:00<?, ?it/s]
#   1%|1         | 32/2392 [00:00<00:08, 281.19it/s]
#   3%|2         | 61/2392 [00:00<00:09, 258.87it/s]
#   9%|8         | 204/2392 [00:00<00:03, 724.29it/s]
#  22%|##1       | 516/2392 [00:00<00:01, 1596.37it/s]
#  40%|####      | 964/2392 [00:00<00:00, 2574.43it/s]
#  62%|######2   | 1492/2392 [00:00<00:00, 3459.48it/s]
#  77%|#######7  | 1848/2392 [00:00<00:00, 3156.11it/s]
# 100%|##########| 2392/2392 [00:00<00:00, 2467.81it/s]
# 100%|##########| 784/784 [00:00<00:00, 8910.10it/s]
# 100%|##########| 1/1 [00:00<00:00, 1511.46it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 1611.33it/s]
#
#   0%|          | 0/2280 [00:00<?, ?it/s]
#   1%|1         | 32/2280 [00:00<00:07, 305.56it/s]
#   3%|2         | 63/2280 [00:00<00:07, 284.95it/s]
#   5%|4         | 104/2280 [00:00<00:06, 323.19it/s]
#   9%|9         | 216/2280 [00:00<00:03, 597.60it/s]
#  28%|##7       | 628/2280 [00:00<00:00, 1742.80it/s]
#  39%|###9      | 900/2280 [00:00<00:00, 1988.28it/s]
#  64%|######4   | 1460/2280 [00:00<00:00, 3089.12it/s]
# 100%|##########| 2280/2280 [00:00<00:00, 2287.81it/s]
# 100%|##########| 784/784 [00:00<00:00, 9042.56it/s]
# 100%|##########| 1/1 [00:00<00:00, 1258.04it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 876.55it/s]
#
#   0%|          | 0/2414 [00:00<?, ?it/s]
#   1%|1         | 32/2414 [00:00<00:07, 310.83it/s]
#   3%|2         | 72/2414 [00:00<00:06, 351.29it/s]
#   6%|6         | 152/2414 [00:00<00:04, 544.77it/s]
#  22%|##1       | 528/2414 [00:00<00:01, 1630.27it/s]
#  34%|###4      | 824/2414 [00:00<00:00, 1890.06it/s]
#  67%|######6   | 1614/2414 [00:00<00:00, 3232.53it/s]
#  86%|########6 | 2088/2414 [00:00<00:00, 3201.62it/s]
# 100%|##########| 2414/2414 [00:01<00:00, 2399.93it/s]
# 100%|##########| 784/784 [00:00<00:00, 9220.71it/s]
# 100%|##########| 1/1 [00:00<00:00, 1173.89it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 155.92it/s]
#
#   0%|          | 0/2306 [00:00<?, ?it/s]
#   1%|1         | 32/2306 [00:00<00:07, 307.21it/s]
#   3%|3         | 72/2306 [00:00<00:06, 339.13it/s]
#   9%|8         | 198/2306 [00:00<00:03, 672.83it/s]
#  18%|#8        | 424/2306 [00:00<00:01, 1240.02it/s]
#  34%|###3      | 778/2306 [00:00<00:00, 1952.61it/s]
#  65%|######5   | 1508/2306 [00:00<00:00, 3514.76it/s]
# 100%|##########| 2306/2306 [00:00<00:00, 2523.56it/s]

# %%
fig, ax = plt.subplots(figsize=(28, 5))

c = sns.color_palette('rainbow', 6)
sns.palplot(c)

dfpcc = pd.DataFrame(pcc_ssim).set_index(0)
dfpcc.index = dfpcc.index.astype(str)
dfpcc.columns = ['PCC: Simp-Explain. to Ground Truth',  
                 'PCC: Shap-Explain. to Ground Truth', 
                 'SSIM: Simp-Explain. to Ground Truth', 
                 'SSIM: Shap-Explain. to Ground Truth', ]

dfpcc.plot(kind='bar',ax=ax, color = [c[0], c[1], c[-2], c[-1]], )
ax.set_ylim(0,1.15)
ax.legend(fontsize=20, ncol=2)

ax.set_xlabel('MNIST Class', fontsize=25)
ax.set_ylabel('PCC / SSIM', fontsize=25)

ax.tick_params(axis='x', rotation=45, labelsize=25)
ax.tick_params(axis='y', rotation=0, labelsize=25)

sns.despine(ax = ax, top=True, right=True, left=False, bottom=False)

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.035, hspace=None)

fig.savefig('./free-local-PCC-SSIM.svg', bbox_inches='tight', dpi=400)

# %% [markdown]
# ## Nosiey-added 0.36, local

# %%
fig, axes = plt.subplots(nrows= 4, ncols= 10, figsize=(28, 14), sharex = False, sharey = False, gridspec_kw={'height_ratios': [1.4, 1.4, 1.4,1.4]})

pcc_ssim = []

for l, i in gidx.apply(lambda x:x[0]).items():

    ax1, ax2, ax3, ax4 = axes[:, l]
    
    simp_explainer = AggMapNet.simply_explainer(clf, mp, apply_logrithm=True)
    I1 = simp_explainer.local_explain(testX_noisy[[i]], testY[[i]])
    IMP = I1.simply_importance.values.reshape(*mp.fmap_shape)
    IMP[IMP < 0.8] = 0 # smaller than 0 is 0 for simply


    shap_explainer = AggMapNet.shapley_explainer(clf, mp)
    I2 = shap_explainer.local_explain(testX_noisy[[i]])
    IMP2 = I2['shapley_importance_class_%s' % l].values.reshape(*mp.fmap_shape)

    
    tr = testX[i].reshape(*mp.fmap_shape)
    tr_n = testX_noisy[i].reshape(*mp.fmap_shape)
    
    S1 = ssim(tr / tr.max(), IMP/IMP.max(), full=True)
    S2 = ssim(tr / tr.max(), IMP2/IMP2.max(), full=True) #the full structural similarity image

    df1 = pd.Series(S1[1].reshape(w*h, )).to_frame(name = 'SSIM to Groudtruth')
    df1['data'] = 'Simp-Explain.'


    df2 = pd.Series(S2[1].reshape(w*h, )).to_frame(name = 'SSIM to Groudtruth')
    df2['data'] = 'Shap-Explain.'

    df = df1.append(df2)

    p1, v1 = pearsonr(tr.reshape(w*h,), IMP.reshape(w*h,))
    p2, v2 = pearsonr(tr.reshape(w*h,), IMP2.reshape(w*h,))

    _hm(tr, ax=ax1, cmap = 'gray',)
    _hm(tr_n, ax=ax2, cmap = 'gray',)    
    _hm(IMP, ax=ax3, cmap = 'rainbow',)    
    _hm(IMP2, ax=ax4, cmap = 'rainbow',)

    if l == 0:
        ax1.set_ylabel('Ground\nTruth', fontdict={'fontsize':28})
        ax2.set_ylabel('Noise added\nstddev=0.36.', fontdict={'fontsize':28})
        ax3.set_ylabel('Simp-\nExplain.', fontdict={'fontsize':28})
        ax4.set_ylabel('Shap-\nExplain.', fontdict={'fontsize':28})
        #ax4.set_ylabel('SSIM to GroudTruth')
    plt.tight_layout()

    pcc_ssim.append([l, p1, p2, S1[0], S2[0]])
    
    
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.035, hspace=None)
fig.savefig('./noisy-local.svg', bbox_inches='tight', dpi=400)
# Out:
# 100%|##########| 784/784 [00:00<00:00, 9083.95it/s]
# 100%|##########| 1/1 [00:00<00:00, 1468.59it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 616.99it/s]
#
#   0%|          | 0/2926 [00:00<?, ?it/s]
#   1%|1         | 32/2926 [00:00<00:09, 313.17it/s]
#   2%|2         | 72/2926 [00:00<00:08, 339.82it/s]
#   6%|6         | 180/2926 [00:00<00:04, 620.63it/s]
#  14%|#4        | 424/2926 [00:00<00:01, 1289.31it/s]
#  26%|##6       | 766/2926 [00:00<00:01, 1895.09it/s]
#  49%|####9     | 1436/2926 [00:00<00:00, 3296.55it/s]
#  60%|######    | 1766/2926 [00:00<00:00, 2710.26it/s]
#  77%|#######6  | 2240/2926 [00:00<00:00, 2778.94it/s]
# 100%|##########| 2926/2926 [00:01<00:00, 2357.83it/s]
# 100%|##########| 784/784 [00:00<00:00, 9134.59it/s]
# 100%|##########| 1/1 [00:00<00:00, 1054.91it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 1333.64it/s]
#
#   0%|          | 0/2828 [00:00<?, ?it/s]
#   1%|          | 24/2828 [00:00<00:12, 231.53it/s]
#   3%|2         | 72/2828 [00:00<00:08, 333.43it/s]
#   7%|7         | 198/2828 [00:00<00:03, 714.55it/s]
#  17%|#6        | 480/2828 [00:00<00:01, 1478.60it/s]
#  26%|##6       | 745/2828 [00:00<00:01, 1882.03it/s]
#  50%|####9     | 1408/2828 [00:00<00:00, 3383.66it/s]
#  73%|#######3  | 2072/2828 [00:00<00:00, 2931.43it/s]
# 100%|##########| 2828/2828 [00:01<00:00, 2501.33it/s]
# 100%|##########| 784/784 [00:00<00:00, 9043.48it/s]
# 100%|##########| 1/1 [00:00<00:00, 1506.57it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 667.46it/s]
#
#   0%|          | 0/2934 [00:00<?, ?it/s]
#   1%|1         | 32/2934 [00:00<00:09, 312.69it/s]
#   2%|2         | 64/2934 [00:00<00:11, 250.93it/s]
#   4%|4         | 128/2934 [00:00<00:06, 402.72it/s]
#  11%|#1        | 336/2934 [00:00<00:02, 989.37it/s]
#  23%|##2       | 672/2934 [00:00<00:01, 1587.52it/s]
#  45%|####5     | 1332/2934 [00:00<00:00, 2921.38it/s]
#  59%|#####8    | 1728/2934 [00:00<00:00, 2750.67it/s]
#  77%|#######6  | 2256/2934 [00:01<00:00, 2823.73it/s]
# 100%|##########| 2934/2934 [00:01<00:00, 2256.03it/s]
# 100%|##########| 784/784 [00:00<00:00, 9016.52it/s]
# 100%|##########| 1/1 [00:00<00:00, 1461.43it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 1064.81it/s]
#
#   0%|          | 0/2920 [00:00<?, ?it/s]
#   1%|          | 20/2920 [00:00<00:15, 191.04it/s]
#   1%|1         | 40/2920 [00:00<00:18, 154.81it/s]
#   4%|3         | 116/2920 [00:00<00:07, 377.77it/s]
#  11%|#         | 316/2920 [00:00<00:02, 878.45it/s]
#  23%|##3       | 680/2920 [00:00<00:01, 1703.18it/s]
#  41%|####1     | 1210/2920 [00:00<00:00, 2691.92it/s]
#  51%|#####     | 1486/2920 [00:00<00:00, 2484.76it/s]
#  60%|#####9    | 1741/2920 [00:00<00:00, 2312.95it/s]
#  74%|#######4  | 2164/2920 [00:01<00:00, 2231.44it/s]
#  89%|########8 | 2588/2920 [00:01<00:00, 2529.98it/s]
# 100%|##########| 2920/2920 [00:01<00:00, 1994.93it/s]
# 100%|##########| 784/784 [00:00<00:00, 8952.94it/s]
# 100%|##########| 1/1 [00:00<00:00, 1526.87it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 1031.56it/s]
#
#   0%|          | 0/2866 [00:00<?, ?it/s]
#   1%|          | 20/2866 [00:00<00:14, 191.28it/s]
#   1%|1         | 40/2866 [00:00<00:16, 170.26it/s]
#   5%|4         | 140/2866 [00:00<00:05, 495.26it/s]
#  14%|#4        | 404/2866 [00:00<00:02, 1204.00it/s]
#  29%|##9       | 836/2866 [00:00<00:00, 2169.31it/s]
#  49%|####9     | 1416/2866 [00:00<00:00, 2474.12it/s]
#  66%|######5   | 1880/2866 [00:00<00:00, 2516.88it/s]
#  82%|########1 | 2344/2866 [00:01<00:00, 2561.99it/s]
# 100%|##########| 2866/2866 [00:01<00:00, 2152.18it/s]
# 100%|##########| 784/784 [00:00<00:00, 9218.90it/s]
# 100%|##########| 1/1 [00:00<00:00, 1459.90it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 798.31it/s]
#
#   0%|          | 0/2944 [00:00<?, ?it/s]
#   1%|          | 26/2944 [00:00<00:12, 226.54it/s]
#   2%|1         | 49/2944 [00:00<00:12, 222.88it/s]
#   5%|5         | 154/2944 [00:00<00:05, 551.01it/s]
#  15%|#5        | 456/2944 [00:00<00:01, 1358.51it/s]
#  31%|###       | 906/2944 [00:00<00:00, 2351.76it/s]
#  51%|#####     | 1496/2944 [00:00<00:00, 2581.25it/s]
#  67%|######6   | 1968/2944 [00:00<00:00, 2713.31it/s]
#  79%|#######8  | 2322/2944 [00:01<00:00, 2906.69it/s]
#  89%|########8 | 2617/2944 [00:01<00:00, 2539.60it/s]
# 100%|##########| 2944/2944 [00:01<00:00, 2230.91it/s]
# 100%|##########| 784/784 [00:00<00:00, 9183.14it/s]
# 100%|##########| 1/1 [00:00<00:00, 1122.97it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 1072.99it/s]
#
#   0%|          | 0/2926 [00:00<?, ?it/s]
#   1%|1         | 40/2926 [00:00<00:07, 364.61it/s]
#   3%|2         | 77/2926 [00:00<00:08, 355.59it/s]
#   7%|6         | 198/2926 [00:00<00:03, 696.78it/s]
#  20%|#9        | 576/2926 [00:00<00:01, 1842.97it/s]
#  33%|###2      | 958/2926 [00:00<00:00, 2380.30it/s]
#  55%|#####5    | 1622/2926 [00:00<00:00, 3512.94it/s]
#  72%|#######2  | 2120/2926 [00:00<00:00, 3259.40it/s]
#  84%|########3 | 2452/2926 [00:00<00:00, 3247.08it/s]
# 100%|##########| 2926/2926 [00:01<00:00, 2802.84it/s]
# 100%|##########| 784/784 [00:00<00:00, 9277.05it/s]
# 100%|##########| 1/1 [00:00<00:00, 803.66it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 857.38it/s]
#
#   0%|          | 0/2856 [00:00<?, ?it/s]
#   1%|1         | 32/2856 [00:00<00:10, 280.58it/s]
#   2%|2         | 61/2856 [00:00<00:10, 277.43it/s]
#   5%|4         | 140/2856 [00:00<00:05, 492.63it/s]
#  16%|#5        | 448/2856 [00:00<00:01, 1445.35it/s]
#  26%|##6       | 750/2856 [00:00<00:01, 1975.86it/s]
#  50%|####9     | 1420/2856 [00:00<00:00, 3442.11it/s]
#  62%|######1   | 1763/2856 [00:00<00:00, 3003.87it/s]
#  78%|#######7  | 2224/2856 [00:00<00:00, 2905.93it/s]
# 100%|##########| 2856/2856 [00:01<00:00, 2395.18it/s]
# 100%|##########| 784/784 [00:00<00:00, 9017.07it/s]
# 100%|##########| 1/1 [00:00<00:00, 1531.33it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 1050.41it/s]
#
#   0%|          | 0/2914 [00:00<?, ?it/s]
#   1%|          | 26/2914 [00:00<00:11, 249.34it/s]
#   2%|1         | 51/2914 [00:00<00:12, 227.95it/s]
#   5%|4         | 140/2914 [00:00<00:05, 485.64it/s]
#  16%|#5        | 456/2914 [00:00<00:01, 1423.57it/s]
#  27%|##7       | 792/2914 [00:00<00:01, 2031.76it/s]
#  52%|#####1    | 1512/2914 [00:00<00:00, 2836.87it/s]
#  64%|######4   | 1872/2914 [00:00<00:00, 2829.88it/s]
#  73%|#######3  | 2141/2914 [00:00<00:00, 2775.70it/s]
# 100%|##########| 2914/2914 [00:01<00:00, 2431.34it/s]
# 100%|##########| 784/784 [00:00<00:00, 9097.14it/s]
# 100%|##########| 1/1 [00:00<00:00, 1506.03it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 795.43it/s]
#
#   0%|          | 0/2846 [00:00<?, ?it/s]
#   1%|          | 20/2846 [00:00<00:15, 183.00it/s]
#   1%|1         | 39/2846 [00:00<00:17, 157.46it/s]
#   4%|3         | 104/2846 [00:00<00:07, 344.61it/s]
#  10%|#         | 290/2846 [00:00<00:03, 821.59it/s]
#  22%|##1       | 620/2846 [00:00<00:01, 1541.88it/s]
#  47%|####7     | 1340/2846 [00:00<00:00, 3069.66it/s]
#  58%|#####7    | 1646/2846 [00:00<00:00, 2738.78it/s]
#  68%|######8   | 1940/2846 [00:00<00:00, 2692.73it/s]
#  78%|#######7  | 2211/2846 [00:01<00:00, 2618.81it/s]
#  89%|########9 | 2540/2846 [00:01<00:00, 2703.11it/s]
# 100%|##########| 2846/2846 [00:01<00:00, 2174.86it/s]

# %%
fig, ax = plt.subplots(figsize=(28, 5))

c = sns.color_palette('rainbow', 6)
sns.palplot(c)

dfpcc = pd.DataFrame(pcc_ssim).set_index(0)
dfpcc.index = dfpcc.index.astype(str)
dfpcc.columns = ['PCC: Simp-Explain. to Ground Truth',  
                 'PCC: Shap-Explain. to Ground Truth', 
                 'SSIM: Simp-Explain. to Ground Truth', 
                 'SSIM: Shap-Explain. to Ground Truth', ]

dfpcc.plot(kind='bar',ax=ax, color = [c[0], c[1], c[-2], c[-1]], )
ax.set_ylim(0,1.15)
ax.legend(fontsize=20, ncol=2)

ax.set_xlabel('MNIST Class', fontsize=25)
ax.set_ylabel('PCC / SSIM', fontsize=25)

ax.tick_params(axis='x', rotation=45, labelsize=25)
ax.tick_params(axis='y', rotation=0, labelsize=25)

sns.despine(ax = ax, top=True, right=True, left=False, bottom=False)

plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.035, hspace=None)

fig.savefig('./noisy-local-PCC-SSIM.svg', bbox_inches='tight', dpi=400)

# %% [markdown]
# ## Nosiey-free, global

# %%
gidx = pd.DataFrame(y_test).groupby(0).apply(lambda x:x.index.tolist()).apply(lambda x:x[:8]) 
select = list(chain(*gidx.tolist()))

# %%
for i in gidx.iloc[1]:
    fig, ax = plt.subplots()
    ax.imshow(testX_noisy[i].reshape(28,28))

# %%
from itertools import chain
simp_explainer = AggMapNet.simply_explainer(clf, mp, apply_logrithm=False)
SIMP_g = simp_explainer.global_explain(testX_noisy[select], testY[select])
# Out:
# 2021-10-07 11:42:04,785 - INFO - [bidd-aggmap] - calculating feature importance for class 0 ...
# 100%|##########| 784/784 [00:06<00:00, 125.95it/s]
# 2021-10-07 11:42:11,016 - INFO - [bidd-aggmap] - calculating feature importance for class 1 ...
# 100%|##########| 784/784 [00:06<00:00, 125.36it/s]
# 2021-10-07 11:42:17,276 - INFO - [bidd-aggmap] - calculating feature importance for class 2 ...
# 100%|##########| 784/784 [00:06<00:00, 124.91it/s]
# 2021-10-07 11:42:23,559 - INFO - [bidd-aggmap] - calculating feature importance for class 3 ...
# 100%|##########| 784/784 [00:06<00:00, 125.94it/s]
# 2021-10-07 11:42:29,791 - INFO - [bidd-aggmap] - calculating feature importance for class 4 ...
# 100%|##########| 784/784 [00:06<00:00, 127.35it/s]
# 2021-10-07 11:42:35,954 - INFO - [bidd-aggmap] - calculating feature importance for class 5 ...
# 100%|##########| 784/784 [00:06<00:00, 124.43it/s]
# 2021-10-07 11:42:42,261 - INFO - [bidd-aggmap] - calculating feature importance for class 6 ...
# 100%|##########| 784/784 [00:06<00:00, 126.14it/s]
# 2021-10-07 11:42:48,482 - INFO - [bidd-aggmap] - calculating feature importance for class 7 ...
# 100%|##########| 784/784 [00:06<00:00, 123.59it/s]
# 2021-10-07 11:42:54,833 - INFO - [bidd-aggmap] - calculating feature importance for class 8 ...
# 100%|##########| 784/784 [00:06<00:00, 117.15it/s]
# 2021-10-07 11:43:01,531 - INFO - [bidd-aggmap] - calculating feature importance for class 9 ...
# 100%|##########| 784/784 [00:06<00:00, 125.21it/s]

# %%
for x in range(10):
    g = SIMP_g['simply_importance_class_%s' % x].values.reshape(*mp.fmap_shape)
    fig, ax = plt.subplots()
    ax.imshow(g, cmap = 'rainbow', vmin=0)

# %%
shap_explainer = AggMapNet.shapley_explainer(clf, mp)
SHAP_g = shap_explainer.global_explain(testX_noisy[select])
# Out:
# 100%|##########| 1/1 [00:00<00:00,  3.79it/s]
#   0%|          | 0/80 [00:00<?, ?it/s]
# 100%|##########| 1/1 [00:00<00:00, 1389.76it/s]
#
#   0%|          | 0/2926 [00:00<?, ?it/s]
#   0%|          | 12/2926 [00:00<00:28, 104.05it/s]
#   1%|          | 24/2926 [00:00<00:26, 110.21it/s]
#   3%|3         | 92/2926 [00:00<00:07, 356.02it/s]
#  13%|#2        | 380/2926 [00:00<00:02, 1178.26it/s]
#  30%|###       | 890/2926 [00:00<00:00, 2352.98it/s]
#  48%|####7     | 1400/2926 [00:00<00:00, 2155.55it/s]
#  59%|#####9    | 1740/2926 [00:01<00:00, 1943.04it/s]
#  71%|#######1  | 2080/2926 [00:01<00:00, 1835.27it/s]
#  78%|#######7  | 2269/2926 [00:01<00:00, 1590.24it/s]
#  83%|########3 | 2431/2926 [00:01<00:00, 1472.72it/s]
# 100%|##########| 2926/2926 [00:01<00:00, 1617.43it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 161.36it/s]
#
#   0%|          | 0/2908 [00:00<?, ?it/s]
#   2%|1         | 48/2908 [00:00<00:06, 444.70it/s]
#   4%|3         | 112/2908 [00:00<00:05, 520.07it/s]
#   9%|8         | 256/2908 [00:00<00:03, 869.73it/s]
#  23%|##3       | 676/2908 [00:00<00:01, 2016.24it/s]
#  39%|###9      | 1148/2908 [00:00<00:00, 2824.65it/s]
#  69%|######8   | 1998/2908 [00:00<00:00, 4240.30it/s]
#  83%|########2 | 2410/2908 [00:00<00:00, 3492.27it/s]
# 100%|##########| 2908/2908 [00:01<00:00, 2820.72it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 198.42it/s]
#
#   0%|          | 0/2944 [00:00<?, ?it/s]
#   2%|1         | 48/2944 [00:00<00:06, 434.35it/s]
#   3%|3         | 92/2944 [00:00<00:07, 394.25it/s]
#  10%|9         | 280/2944 [00:00<00:02, 970.37it/s]
#  20%|##        | 600/2944 [00:00<00:01, 1744.68it/s]
#  40%|####      | 1190/2944 [00:00<00:00, 2902.11it/s]
#  67%|######6   | 1960/2944 [00:00<00:00, 3280.40it/s]
# 100%|##########| 2944/2944 [00:01<00:00, 2784.06it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 201.13it/s]
#
#   0%|          | 0/2966 [00:00<?, ?it/s]
#   1%|1         | 38/2966 [00:00<00:07, 369.81it/s]
#   4%|3         | 112/2966 [00:00<00:05, 505.99it/s]
#  12%|#1        | 354/2966 [00:00<00:02, 1160.78it/s]
#  29%|##9       | 872/2966 [00:00<00:00, 2193.18it/s]
#  52%|#####1    | 1536/2966 [00:00<00:00, 3506.97it/s]
#  74%|#######4  | 2200/2966 [00:00<00:00, 3380.99it/s]
# 100%|##########| 2966/2966 [00:01<00:00, 2912.51it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 195.02it/s]
#
#   0%|          | 0/2908 [00:00<?, ?it/s]
#   2%|1         | 44/2908 [00:00<00:06, 417.54it/s]
#   5%|4         | 132/2908 [00:00<00:04, 653.22it/s]
#  11%|#1        | 328/2908 [00:00<00:02, 1089.40it/s]
#  30%|##9       | 860/2908 [00:00<00:00, 2466.67it/s]
#  45%|####4     | 1304/2908 [00:00<00:00, 3006.11it/s]
#  73%|#######2  | 2117/2908 [00:00<00:00, 4597.47it/s]
# 100%|##########| 2908/2908 [00:00<00:00, 3150.69it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 205.62it/s]
#
#   0%|          | 0/2906 [00:00<?, ?it/s]
#   2%|1         | 58/2906 [00:00<00:05, 497.94it/s]
#   4%|3         | 112/2906 [00:00<00:05, 504.37it/s]
#   9%|8         | 256/2906 [00:00<00:02, 905.83it/s]
#  23%|##3       | 676/2906 [00:00<00:01, 2080.62it/s]
#  40%|###9      | 1160/2906 [00:00<00:00, 2931.11it/s]
#  70%|#######   | 2040/2906 [00:00<00:00, 4536.81it/s]
# 100%|##########| 2906/2906 [00:00<00:00, 3130.04it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 196.33it/s]
#
#   0%|          | 0/2914 [00:00<?, ?it/s]
#   2%|1         | 58/2914 [00:00<00:05, 533.26it/s]
#   5%|4         | 136/2914 [00:00<00:04, 647.94it/s]
#   9%|8         | 256/2914 [00:00<00:03, 849.28it/s]
#  24%|##3       | 688/2914 [00:00<00:01, 2066.92it/s]
#  40%|###9      | 1164/2914 [00:00<00:00, 2916.96it/s]
#  63%|######3   | 1844/2914 [00:00<00:00, 4065.78it/s]
#  77%|#######7  | 2252/2914 [00:00<00:00, 3429.18it/s]
# 100%|##########| 2914/2914 [00:01<00:00, 2855.99it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 133.85it/s]
#
#   0%|          | 0/2970 [00:00<?, ?it/s]
#   1%|1         | 32/2970 [00:00<00:10, 285.52it/s]
#   2%|2         | 72/2970 [00:00<00:08, 337.72it/s]
#   7%|6         | 198/2970 [00:00<00:03, 709.61it/s]
#  22%|##2       | 660/2970 [00:00<00:01, 2099.31it/s]
#  39%|###8      | 1152/2970 [00:00<00:00, 2827.36it/s]
#  68%|######7   | 2012/2970 [00:00<00:00, 4302.96it/s]
#  82%|########1 | 2432/2970 [00:00<00:00, 3580.03it/s]
# 100%|##########| 2970/2970 [00:01<00:00, 2878.47it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 2102.41it/s]
#
#   0%|          | 0/2828 [00:00<?, ?it/s]
#   1%|1         | 32/2828 [00:00<00:10, 279.45it/s]
#   2%|2         | 64/2828 [00:00<00:09, 291.65it/s]
#   7%|7         | 198/2828 [00:00<00:03, 710.36it/s]
#  21%|##1       | 600/2828 [00:00<00:01, 1889.01it/s]
#  42%|####2     | 1198/2828 [00:00<00:00, 3282.31it/s]
#  62%|######2   | 1756/2828 [00:00<00:00, 4034.28it/s]
#  77%|#######6  | 2169/2828 [00:00<00:00, 3161.30it/s]
# 100%|##########| 2828/2828 [00:01<00:00, 2717.29it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1308.27it/s]
#
#   0%|          | 0/2860 [00:00<?, ?it/s]
#   1%|1         | 32/2860 [00:00<00:09, 309.74it/s]
#   2%|2         | 63/2860 [00:00<00:09, 283.45it/s]
#   5%|5         | 154/2860 [00:00<00:05, 532.09it/s]
#  16%|#5        | 456/2860 [00:00<00:01, 1428.84it/s]
#  34%|###4      | 978/2860 [00:00<00:00, 2560.89it/s]
#  59%|#####9    | 1688/2860 [00:00<00:00, 3059.62it/s]
#  79%|#######8  | 2256/2860 [00:00<00:00, 3111.86it/s]
# 100%|##########| 2860/2860 [00:01<00:00, 2486.18it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 179.45it/s]
#
#   0%|          | 0/2844 [00:00<?, ?it/s]
#   1%|1         | 32/2844 [00:00<00:09, 284.84it/s]
#   2%|2         | 64/2844 [00:00<00:09, 294.36it/s]
#   7%|7         | 200/2844 [00:00<00:03, 718.79it/s]
#  21%|##        | 596/2844 [00:00<00:01, 1868.38it/s]
#  38%|###7      | 1072/2844 [00:00<00:00, 2674.07it/s]
#  68%|######7   | 1932/2844 [00:00<00:00, 4246.61it/s]
#  83%|########2 | 2348/2844 [00:00<00:00, 3497.29it/s]
# 100%|##########| 2844/2844 [00:01<00:00, 2755.26it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 199.34it/s]
#
#   0%|          | 0/2822 [00:00<?, ?it/s]
#   1%|1         | 38/2822 [00:00<00:09, 295.61it/s]
#   5%|4         | 132/2822 [00:00<00:04, 562.30it/s]
#  12%|#1        | 332/2822 [00:00<00:02, 1132.43it/s]
#  26%|##6       | 740/2822 [00:00<00:01, 1983.55it/s]
#  50%|#####     | 1416/2822 [00:00<00:00, 3279.37it/s]
#  72%|#######1  | 2024/2822 [00:00<00:00, 3254.74it/s]
# 100%|##########| 2822/2822 [00:01<00:00, 2706.28it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 166.83it/s]
#
#   0%|          | 0/2788 [00:00<?, ?it/s]
#   2%|2         | 58/2788 [00:00<00:05, 459.73it/s]
#   4%|4         | 112/2788 [00:00<00:05, 482.35it/s]
#  12%|#2        | 345/2788 [00:00<00:01, 1260.94it/s]
#  26%|##5       | 724/2788 [00:00<00:01, 1988.45it/s]
#  44%|####4     | 1236/2788 [00:00<00:00, 1669.46it/s]
#  70%|#######   | 1964/2788 [00:00<00:00, 2579.61it/s]
# 100%|##########| 2788/2788 [00:01<00:00, 2349.06it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 167.38it/s]
#
#   0%|          | 0/2820 [00:00<?, ?it/s]
#   1%|1         | 38/2820 [00:00<00:08, 331.50it/s]
#   4%|3         | 110/2820 [00:00<00:05, 493.28it/s]
#  12%|#1        | 332/2820 [00:00<00:02, 1137.51it/s]
#  26%|##6       | 740/2820 [00:00<00:00, 2096.18it/s]
#  45%|####5     | 1282/2820 [00:00<00:00, 3135.23it/s]
#  68%|######7   | 1914/2820 [00:00<00:00, 4035.01it/s]
#  82%|########2 | 2325/2820 [00:00<00:00, 3450.65it/s]
# 100%|##########| 2820/2820 [00:00<00:00, 2823.41it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 195.70it/s]
#
#   0%|          | 0/2866 [00:00<?, ?it/s]
#   2%|1         | 48/2866 [00:00<00:06, 406.56it/s]
#   5%|4         | 140/2866 [00:00<00:04, 594.11it/s]
#  13%|#2        | 368/2866 [00:00<00:02, 1213.44it/s]
#  28%|##7       | 800/2866 [00:00<00:00, 2298.47it/s]
#  48%|####7     | 1364/2866 [00:00<00:00, 3206.03it/s]
#  70%|#######   | 2020/2866 [00:00<00:00, 4178.89it/s]
#  85%|########5 | 2447/2866 [00:00<00:00, 3603.65it/s]
# 100%|##########| 2866/2866 [00:01<00:00, 2833.40it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1259.93it/s]
#
#   0%|          | 0/2790 [00:00<?, ?it/s]
#   2%|1         | 48/2790 [00:00<00:07, 385.16it/s]
#   6%|5         | 160/2790 [00:00<00:03, 704.59it/s]
#  13%|#2        | 354/2790 [00:00<00:02, 1193.29it/s]
#  26%|##5       | 724/2790 [00:00<00:01, 2027.70it/s]
#  49%|####8     | 1364/2790 [00:00<00:00, 3290.60it/s]
#  72%|#######2  | 2020/2790 [00:00<00:00, 4172.67it/s]
# 100%|##########| 2790/2790 [00:00<00:00, 3070.79it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 198.13it/s]
#
#   0%|          | 0/2934 [00:00<?, ?it/s]
#   1%|1         | 32/2934 [00:00<00:09, 293.86it/s]
#   2%|2         | 64/2934 [00:00<00:09, 298.16it/s]
#   7%|6         | 200/2934 [00:00<00:03, 723.23it/s]
#  18%|#8        | 530/2934 [00:00<00:01, 1659.19it/s]
#  37%|###6      | 1080/2934 [00:00<00:00, 2896.55it/s]
#  66%|######5   | 1934/2934 [00:00<00:00, 4720.64it/s]
#  82%|########2 | 2417/2934 [00:00<00:00, 3538.69it/s]
# 100%|##########| 2934/2934 [00:01<00:00, 2839.89it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1363.56it/s]
#
#   0%|          | 0/2936 [00:00<?, ?it/s]
#   1%|1         | 38/2936 [00:00<00:09, 298.53it/s]
#   4%|3         | 112/2936 [00:00<00:05, 511.46it/s]
#  12%|#2        | 354/2936 [00:00<00:02, 1231.23it/s]
#  25%|##4       | 724/2936 [00:00<00:01, 2060.20it/s]
#  41%|####1     | 1204/2936 [00:00<00:00, 2873.91it/s]
#  69%|######9   | 2034/2936 [00:00<00:00, 4303.24it/s]
#  84%|########3 | 2460/2936 [00:00<00:00, 3676.12it/s]
# 100%|##########| 2936/2936 [00:01<00:00, 2878.10it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1481.56it/s]
#
#   0%|          | 0/2858 [00:00<?, ?it/s]
#   1%|1         | 32/2858 [00:00<00:10, 279.30it/s]
#   3%|2         | 72/2858 [00:00<00:08, 333.50it/s]
#   7%|6         | 198/2858 [00:00<00:03, 700.59it/s]
#  23%|##2       | 648/2858 [00:00<00:01, 2037.62it/s]
#  40%|###9      | 1132/2858 [00:00<00:00, 2906.23it/s]
#  63%|######3   | 1812/2858 [00:00<00:00, 4040.40it/s]
#  78%|#######7  | 2218/2858 [00:00<00:00, 3421.91it/s]
# 100%|##########| 2858/2858 [00:01<00:00, 2778.75it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1513.10it/s]
#
#   0%|          | 0/2866 [00:00<?, ?it/s]
#   1%|1         | 38/2866 [00:00<00:08, 350.17it/s]
#   3%|3         | 88/2866 [00:00<00:06, 406.78it/s]
#   8%|8         | 242/2866 [00:00<00:03, 853.84it/s]
#  23%|##3       | 660/2866 [00:00<00:01, 1942.06it/s]
#  40%|###9      | 1140/2866 [00:00<00:00, 2727.19it/s]
#  70%|#######   | 2010/2866 [00:00<00:00, 4308.43it/s]
# 100%|##########| 2866/2866 [00:00<00:00, 3037.90it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 181.02it/s]
#
#   0%|          | 0/2864 [00:00<?, ?it/s]
#   1%|1         | 32/2864 [00:00<00:10, 279.41it/s]
#   2%|2         | 64/2864 [00:00<00:09, 293.39it/s]
#   6%|6         | 184/2864 [00:00<00:04, 660.31it/s]
#  19%|#9        | 548/2864 [00:00<00:01, 1732.25it/s]
#  34%|###4      | 983/2864 [00:00<00:00, 2629.25it/s]
#  58%|#####8    | 1672/2864 [00:00<00:00, 3913.93it/s]
#  72%|#######2  | 2065/2864 [00:00<00:00, 3340.05it/s]
# 100%|##########| 2864/2864 [00:01<00:00, 2722.54it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 167.52it/s]
#
#   0%|          | 0/2826 [00:00<?, ?it/s]
#   2%|1         | 48/2826 [00:00<00:08, 335.44it/s]
#   5%|4         | 136/2826 [00:00<00:04, 547.96it/s]
#  15%|#5        | 428/2826 [00:00<00:01, 1454.61it/s]
#  28%|##8       | 798/2826 [00:00<00:00, 2141.56it/s]
#  48%|####8     | 1364/2826 [00:00<00:00, 3235.36it/s]
#  71%|#######1  | 2020/2826 [00:00<00:00, 4269.16it/s]
# 100%|##########| 2826/2826 [00:00<00:00, 3049.37it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 172.86it/s]
#
#   0%|          | 0/2842 [00:00<?, ?it/s]
#   1%|1         | 40/2842 [00:00<00:07, 350.98it/s]
#   3%|2         | 76/2842 [00:00<00:07, 347.29it/s]
#   8%|7         | 216/2842 [00:00<00:03, 778.49it/s]
#  24%|##3       | 672/2842 [00:00<00:01, 2151.46it/s]
#  35%|###4      | 988/2842 [00:00<00:00, 2314.48it/s]
#  64%|######3   | 1808/2842 [00:00<00:00, 3905.62it/s]
#  77%|#######7  | 2193/2842 [00:00<00:00, 3321.41it/s]
# 100%|##########| 2842/2842 [00:01<00:00, 2740.65it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 137.31it/s]
#
#   0%|          | 0/2928 [00:00<?, ?it/s]
#   1%|1         | 32/2928 [00:00<00:09, 315.56it/s]
#   2%|2         | 64/2928 [00:00<00:09, 303.34it/s]
#   6%|5         | 168/2928 [00:00<00:04, 601.03it/s]
#  17%|#7        | 510/2928 [00:00<00:01, 1633.57it/s]
#  34%|###4      | 1008/2928 [00:00<00:00, 2664.02it/s]
#  61%|######1   | 1788/2928 [00:00<00:00, 4036.50it/s]
#  74%|#######4  | 2181/2928 [00:00<00:00, 3325.07it/s]
# 100%|##########| 2928/2928 [00:01<00:00, 2741.58it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 192.48it/s]
#
#   0%|          | 0/2920 [00:00<?, ?it/s]
#   2%|1         | 48/2920 [00:00<00:06, 422.44it/s]
#   3%|3         | 91/2920 [00:00<00:06, 421.19it/s]
#   9%|9         | 264/2920 [00:00<00:02, 995.98it/s]
#  28%|##8       | 828/2920 [00:00<00:00, 2709.70it/s]
#  38%|###7      | 1097/2920 [00:00<00:00, 2632.85it/s]
#  63%|######3   | 1840/2920 [00:00<00:00, 3907.28it/s]
# 100%|##########| 2920/2920 [00:00<00:00, 3053.27it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 194.23it/s]
#
#   0%|          | 0/2888 [00:00<?, ?it/s]
#   2%|2         | 58/2888 [00:00<00:05, 515.79it/s]
#   4%|3         | 112/2888 [00:00<00:05, 511.37it/s]
#  13%|#2        | 366/2888 [00:00<00:01, 1322.05it/s]
#  28%|##7       | 796/2888 [00:00<00:00, 2357.14it/s]
#  36%|###6      | 1054/2888 [00:00<00:00, 2359.81it/s]
#  57%|#####7    | 1656/2888 [00:00<00:00, 3385.12it/s]
#  81%|########1 | 2344/2888 [00:00<00:00, 4344.44it/s]
# 100%|##########| 2888/2888 [00:00<00:00, 2922.26it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 191.03it/s]
#
#   0%|          | 0/2852 [00:00<?, ?it/s]
#   2%|2         | 58/2852 [00:00<00:05, 511.83it/s]
#   5%|4         | 136/2852 [00:00<00:04, 637.31it/s]
#  10%|9         | 280/2852 [00:00<00:02, 949.54it/s]
#  28%|##7       | 798/2852 [00:00<00:00, 2451.38it/s]
#  44%|####3     | 1244/2852 [00:00<00:00, 2971.96it/s]
#  70%|######9   | 1988/2852 [00:00<00:00, 4330.81it/s]
# 100%|##########| 2852/2852 [00:00<00:00, 3100.06it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 189.75it/s]
#
#   0%|          | 0/2880 [00:00<?, ?it/s]
#   1%|1         | 32/2880 [00:00<00:10, 284.49it/s]
#   2%|2         | 61/2880 [00:00<00:10, 278.20it/s]
#   8%|8         | 238/2880 [00:00<00:02, 888.11it/s]
#  23%|##2       | 658/2880 [00:00<00:01, 2084.06it/s]
#  36%|###5      | 1032/2880 [00:00<00:00, 2597.62it/s]
#  62%|######2   | 1792/2880 [00:00<00:00, 3948.49it/s]
#  76%|#######5  | 2178/2880 [00:00<00:00, 3351.15it/s]
# 100%|##########| 2880/2880 [00:01<00:00, 2745.81it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1189.20it/s]
#
#   0%|          | 0/2914 [00:00<?, ?it/s]
#   2%|1         | 58/2914 [00:00<00:05, 505.21it/s]
#   5%|4         | 136/2914 [00:00<00:04, 636.47it/s]
#  10%|9         | 280/2914 [00:00<00:02, 947.63it/s]
#  28%|##7       | 812/2914 [00:00<00:00, 2489.96it/s]
#  44%|####3     | 1272/2914 [00:00<00:00, 3094.13it/s]
#  70%|#######   | 2040/2914 [00:00<00:00, 4475.87it/s]
# 100%|##########| 2914/2914 [00:00<00:00, 3185.65it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 164.45it/s]
#
#   0%|          | 0/2872 [00:00<?, ?it/s]
#   2%|2         | 58/2872 [00:00<00:05, 504.11it/s]
#   4%|3         | 112/2872 [00:00<00:05, 506.67it/s]
#   9%|8         | 256/2872 [00:00<00:03, 865.72it/s]
#  27%|##7       | 784/2872 [00:00<00:00, 2407.41it/s]
#  42%|####1     | 1192/2872 [00:00<00:00, 2903.62it/s]
#  71%|#######   | 2032/2872 [00:00<00:00, 4347.64it/s]
#  86%|########5 | 2458/2872 [00:00<00:00, 3549.59it/s]
# 100%|##########| 2872/2872 [00:01<00:00, 2799.15it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 201.54it/s]
#
#   0%|          | 0/2906 [00:00<?, ?it/s]
#   2%|1         | 58/2906 [00:00<00:05, 511.04it/s]
#   4%|3         | 112/2906 [00:00<00:05, 523.34it/s]
#   9%|8         | 256/2906 [00:00<00:02, 927.88it/s]
#  25%|##4       | 724/2906 [00:00<00:00, 2313.16it/s]
#  36%|###5      | 1042/2906 [00:00<00:00, 2534.59it/s]
#  59%|#####9    | 1722/2906 [00:00<00:00, 3919.28it/s]
# 100%|##########| 2906/2906 [00:00<00:00, 3172.88it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 163.96it/s]
#
#   0%|          | 0/2798 [00:00<?, ?it/s]
#   2%|2         | 58/2798 [00:00<00:05, 510.76it/s]
#   6%|5         | 166/2798 [00:00<00:03, 802.06it/s]
#  11%|#         | 296/2798 [00:00<00:02, 978.06it/s]
#  29%|##9       | 814/2798 [00:00<00:00, 2461.61it/s]
#  45%|####5     | 1260/2798 [00:00<00:00, 3025.12it/s]
#  72%|#######1  | 2004/2798 [00:00<00:00, 4335.65it/s]
# 100%|##########| 2798/2798 [00:00<00:00, 3068.24it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 167.38it/s]
#
#   0%|          | 0/2866 [00:00<?, ?it/s]
#   2%|1         | 48/2866 [00:00<00:06, 452.00it/s]
#   5%|4         | 138/2866 [00:00<00:04, 630.78it/s]
#  13%|#3        | 376/2866 [00:00<00:02, 1225.87it/s]
#  27%|##6       | 760/2866 [00:00<00:01, 1946.10it/s]
#  53%|#####3    | 1520/2866 [00:00<00:00, 3552.69it/s]
#  69%|######8   | 1976/2866 [00:00<00:00, 3138.31it/s]
# 100%|##########| 2866/2866 [00:01<00:00, 2856.39it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 141.55it/s]
#
#   0%|          | 0/2902 [00:00<?, ?it/s]
#   2%|1         | 58/2902 [00:00<00:05, 524.33it/s]
#   4%|3         | 112/2902 [00:00<00:05, 532.30it/s]
#  10%|9         | 280/2902 [00:00<00:02, 977.68it/s]
#  29%|##8       | 831/2902 [00:00<00:00, 2670.71it/s]
#  41%|####      | 1182/2902 [00:00<00:00, 2962.68it/s]
#  67%|######6   | 1930/2902 [00:00<00:00, 4462.45it/s]
# 100%|##########| 2902/2902 [00:00<00:00, 3198.59it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 169.57it/s]
#
#   0%|          | 0/2822 [00:00<?, ?it/s]
#   1%|1         | 32/2822 [00:00<00:09, 281.64it/s]
#   2%|2         | 61/2822 [00:00<00:10, 265.52it/s]
#   9%|9         | 260/2822 [00:00<00:02, 891.43it/s]
#  21%|##        | 584/2822 [00:00<00:01, 1654.92it/s]
#  47%|####6     | 1314/2822 [00:00<00:00, 3431.93it/s]
#  62%|######2   | 1752/2822 [00:00<00:00, 3052.46it/s]
# 100%|##########| 2822/2822 [00:01<00:00, 2761.17it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 162.43it/s]
#
#   0%|          | 0/2816 [00:00<?, ?it/s]
#   1%|1         | 32/2816 [00:00<00:09, 290.35it/s]
#   2%|2         | 62/2816 [00:00<00:09, 290.78it/s]
#   6%|5         | 168/2816 [00:00<00:04, 608.31it/s]
#  21%|##        | 588/2816 [00:00<00:01, 1952.14it/s]
#  42%|####1     | 1176/2816 [00:00<00:00, 3192.76it/s]
#  67%|######6   | 1880/2816 [00:00<00:00, 4400.60it/s]
#  82%|########2 | 2323/2816 [00:00<00:00, 3513.45it/s]
# 100%|##########| 2816/2816 [00:01<00:00, 2729.10it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 169.14it/s]
#
#   0%|          | 0/2872 [00:00<?, ?it/s]
#   1%|1         | 32/2872 [00:00<00:09, 287.75it/s]
#   2%|2         | 61/2872 [00:00<00:10, 279.64it/s]
#   6%|5         | 168/2872 [00:00<00:04, 580.76it/s]
#  21%|##        | 600/2872 [00:00<00:01, 1724.46it/s]
#  50%|#####     | 1440/2872 [00:00<00:00, 3696.21it/s]
#  68%|######7   | 1944/2872 [00:00<00:00, 3164.69it/s]
# 100%|##########| 2872/2872 [00:01<00:00, 2784.60it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 165.65it/s]
#
#   0%|          | 0/2864 [00:00<?, ?it/s]
#   2%|1         | 48/2864 [00:00<00:06, 418.17it/s]
#   3%|3         | 90/2864 [00:00<00:07, 380.68it/s]
#  14%|#4        | 408/2864 [00:00<00:01, 1468.64it/s]
#  25%|##5       | 728/2864 [00:00<00:01, 1841.11it/s]
#  54%|#####3    | 1538/2864 [00:00<00:00, 3615.71it/s]
#  71%|#######   | 2024/2864 [00:00<00:00, 3153.91it/s]
# 100%|##########| 2864/2864 [00:01<00:00, 2783.65it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 187.03it/s]
#
#   0%|          | 0/2870 [00:00<?, ?it/s]
#   2%|2         | 58/2870 [00:00<00:05, 506.99it/s]
#   4%|3         | 112/2870 [00:00<00:05, 510.23it/s]
#  10%|9         | 280/2870 [00:00<00:02, 996.99it/s]
#  29%|##9       | 840/2870 [00:00<00:00, 2583.63it/s]
#  46%|####5     | 1312/2870 [00:00<00:00, 3134.00it/s]
#  73%|#######3  | 2096/2870 [00:00<00:00, 4444.01it/s]
# 100%|##########| 2870/2870 [00:00<00:00, 3150.80it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1245.71it/s]
#
#   0%|          | 0/2906 [00:00<?, ?it/s]
#   2%|1         | 48/2906 [00:00<00:06, 416.98it/s]
#   3%|3         | 90/2906 [00:00<00:06, 408.71it/s]
#   7%|7         | 216/2906 [00:00<00:03, 762.77it/s]
#  23%|##2       | 664/2906 [00:00<00:01, 2112.71it/s]
#  37%|###7      | 1084/2906 [00:00<00:00, 2803.53it/s]
#  68%|######7   | 1974/2906 [00:00<00:00, 4508.34it/s]
#  83%|########3 | 2413/2906 [00:00<00:00, 3543.59it/s]
# 100%|##########| 2906/2906 [00:01<00:00, 2820.03it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 196.79it/s]
#
#   0%|          | 0/2944 [00:00<?, ?it/s]
#   2%|1         | 48/2944 [00:00<00:06, 451.25it/s]
#   4%|3         | 112/2944 [00:00<00:05, 541.70it/s]
#  10%|9         | 280/2944 [00:00<00:02, 969.55it/s]
#  26%|##6       | 778/2944 [00:00<00:00, 2451.47it/s]
#  41%|####1     | 1214/2944 [00:00<00:00, 3110.78it/s]
#  68%|######7   | 2000/2944 [00:00<00:00, 4362.93it/s]
# 100%|##########| 2944/2944 [00:00<00:00, 3127.89it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 168.89it/s]
#
#   0%|          | 0/2886 [00:00<?, ?it/s]
#   2%|2         | 58/2886 [00:00<00:05, 529.43it/s]
#   4%|3         | 114/2886 [00:00<00:05, 544.29it/s]
#  10%|#         | 296/2886 [00:00<00:02, 1077.22it/s]
#  27%|##6       | 776/2886 [00:00<00:00, 2466.27it/s]
#  39%|###9      | 1132/2886 [00:00<00:00, 2713.25it/s]
#  66%|######6   | 1916/2886 [00:00<00:00, 4245.96it/s]
# 100%|##########| 2886/2886 [00:00<00:00, 3178.80it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 166.65it/s]
#
#   0%|          | 0/2852 [00:00<?, ?it/s]
#   2%|1         | 48/2852 [00:00<00:06, 421.94it/s]
#   3%|3         | 91/2852 [00:00<00:07, 382.87it/s]
#   7%|7         | 200/2852 [00:00<00:03, 668.80it/s]
#  22%|##1       | 620/2852 [00:00<00:01, 1890.73it/s]
#  49%|####8     | 1392/2852 [00:00<00:00, 3636.83it/s]
#  74%|#######3  | 2104/2852 [00:00<00:00, 3393.25it/s]
# 100%|##########| 2852/2852 [00:01<00:00, 2802.29it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 189.44it/s]
#
#   0%|          | 0/2848 [00:00<?, ?it/s]
#   1%|1         | 38/2848 [00:00<00:07, 372.85it/s]
#   4%|4         | 114/2848 [00:00<00:04, 549.55it/s]
#   9%|9         | 270/2848 [00:00<00:02, 942.02it/s]
#  24%|##3       | 680/2848 [00:00<00:01, 1153.31it/s]
#  31%|###       | 872/2848 [00:00<00:01, 1253.51it/s]
#  42%|####1     | 1192/2848 [00:00<00:01, 1650.56it/s]
#  53%|#####3    | 1512/2848 [00:01<00:00, 1982.46it/s]
#  64%|######4   | 1832/2848 [00:01<00:00, 2250.72it/s]
#  83%|########2 | 2352/2848 [00:01<00:00, 2885.39it/s]
# 100%|##########| 2848/2848 [00:01<00:00, 2039.08it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 145.30it/s]
#
#   0%|          | 0/2834 [00:00<?, ?it/s]
#   1%|1         | 41/2834 [00:00<00:06, 409.97it/s]
#   3%|3         | 92/2834 [00:00<00:06, 448.70it/s]
#   8%|8         | 232/2834 [00:00<00:03, 833.20it/s]
#  21%|##1       | 604/2834 [00:00<00:01, 1887.67it/s]
#  38%|###8      | 1084/2834 [00:00<00:00, 2784.89it/s]
#  70%|######9   | 1974/2834 [00:00<00:00, 4435.27it/s]
# 100%|##########| 2834/2834 [00:00<00:00, 3124.16it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 150.57it/s]
#
#   0%|          | 0/2834 [00:00<?, ?it/s]
#   1%|1         | 32/2834 [00:00<00:08, 317.60it/s]
#   2%|2         | 64/2834 [00:00<00:09, 285.38it/s]
#   6%|5         | 168/2834 [00:00<00:04, 591.58it/s]
#  19%|#8        | 528/2834 [00:00<00:01, 1698.14it/s]
#  41%|####1     | 1170/2834 [00:00<00:00, 3180.86it/s]
#  66%|######5   | 1866/2834 [00:00<00:00, 4384.66it/s]
#  82%|########1 | 2310/2834 [00:00<00:00, 3448.64it/s]
# 100%|##########| 2834/2834 [00:01<00:00, 2706.27it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 187.58it/s]
#
#   0%|          | 0/2794 [00:00<?, ?it/s]
#   2%|1         | 48/2794 [00:00<00:05, 460.04it/s]
#   3%|3         | 95/2794 [00:00<00:06, 448.15it/s]
#   8%|7         | 220/2794 [00:00<00:03, 766.43it/s]
#  25%|##5       | 704/2794 [00:00<00:00, 2129.12it/s]
#  41%|####1     | 1146/2794 [00:00<00:00, 2708.87it/s]
#  66%|######6   | 1858/2794 [00:00<00:00, 3797.18it/s]
# 100%|##########| 2794/2794 [00:00<00:00, 2927.95it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 151.73it/s]
#
#   0%|          | 0/2936 [00:00<?, ?it/s]
#   1%|1         | 32/2936 [00:00<00:10, 282.61it/s]
#   2%|2         | 72/2936 [00:00<00:08, 333.41it/s]
#   7%|6         | 198/2936 [00:00<00:03, 697.55it/s]
#  20%|##        | 588/2936 [00:00<00:01, 1727.92it/s]
#  41%|####      | 1199/2936 [00:00<00:00, 3159.37it/s]
#  65%|######4   | 1902/2936 [00:00<00:00, 4295.66it/s]
#  80%|#######9  | 2341/2936 [00:00<00:00, 3440.06it/s]
# 100%|##########| 2936/2936 [00:01<00:00, 2771.44it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 145.42it/s]
#
#   0%|          | 0/2926 [00:00<?, ?it/s]
#   1%|          | 26/2926 [00:00<00:12, 229.59it/s]
#   2%|1         | 49/2926 [00:00<00:12, 224.84it/s]
#   5%|5         | 154/2926 [00:00<00:04, 562.78it/s]
#  16%|#5        | 468/2926 [00:00<00:01, 1484.09it/s]
#  32%|###2      | 946/2926 [00:00<00:00, 2555.86it/s]
#  54%|#####3    | 1576/2926 [00:00<00:00, 2930.85it/s]
#  71%|#######1  | 2080/2926 [00:00<00:00, 3015.58it/s]
# 100%|##########| 2926/2926 [00:01<00:00, 2633.64it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 140.89it/s]
#
#   0%|          | 0/2886 [00:00<?, ?it/s]
#   1%|          | 26/2886 [00:00<00:13, 214.23it/s]
#   2%|1         | 48/2886 [00:00<00:13, 212.22it/s]
#   5%|4         | 140/2886 [00:00<00:05, 493.89it/s]
#  14%|#3        | 404/2886 [00:00<00:01, 1269.34it/s]
#  28%|##8       | 812/2886 [00:00<00:00, 2149.95it/s]
#  47%|####6     | 1352/2886 [00:00<00:00, 2683.95it/s]
#  62%|######1   | 1784/2886 [00:00<00:00, 2836.74it/s]
#  77%|#######6  | 2216/2886 [00:00<00:00, 2969.20it/s]
# 100%|##########| 2886/2886 [00:01<00:00, 2389.73it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 124.20it/s]
#
#   0%|          | 0/2890 [00:00<?, ?it/s]
#   1%|1         | 38/2890 [00:00<00:08, 333.96it/s]
#   4%|3         | 110/2890 [00:00<00:05, 494.33it/s]
#   8%|8         | 242/2890 [00:00<00:03, 830.48it/s]
#  23%|##2       | 660/2890 [00:00<00:01, 1877.37it/s]
#  44%|####4     | 1284/2890 [00:00<00:00, 3073.13it/s]
#  73%|#######2  | 2104/2890 [00:00<00:00, 3386.26it/s]
# 100%|##########| 2890/2890 [00:01<00:00, 2859.86it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 183.63it/s]
#
#   0%|          | 0/2852 [00:00<?, ?it/s]
#   1%|1         | 38/2852 [00:00<00:09, 297.25it/s]
#   4%|3         | 112/2852 [00:00<00:05, 508.50it/s]
#  12%|#1        | 333/2852 [00:00<00:02, 1221.91it/s]
#  25%|##5       | 724/2852 [00:00<00:00, 2131.56it/s]
#  43%|####3     | 1240/2852 [00:00<00:00, 3014.99it/s]
#  69%|######9   | 1976/2852 [00:00<00:00, 4155.49it/s]
# 100%|##########| 2852/2852 [00:00<00:00, 3061.23it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1078.78it/s]
#
#   0%|          | 0/2970 [00:00<?, ?it/s]
#   1%|          | 28/2970 [00:00<00:11, 248.63it/s]
#   4%|3         | 112/2970 [00:00<00:05, 551.01it/s]
#   9%|8         | 256/2970 [00:00<00:03, 885.33it/s]
#  22%|##2       | 664/2970 [00:00<00:01, 1889.04it/s]
#  44%|####3     | 1302/2970 [00:00<00:00, 3129.00it/s]
#  72%|#######2  | 2152/2970 [00:00<00:00, 3379.91it/s]
# 100%|##########| 2970/2970 [00:01<00:00, 2899.80it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 184.66it/s]
#
#   0%|          | 0/2852 [00:00<?, ?it/s]
#   1%|          | 26/2852 [00:00<00:12, 225.16it/s]
#   2%|1         | 49/2852 [00:00<00:12, 222.15it/s]
#   5%|5         | 154/2852 [00:00<00:04, 557.15it/s]
#  16%|#5        | 456/2852 [00:00<00:01, 1456.92it/s]
#  33%|###2      | 930/2852 [00:00<00:00, 2434.55it/s]
#  55%|#####4    | 1560/2852 [00:00<00:00, 2964.83it/s]
#  72%|#######2  | 2064/2852 [00:00<00:00, 3044.61it/s]
# 100%|##########| 2852/2852 [00:01<00:00, 2559.34it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 171.56it/s]
#
#   0%|          | 0/2870 [00:00<?, ?it/s]
#   1%|1         | 38/2870 [00:00<00:09, 295.50it/s]
#   4%|3         | 110/2870 [00:00<00:05, 503.21it/s]
#   8%|8         | 242/2870 [00:00<00:03, 833.77it/s]
#  20%|#9        | 564/2870 [00:00<00:01, 1674.68it/s]
#  37%|###6      | 1060/2870 [00:00<00:00, 2774.84it/s]
#  64%|######4   | 1850/2870 [00:00<00:00, 4172.38it/s]
#  79%|#######8  | 2262/2870 [00:00<00:00, 3423.39it/s]
# 100%|##########| 2870/2870 [00:01<00:00, 2767.46it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1180.83it/s]
#
#   0%|          | 0/2886 [00:00<?, ?it/s]
#   2%|1         | 48/2886 [00:00<00:06, 405.99it/s]
#   4%|3         | 110/2886 [00:00<00:05, 484.91it/s]
#   8%|8         | 242/2886 [00:00<00:03, 823.30it/s]
#  21%|##1       | 612/2886 [00:00<00:01, 1821.14it/s]
#  36%|###6      | 1048/2886 [00:00<00:00, 2647.66it/s]
#  64%|######4   | 1848/2886 [00:00<00:00, 4243.08it/s]
#  79%|#######8  | 2274/2886 [00:00<00:00, 3462.70it/s]
# 100%|##########| 2886/2886 [00:01<00:00, 2800.54it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 190.99it/s]
#
#   0%|          | 0/2856 [00:00<?, ?it/s]
#   1%|1         | 32/2856 [00:00<00:10, 279.63it/s]
#   2%|2         | 64/2856 [00:00<00:09, 289.81it/s]
#   6%|6         | 184/2856 [00:00<00:04, 656.62it/s]
#  16%|#5        | 450/2856 [00:00<00:01, 1380.18it/s]
#  37%|###6      | 1056/2856 [00:00<00:00, 2940.19it/s]
#  63%|######2   | 1797/2856 [00:00<00:00, 4395.81it/s]
#  79%|#######8  | 2246/2856 [00:00<00:00, 3502.24it/s]
# 100%|##########| 2856/2856 [00:01<00:00, 2750.93it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 165.14it/s]
#
#   0%|          | 0/2860 [00:00<?, ?it/s]
#   1%|1         | 32/2860 [00:00<00:11, 250.83it/s]
#   3%|3         | 90/2860 [00:00<00:07, 381.92it/s]
#  11%|#1        | 325/2860 [00:00<00:02, 1177.50it/s]
#  23%|##3       | 664/2860 [00:00<00:01, 1915.21it/s]
#  42%|####1     | 1190/2860 [00:00<00:00, 3009.79it/s]
#  68%|######7   | 1944/2860 [00:00<00:00, 4467.57it/s]
#  84%|########4 | 2407/2860 [00:00<00:00, 3560.45it/s]
# 100%|##########| 2860/2860 [00:01<00:00, 2752.56it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1376.99it/s]
#
#   0%|          | 0/2822 [00:00<?, ?it/s]
#   1%|          | 26/2822 [00:00<00:12, 229.24it/s]
#   2%|1         | 49/2822 [00:00<00:12, 222.67it/s]
#   5%|5         | 154/2822 [00:00<00:04, 552.40it/s]
#  16%|#6        | 456/2822 [00:00<00:01, 1435.91it/s]
#  34%|###3      | 948/2822 [00:00<00:00, 2494.03it/s]
#  57%|#####6    | 1608/2822 [00:00<00:00, 2945.87it/s]
#  76%|#######5  | 2136/2822 [00:01<00:00, 2242.91it/s]
# 100%|##########| 2822/2822 [00:01<00:00, 2168.10it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1675.04it/s]
#
#   0%|          | 0/2888 [00:00<?, ?it/s]
#   2%|1         | 48/2888 [00:00<00:07, 375.84it/s]
#   4%|3         | 112/2888 [00:00<00:05, 497.97it/s]
#  12%|#2        | 354/2888 [00:00<00:02, 1160.52it/s]
#  28%|##7       | 798/2888 [00:00<00:00, 2197.83it/s]
#  47%|####7     | 1364/2888 [00:00<00:00, 3168.34it/s]
#  76%|#######5  | 2184/2888 [00:00<00:00, 3419.22it/s]
# 100%|##########| 2888/2888 [00:01<00:00, 2837.70it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 164.55it/s]
#
#   0%|          | 0/2902 [00:00<?, ?it/s]
#   1%|1         | 38/2902 [00:00<00:09, 295.28it/s]
#   4%|3         | 110/2902 [00:00<00:05, 507.45it/s]
#   8%|8         | 242/2902 [00:00<00:03, 842.54it/s]
#  23%|##2       | 660/2902 [00:00<00:01, 1885.86it/s]
#  38%|###8      | 1104/2902 [00:00<00:00, 2705.92it/s]
#  65%|######4   | 1884/2902 [00:00<00:00, 4012.59it/s]
#  79%|#######8  | 2279/2902 [00:00<00:00, 3545.54it/s]
# 100%|##########| 2902/2902 [00:01<00:00, 2810.83it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1026.00it/s]
#
#   0%|          | 0/2806 [00:00<?, ?it/s]
#   2%|1         | 48/2806 [00:00<00:06, 430.15it/s]
#   5%|4         | 136/2806 [00:00<00:04, 653.06it/s]
#   9%|9         | 256/2806 [00:00<00:03, 847.03it/s]
#  24%|##3       | 664/2806 [00:00<00:01, 1986.59it/s]
#  47%|####7     | 1320/2806 [00:00<00:00, 3261.02it/s]
# 100%|##########| 2806/2806 [00:00<00:00, 3060.67it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 141.37it/s]
#
#   0%|          | 0/2870 [00:00<?, ?it/s]
#   1%|1         | 32/2870 [00:00<00:10, 280.66it/s]
#   2%|2         | 61/2870 [00:00<00:10, 276.49it/s]
#   5%|5         | 154/2870 [00:00<00:05, 538.60it/s]
#  14%|#4        | 408/2870 [00:00<00:01, 1269.16it/s]
#  34%|###4      | 990/2870 [00:00<00:00, 2740.36it/s]
#  60%|#####9    | 1720/2870 [00:00<00:00, 3107.50it/s]
#  75%|#######5  | 2158/2870 [00:00<00:00, 3424.50it/s]
# 100%|##########| 2870/2870 [00:01<00:00, 2800.38it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1134.82it/s]
#
#   0%|          | 0/2916 [00:00<?, ?it/s]
#   2%|1         | 48/2916 [00:00<00:06, 418.00it/s]
#   3%|3         | 90/2916 [00:00<00:07, 373.64it/s]
#  10%|9         | 280/2916 [00:00<00:02, 950.76it/s]
#  23%|##2       | 664/2916 [00:00<00:01, 1922.68it/s]
#  46%|####6     | 1344/2916 [00:00<00:00, 3285.71it/s]
#  67%|######7   | 1960/2916 [00:00<00:00, 3184.09it/s]
# 100%|##########| 2916/2916 [00:01<00:00, 2772.20it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 199.99it/s]
#
#   0%|          | 0/2914 [00:00<?, ?it/s]
#   1%|1         | 32/2914 [00:00<00:10, 285.00it/s]
#   2%|2         | 72/2914 [00:00<00:08, 334.67it/s]
#   7%|7         | 216/2914 [00:00<00:03, 744.36it/s]
#  26%|##6       | 768/2914 [00:00<00:00, 2387.81it/s]
#  35%|###4      | 1011/2914 [00:00<00:00, 2335.91it/s]
#  61%|######    | 1768/2914 [00:00<00:00, 3728.57it/s]
# 100%|##########| 2914/2914 [00:00<00:00, 2948.55it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 180.94it/s]
#
#   0%|          | 0/2914 [00:00<?, ?it/s]
#   2%|1         | 58/2914 [00:00<00:05, 513.56it/s]
#   4%|3         | 110/2914 [00:00<00:05, 493.09it/s]
#   9%|9         | 264/2914 [00:00<00:02, 942.23it/s]
#  25%|##5       | 732/2914 [00:00<00:00, 2320.50it/s]
#  37%|###7      | 1086/2914 [00:00<00:00, 2647.65it/s]
#  64%|######4   | 1878/2914 [00:00<00:00, 4325.37it/s]
# 100%|##########| 2914/2914 [00:00<00:00, 3103.42it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 167.46it/s]
#
#   0%|          | 0/2884 [00:00<?, ?it/s]
#   1%|1         | 32/2884 [00:00<00:09, 288.07it/s]
#   2%|2         | 61/2884 [00:00<00:10, 271.92it/s]
#   6%|5         | 168/2884 [00:00<00:04, 592.17it/s]
#  20%|##        | 588/2884 [00:00<00:01, 1871.50it/s]
#  41%|####      | 1170/2884 [00:00<00:00, 3135.18it/s]
#  71%|#######   | 2040/2884 [00:00<00:00, 3325.19it/s]
# 100%|##########| 2884/2884 [00:01<00:00, 2757.51it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 192.47it/s]
#
#   0%|          | 0/2924 [00:00<?, ?it/s]
#   2%|2         | 68/2924 [00:00<00:04, 630.72it/s]
#   5%|5         | 160/2924 [00:00<00:03, 721.05it/s]
#  14%|#4        | 420/2924 [00:00<00:01, 1471.54it/s]
#  30%|###       | 880/2924 [00:00<00:00, 2592.51it/s]
#  40%|###9      | 1156/2924 [00:00<00:00, 2545.67it/s]
#  65%|######4   | 1892/2924 [00:00<00:00, 3811.54it/s]
# 100%|##########| 2924/2924 [00:00<00:00, 3073.20it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 148.33it/s]
#
#   0%|          | 0/2902 [00:00<?, ?it/s]
#   1%|1         | 40/2902 [00:00<00:07, 398.58it/s]
#   4%|3         | 116/2902 [00:00<00:04, 602.90it/s]
#   9%|8         | 248/2902 [00:00<00:03, 881.04it/s]
#  22%|##1       | 632/2902 [00:00<00:01, 1991.29it/s]
#  38%|###7      | 1092/2902 [00:00<00:00, 2757.95it/s]
#  66%|######6   | 1922/2902 [00:00<00:00, 4284.51it/s]
#  81%|########  | 2340/2902 [00:00<00:00, 3486.64it/s]
# 100%|##########| 2902/2902 [00:01<00:00, 2809.61it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 151.65it/s]
#
#   0%|          | 0/2944 [00:00<?, ?it/s]
#   2%|1         | 48/2944 [00:00<00:06, 419.54it/s]
#   3%|3         | 90/2944 [00:00<00:07, 379.52it/s]
#   9%|8         | 258/2944 [00:00<00:03, 882.49it/s]
#  21%|##        | 606/2944 [00:00<00:01, 1796.44it/s]
#  43%|####3     | 1272/2944 [00:00<00:00, 3268.15it/s]
#  64%|######3   | 1880/2944 [00:00<00:00, 3153.42it/s]
# 100%|##########| 2944/2944 [00:01<00:00, 2825.30it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 161.03it/s]
#
#   0%|          | 0/2830 [00:00<?, ?it/s]
#   2%|2         | 58/2830 [00:00<00:05, 508.62it/s]
#   4%|3         | 112/2830 [00:00<00:05, 507.33it/s]
#  13%|#2        | 364/2830 [00:00<00:01, 1281.03it/s]
#  28%|##7       | 784/2830 [00:00<00:00, 2306.83it/s]
#  37%|###6      | 1036/2830 [00:00<00:00, 2349.30it/s]
#  60%|######    | 1708/2830 [00:00<00:00, 3567.07it/s]
# 100%|##########| 2830/2830 [00:00<00:00, 2990.22it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1058.90it/s]
#
#   0%|          | 0/2926 [00:00<?, ?it/s]
#   2%|1         | 48/2926 [00:00<00:06, 415.50it/s]
#   3%|3         | 90/2926 [00:00<00:06, 406.48it/s]
#   7%|7         | 216/2926 [00:00<00:03, 747.84it/s]
#  23%|##3       | 680/2926 [00:00<00:01, 1863.82it/s]
#  53%|#####3    | 1560/2926 [00:00<00:00, 3866.95it/s]
#  71%|#######1  | 2088/2926 [00:00<00:00, 3300.88it/s]
# 100%|##########| 2926/2926 [00:01<00:00, 2819.66it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1212.23it/s]
#
#   0%|          | 0/2846 [00:00<?, ?it/s]
#   2%|2         | 58/2846 [00:00<00:05, 520.36it/s]
#   5%|4         | 136/2846 [00:00<00:04, 641.48it/s]
#  10%|9         | 280/2846 [00:00<00:02, 944.36it/s]
#  25%|##5       | 724/2846 [00:00<00:00, 2198.53it/s]
#  44%|####4     | 1256/2846 [00:00<00:00, 3153.07it/s]
#  71%|#######1  | 2024/2846 [00:00<00:00, 4489.35it/s]
# 100%|##########| 2846/2846 [00:00<00:00, 3117.55it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 191.62it/s]
#
#   0%|          | 0/2874 [00:00<?, ?it/s]
#   2%|1         | 48/2874 [00:00<00:06, 416.24it/s]
#   4%|3         | 112/2874 [00:00<00:05, 524.83it/s]
#   8%|8         | 232/2874 [00:00<00:03, 805.66it/s]
#  25%|##4       | 712/2874 [00:00<00:01, 1889.05it/s]
#  55%|#####4    | 1572/2874 [00:00<00:00, 3780.56it/s]
#  73%|#######2  | 2088/2874 [00:00<00:00, 3224.86it/s]
# 100%|##########| 2874/2874 [00:01<00:00, 2233.95it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 120.02it/s]
#
#   0%|          | 0/2866 [00:00<?, ?it/s]
#   2%|1         | 48/2866 [00:00<00:06, 465.95it/s]
#   3%|3         | 95/2866 [00:00<00:06, 454.51it/s]
#   8%|7         | 220/2866 [00:00<00:03, 767.78it/s]
#  24%|##4       | 694/2866 [00:00<00:00, 2179.28it/s]
#  33%|###3      | 952/2866 [00:00<00:00, 2315.23it/s]
#  58%|#####8    | 1672/2866 [00:00<00:00, 3846.06it/s]
#  77%|#######7  | 2212/2866 [00:00<00:00, 4238.97it/s]
# 100%|##########| 2866/2866 [00:00<00:00, 3058.73it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 193.65it/s]
#
#   0%|          | 0/2912 [00:00<?, ?it/s]
#   1%|          | 26/2912 [00:00<00:12, 226.05it/s]
#   2%|1         | 49/2912 [00:00<00:12, 223.23it/s]
#   5%|4         | 140/2912 [00:00<00:05, 518.17it/s]
#  16%|#6        | 468/2912 [00:00<00:01, 1508.82it/s]
#  34%|###4      | 994/2912 [00:00<00:00, 2631.90it/s]
#  59%|#####8    | 1704/2912 [00:00<00:00, 3100.97it/s]
#  78%|#######8  | 2272/2912 [00:00<00:00, 3121.89it/s]
# 100%|##########| 2912/2912 [00:01<00:00, 2637.21it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 1258.04it/s]
#
#   0%|          | 0/2908 [00:00<?, ?it/s]
#   1%|1         | 38/2908 [00:00<00:09, 296.86it/s]
#   5%|4         | 132/2908 [00:00<00:04, 601.70it/s]
#  11%|#1        | 332/2908 [00:00<00:02, 1117.54it/s]
#  23%|##3       | 672/2908 [00:00<00:01, 1880.41it/s]
#  39%|###8      | 1120/2908 [00:00<00:00, 2698.88it/s]
#  60%|#####9    | 1744/2908 [00:00<00:00, 3791.46it/s]
#  73%|#######3  | 2133/2908 [00:00<00:00, 3388.69it/s]
# 100%|##########| 2908/2908 [00:01<00:00, 2767.90it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 166.71it/s]
#
#   0%|          | 0/2856 [00:00<?, ?it/s]
#   1%|1         | 38/2856 [00:00<00:08, 332.27it/s]
#   4%|3         | 110/2856 [00:00<00:05, 520.66it/s]
#   8%|8         | 242/2856 [00:00<00:03, 809.96it/s]
#  20%|##        | 584/2856 [00:00<00:01, 1742.63it/s]
#  38%|###7      | 1080/2856 [00:00<00:00, 2708.55it/s]
#  64%|######4   | 1840/2856 [00:00<00:00, 4075.47it/s]
#  79%|#######8  | 2246/2856 [00:00<00:00, 3391.44it/s]
# 100%|##########| 2856/2856 [00:01<00:00, 2776.10it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 140.15it/s]
#
#   0%|          | 0/2894 [00:00<?, ?it/s]
#   1%|          | 26/2894 [00:00<00:12, 225.96it/s]
#   2%|1         | 49/2894 [00:00<00:12, 223.10it/s]
#   5%|5         | 154/2894 [00:00<00:04, 557.30it/s]
#  14%|#4        | 418/2894 [00:00<00:01, 1316.98it/s]
#  33%|###3      | 964/2894 [00:00<00:00, 2617.83it/s]
#  56%|#####6    | 1624/2894 [00:00<00:00, 3088.04it/s]
#  74%|#######4  | 2152/2894 [00:00<00:00, 3128.61it/s]
# 100%|##########| 2894/2894 [00:01<00:00, 2623.17it/s]
#
# 100%|##########| 1/1 [00:00<00:00, 128.16it/s]
#
#   0%|          | 0/2882 [00:00<?, ?it/s]
#   1%|1         | 40/2882 [00:00<00:08, 348.54it/s]
#   3%|2         | 75/2882 [00:00<00:08, 323.80it/s]
#   6%|6         | 184/2882 [00:00<00:04, 631.15it/s]
#  17%|#6        | 480/2882 [00:00<00:01, 1445.91it/s]
#  33%|###3      | 964/2882 [00:00<00:00, 2539.45it/s]
#  66%|######6   | 1912/2882 [00:00<00:00, 3278.44it/s]
# 100%|##########| 2882/2882 [00:01<00:00, 2703.82it/s]

# %%
for x in range(10):
    s = SHAP_g['shapley_importance_class_%s' % x]
    smin = s[s != 0].min()
    s1 = s.values
    s1[s1 == 0] = smin
    g = s1.reshape(*mp.fmap_shape)
    fig, ax = plt.subplots()
    ax.imshow(g, cmap = 'rainbow', vmin=0)

# %%
plt.imshow(testX_noisy[0].reshape(28,28))
